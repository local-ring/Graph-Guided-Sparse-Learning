# %%
import numpy as np
import scipy.io as sio
from scipy.linalg import toeplitz
from scipy.stats import multivariate_normal
import time
import random
from scipy.linalg import block_diag
from sklearn.metrics import precision_recall_curve, auc
import scipy.stats
import networkx as nx
import seaborn as sns
import matplotlib.pyplot as plt

import numpy as np
import random
import scipy.sparse as sp
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pickle
from collections import defaultdict

import sys
# sys.path.append('/Users/yijwang-admin/Documents/Research/GFL/Code/PQN_Python_main')
from minConf.minConf_PQN import minConF_PQN
import random
import itertools
import os
import matlab.engine
from sklearn.linear_model import Lasso

# %%
import numpy as np
from scipy.sparse import spdiags
from scipy.linalg import inv
from gurobipy import Model, GRB, QuadExpr

def GroupLasso(u, X, y, rho):
    n, d = X.shape
    D_u = spdiags(u.flatten(), 0, d, d)
    M = inv((1/rho) * X @ D_u @ X.T + np.eye(n))
    f = y.T @ M @ y
    g = -(1/(2*rho)) * ((X.T @ M @ y)**2)

    return f, g

def GeneralizedFusedLasso(u, X, y, rho, L, mu):
    n, d = X.shape
    D_u = spdiags(u.flatten(), 0, d, d)
    M = inv((1/rho) * X @ D_u @ X.T + np.eye(n))
    f = (1/2) * y.T @ M @ y + mu * u.T @ L @ u
    g = -(1/(2*rho)) * ((X.T @ M @ y)**2) + 2 * mu * L @ u

    return f.flatten(), g.flatten()


def ProjLassoGurobi(u, k, d):
    A = np.ones((1, d))
    b = np.array([k])
    Q = np.eye(d)
    f = -2 * u.flatten()

    model = Model("GeneralizedFusedLasso")
    x = model.addMVar(d, lb=0.0, ub=1.0)

    model.setObjective(x@Q@x + x@f)
    model.addConstr(A @ x == b)

    model.setParam('OutputFlag', 0)
    model.setParam('IterationLimit', 500)

    model.optimize()
    # print("Lasso x.x: ", x.x)

    return x.x

def ProjGroupLassoGurobi(u, k, groups, h, d):
    """
    Solves the Group Lasso projection problem using Gurobi.

    Parameters:
    - u: Input vector of size (d, 1)
    - k: Sparsity level (L1 constraint)
    - groups: List of groups, where each group is a list of indices
    - h: Sum constraint for group norms

    Returns:
    - up: Projected vector (u')
    - zp: Auxiliary variables for group norms
    """
    # d = u.shape  # Number of variables
    g = len(groups)  # Number of groups

    # Quadratic objective matrices and linear term
    H1 = np.eye(d)  # Identity for quadratic term on `u`
    f1 = -2 * u.flatten()  # Linear term for `u`
    H2 = np.zeros((g, g))  # No quadratic term for auxiliary variables
    f2 = np.zeros(g)  # No linear term for auxiliary variables

    # Combine H1, H2 and f1, f2 into block matrices
    H = np.block([[H1, np.zeros((d, g))], [np.zeros((g, d)), H2]])
    f = np.concatenate([f1, f2])

    # Constraint matrices for `u` (A1) and `z` (A2)
    A1 = np.vstack([np.ones((1, d)), -np.ones((1, d))])  # L1 constraint on `u`
    A2 = np.zeros((2, g))  # Initialize A2
    group_constraints_count = 0

    # Build group constraints
    for i, group in enumerate(groups):
        for idx in group:
            A1_row = np.zeros((1, d))
            A1_row[0, idx] = 1
            A1 = np.vstack([A1, A1_row])  # Adding constraints for group indices

            A2_row = np.zeros((1, g))
            A2_row[0, i] = -1
            A2 = np.vstack([A2, A2_row])  # Adding constraints for group norms
            group_constraints_count += 1

    # Add overall group norm constraint
    A1 = np.vstack([A1, np.zeros((1, d))])
    A2 = np.vstack([A2, np.ones((1, g))])
    A = np.hstack([A1, A2])  # Combine A1 and A2

    # RHS vector for constraints
    b = np.zeros(group_constraints_count + 3)
    b[0] = k  # Sparsity constraint (sum of u <= k)
    b[1] = -k + 1  # Lower bound for sparsity
    b[-1] = h  # Sum constraint for group norms

    # Lower and upper bounds for variables
    lb = np.zeros(d + g)
    ub = np.ones(d + g)

    # Setup Gurobi model
    model = Model("ProjGroupLasso")
    x = model.addMVar(d + g, lb=lb, ub=ub)  # Variables for `u` and `z`

    # Set quadratic objective
    model.setObjective(x @ H @ x + x @ f)

    # Add constraints
    model.addConstr(A @ x <= b)

    # Configure Gurobi parameters
    model.setParam('OutputFlag', 0)  # Suppress output
    model.setParam('IterationLimit', 500)
    # Solve the model
    model.optimize()

    # Extract the results
    up = x.x[:d]  # Projected vector `u'`
    zp = x.x[d:]  # Auxiliary variables `z'`

    # print("GroupLasso x.x: ", up[:, np.newaxis])

    return up


def ProjGeneralizedFusedLassoGurobi(u, k, d):
    A = np.ones((1, d))
    b = np.array([k])
    c = np.array([k-1])
    
    # A = np.vstack([A, -np.ones((1, d))])
    # b = np.vstack([b, -k + 1])
    Q = np.eye(d)
    f = -2 * u.flatten()

    model = Model("GeneralizedFusedLasso")
    x = model.addMVar(d, lb=0.0, ub=1.0)

    model.setObjective(x@Q@x + x@f)
    model.addConstr(A @ x <= b)
    # model.addConstr(A @ x >= c)

    model.setParam('OutputFlag', 0)
    model.setParam('IterationLimit', 500)

    model.optimize()
    # print("GeneralizedFusedLasso x.x: ", x.x)

    return x.x

# %%
class RandomEnsemble:
    def __init__(self, n, d, k, h_total, h_selected, h_rest, gamma, 
                 p=0.95, q=0.01, 
                 options=None, num_replications=20,
                 datafile=f'./code_fgfl_aaai14/data_gfl/',
                 resultfile='./code_fgfl_aaai14/result_gfl/',
                 models=None):
        assert h_total == h_selected + h_rest, "h_total should be equal to h_selected + h_rest"
        self.n = n
        self.d = d
        self.k = k
        self.h_total = h_total
        self.h_selected = h_selected
        self.h_rest = h_rest
        self.gamma = gamma
        self.p = p
        self.q = q
        self.options = options if options else {'maxIter': 500, 'verbose': 0, 'SPGiters': 100}
        self.num_replications = num_replications
        self.datafile = os.path.join(os.path.abspath(datafile), f'{n}_{d}_{k}_{h_total}_{h_selected}_{h_rest}_{gamma}_{p}_{q}')
        self.resultfile = os.path.join(os.path.abspath(resultfile), f'{n}_{d}_{k}_{h_total}_{h_selected}_{h_rest}_{gamma}_{p}_{q}') # matlab does not like relative path
        self.best_rho1 = 0.5
        self.best_rho2 = 0.5
        self.best_mu = 1.0
        # self.best_rho = np.sqrt(self.n) * 6.8
        self.best_rho = np.sqrt(self.n)
        self.datafile_pqn = os.path.join(os.path.abspath('./PQN/data/'), f'{n}_{d}_{k}_{h_total}_{h_selected}_{h_rest}_{gamma}_{p}_{q}')
        self.resultfile_pqn = os.path.join(os.path.abspath('./PQN/result/'), f'{n}_{d}_{k}_{h_total}_{h_selected}_{h_rest}_{gamma}_{p}_{q}')
        self._init(self.datafile, self.resultfile)
        self._init(self.datafile_pqn, self.resultfile_pqn)
        self.models = models

    
    def _init(self, datafile, resultfile):
        if not os.path.exists(datafile):
            os.makedirs(datafile)
        if not os.path.exists(resultfile):
            os.makedirs(resultfile)

    def _random_partition(self):
        # partition the first k nodes into h_selected groups and the rest into h_rest groups
        assert self.h_selected <= self.k, "h_selected should be less than k"
        assert self.h_rest <= self.d - self.k, "h_rest should be less d-k"
        if self.k % self.h_selected != 0 or (self.d - self.k) % self.h_rest != 0:
            break_points = np.sort(random.sample(range(1, self.k), self.h_selected-1))
            break_points_rest = np.sort(random.sample(range(self.k+1, self.d), self.h_rest-1))
        else: # evenly divide the nodes
            break_points = np.arange(self.k // self.h_selected, self.k, self.k // self.h_selected)
            break_points_rest = np.arange(self.k + (self.d - self.k) // self.h_rest, self.d, (self.d - self.k) // self.h_rest)
            
        return break_points, break_points_rest
    
    def _generate_clusters(self):
        break_points, break_points_rest = self._random_partition()
        clusters = []
        clusters.append(np.arange(break_points[0])) # first selected cluster
        for i in range(1, self.h_selected-1):
            clusters.append(np.arange(break_points[i-1], break_points[i]))
        clusters.append(np.arange(break_points[-1], self.k)) # last selected cluster

        clusters.append(np.arange(self.k, break_points_rest[0])) # first rest cluster
        for i in range(1, self.h_rest-1):
            clusters.append(np.arange(break_points_rest[i-1], break_points_rest[i]))
        clusters.append(np.arange(break_points_rest[-1], self.d))

        return clusters

    def _generate_graph(self):
        # here we generate the adjacency matrix and laplacian of the graph
        clusters = self._generate_clusters()

        A = sp.lil_matrix((self.d, self.d))
        
        # generate thr inner cluster connections
        for cluster in clusters:
            cluster_size = len(cluster)
            block = (np.random.rand(cluster_size, cluster_size) < self.p).astype(int)
            np.fill_diagonal(block, 0) # no self-loop
            block = np.triu(block) + np.triu(block, 1).T # make it symmetric
            for i, node_i in enumerate(cluster):
                for j, node_j in enumerate(cluster):
                    A[node_i, node_j] = block[i, j]

        # generate the connections between clusters
        for i in range(self.h_total):
            for j in range(i+1, self.h_total):
                cluster_i = clusters[i]
                cluster_j = clusters[j]
                block = (np.random.rand(len(cluster_i), len(cluster_j)) < self.q).astype(int)
                for m, node_i in enumerate(cluster_i):
                    for n, node_j in enumerate(cluster_j):
                        A[node_i, node_j] = block[m, n]
                        A[node_j, node_i] = block[m, n]

        # TODO: check if the graph is connected and make it connected if not 
        # (optional, maybe not necessary)
        D = sp.diags(np.ravel(A.sum(axis=1)))
        L = D - A
        return L, clusters, A
    
    def _visualize_graph(self, A):
        # if we want to visualize the graph, we need to change it to array rather than sparse matrix
        A_arr = A.toarray()
        plt.figure(figsize=(8, 8))
        plt.title('Adjacency matrix')
        plt.spy(A_arr)
        plt.axis('off')
        plt.show()

    def _generate_w(self, clusters):
        w = np.zeros(self.d)
        for i in range(self.h_selected):
            cluster_sign = np.random.choice([-1, 1])
            cluster_weight = cluster_sign * (1 / np.sqrt(self.k)) # TODO: make more choice other than 1/sqrt(k)
            for node in clusters[i]:
                w[node] = cluster_weight
        # w = w[:, np.newaxis]
        return w

    def _generate_X(self):
        # X = np.random.normal(0, 1, (self.n, self.d))
        mean = np.zeros(self.d)
        cov = np.eye(self.d)
        X = np.random.multivariate_normal(mean, cov, self.n)
        return X
    
    def _generate_y(self, X, w):
        signal = X @ w
        noise = np.random.normal(0, self.gamma, signal.shape)
        y = signal + noise
        SNR = self._compute_snr(signal, noise)
        if 0: # TODO: add a debug/verbose flag
            print(f'SNR: {SNR}')

        return y

    def _generate_data(self):
        L, clusters, A = self._generate_graph()
        if 0: # TODO: add a debug/verbose flag 
            self._visualize_graph(A)
        w = self._generate_w(clusters)
        X = self._generate_X()
        y = self._generate_y(X, w)
        return L, w, X, y, clusters, A


    def _compute_snr(self, signal, noise):  
        # in our case, the snr is 10*log10(1/gamma^2)
        signal = np.asarray(signal)
        noise = np.asarray(noise)

        signal_power = np.mean(signal ** 2)
        noise_power = np.mean(noise ** 2)
        
        snr = signal_power / noise_power
        snr_db = 10 * np.log10(snr)
        
        return snr_db
    
    def _define_obj(self, model, X, y, rho=1, L=None, mu=None):
        """
        Support models: 'Lasso', GroupLasso', 'GeneralizedFusedLasso'
        I plan to support Proximal method by calling matlab session
        this part and the one below is to support PQN, the Proxiaml method is on its own, it does not need this
        """
        if model == "Lasso":
            return lambda u: Lasso(u, X, y, rho)
        elif model == "GroupLasso":
            return lambda u: GroupLasso(u, X, y, rho)
        elif model == "GeneralizedFusedLasso":
            return lambda u: GeneralizedFusedLasso(u, X, y, rho, L, mu)
        else:
            raise ValueError("Model not supported")
        
    def _define_projection(self, model, groups=None):
        """
        Support models: 'Lasso', GroupLasso', 'GeneralizedFusedLasso'
        """
        if model == "Lasso":
            return lambda u: ProjLassoGurobi(u, self.k, self.d)
        elif model == "GroupLasso":
            return lambda u: ProjGroupLassoGurobi(u, self.k, groups, self.h_selected, self.d)
        elif model == "GeneralizedFusedLasso":
            return lambda u: ProjGeneralizedFusedLassoGurobi(u, self.k, self.d)
        else:
            raise ValueError("Model not supported")
        
    def _max_degree(self, L):
        # find the maximum degree of the graph according to the laplacian matrix
        return np.max(np.diag(L.toarray()))
    
    def solver(self, model, X, y, clusters=None, L=None, A=None, i=None, rho=1, mu=1):
        if model == "Proximal":
            return self._solver_proximal(X, y, A, i)
        elif model == "Lasso":
            rho = np.sqrt(self.n) # TODO: check if this is the correct value
            # funObj = self._define_obj(model, X, y, rho)
            # funProj = self._define_projection(model)
            return self._solver_gfl(X, y, L, i, rho, mu=0.0)
        elif model == "GroupLasso":
            rho = np.sqrt(self.n) # TODO: check if this is the correct value
            funObj = self._define_obj(model, X, y, rho)
            funProj = self._define_projection(model, clusters)
        elif model == "GeneralizedFusedLasso":
            # max_degree = self._max_degree(L)
            # rho = 3.4 * self.k * 2 * mu * 2 * max_degree  # TODO: check if this is the correct value
            # rho = np.sqrt(self.n) # TODO: check if this is the correct value
            if i == 0:
                # rho_values = [1, 10, np.sqrt(self.n), 50, 70, 100] # sqrt(300)=17.32
                # rho_values = [10, np.sqrt(self.n), 50, 100]
                rho_values = [0.1, 0.5, 1.0, 5.0]
                mu_values = [0.01, 0.1, 1.0]
                self.best_rho, self.best_mu = self._cross_validation_gfl(X, y, L, rho_values, mu_values)
            else:
                rho = self.best_rho
                mu = self.best_mu
            funObj = self._define_obj(model, X, y, rho, L, mu)
            funProj = self._define_projection(model)
        elif model == "GFL_Matlab":
            # rho = np.sqrt(self.n) # TODO: check if this is the correct value
            # mu = 1.0
            return self._solver_gfl(X, y, L, i)
        elif model == "Lasso_Sklearn":
            return self._solver_lasso_sklearn(X, y)
        else:
            raise ValueError("Model not supported")
        
        uSimplex = np.ones((self.d, 1)) / self.d
        uout, obj, _ = minConF_PQN(funObj, uSimplex, funProj, self.options)
        # uout = funProj(uout) # TODO: check if this is necessary

        self._save_result(uout, f'./res/result_{model}_{i}.mat')

        return uout
    
    def _solver_lasso_sklearn(self, X, y):
        """
        Use sklearn's Lasso implementation to solve the Lasso problem.
        """
        alpha = 0.1
        lasso_model = Lasso(alpha=alpha, max_iter=10000)  # Lasso model with high max_iter
        lasso_model.fit(X, y)  # Fit the model
        u = lasso_model.coef_  # Get the coefficients
        # print(f"Lasso coefficients: {u}")
        return u
    
    def _solver_gfl(self, X, y, L, i, rho=None, mu=None):
        datafile_pqn = os.path.join(self.datafile_pqn, f'data_{i}.mat')
        resultfile_pqn = os.path.join(self.resultfile_pqn, f'result_{i}.mat')
        if rho is None or mu is None: # we don't need to store the data when we do Lasso
            self._save_mat_pqn(X, y, L, datafile_pqn)
        if rho is None or mu is None:
            if i == 0:
                rho_values = [np.sqrt(self.n), 6.8 * np.sqrt(self.n)]
                mu_values = [0.01, 0.1, 1.0]
                self.best_rho, self.best_mu = self._cross_validation_gfl(X, y, L, rho_values, mu_values)
                print(f"Best rho: {self.best_rho}, Best mu: {self.best_mu}")
            rho = self.best_rho
            mu = self.best_mu

        self._call_gfl(datafile_pqn, resultfile_pqn, rho, mu)
        u, _ = self._read_result(resultfile_pqn)
        return u.flatten()
    
    def _save_mat_pqn(self, X, y, L, filename=None):
        # save the data to .mat file so that the matlab code of proxiaml can use it
        # print("X.shape", X.shape)   
        # print("y.shape", y.shape)
        # print("A.shape", A.shape)
        if y.ndim == 1:
            y = y[:, np.newaxis]
        data = {
            "X": X,
            "y": y,
            "L": L.toarray() if sp.issparse(L) else L,  # we store the adjacency matrix as dense matrix
        }
        sio.savemat(filename, data)

    
    def _call_gfl(self, datafile, resultfile, rho, mu):
        eng = matlab.engine.start_matlab()
        try:
            eng.cd(os.path.abspath('./PQN/'))
            eng.addpath(os.path.abspath('./PQN/'))
            eng.addpath(eng.genpath(os.path.abspath('./PQN/')))
            eng.addpath(eng.genpath(os.path.abspath('./PQN/minConF/')))
            eng.gfl_pqn(datafile, resultfile, rho, mu, float(self.k), nargout=0)
        finally:
            eng.quit()
    
    def _save_result(self, u, filename):
        sio.savemat(filename, {'beta': u})
    
    def _gfl_helper(self, X, y, L, rho, mu):
        funObj = self._define_obj("GeneralizedFusedLasso", X, y, rho, L, mu)
        funProj = self._define_projection("GeneralizedFusedLasso")
        uSimplex = np.ones((self.d, 1)) / self.d
        uout, obj, _ = minConF_PQN(funObj, uSimplex, funProj, self.options)
        uout = funProj(uout) # TODO: check if this is necessary

        return uout

    
    def _call_proximal(self, datafile, resultfile, rho1, rho2):
        eng = matlab.engine.start_matlab()
        try:
            eng.cd(os.path.abspath('./code_fgfl_aaai14/'))
            eng.addpath(os.path.abspath('./code_fgfl_aaai14/GFL/'))
            eng.addpath(eng.genpath(os.path.abspath('./code_fgfl_aaai14/')))
            eng.gfl_proximal(datafile, resultfile, rho1, rho2, nargout=0)
        finally:
            eng.quit()

    def _cross_validation(self, X, y, A, rho1_values, rho2_values, k_folds=5):
        results = []
        n = self.n
        indices = np.arange(n)
        np.random.shuffle(indices)
        folds = np.array_split(indices, k_folds)
        datafile = os.path.join(self.datafile, 'data.mat') 
        resultfile = os.path.join(self.resultfile, 'result.mat')

        for rho1, rho2 in itertools.product(rho1_values, rho2_values):
            mse_list = []
            for fold in folds:
                train_indices = np.setdiff1d(indices, fold)
                test_indices = fold
                X_train, y_train = X[train_indices], y[train_indices]
                X_test, y_test = X[test_indices], y[test_indices]

                self._save_mat(X_train, y_train, A, datafile)
                self._call_proximal(datafile, resultfile, rho1, rho2)
                u, funcVal = self._read_result(resultfile)      
                mse = np.mean((X_test @ u - y_test) ** 2)
                mse_list.append(mse)

            avg = np.mean(mse_list)
            results.append((rho1, rho2, avg))

        best_rho1, best_rho2, _ = min(results, key=lambda x: x[2])
        return best_rho1, best_rho2
    
    def _cross_validation_gfl(self, X, y, L, rho_values, mu_values, k_folds=5):
        results = []
        n = self.n
        indices = np.arange(n)
        np.random.shuffle(indices)
        folds = np.array_split(indices, k_folds)
        datafile = os.path.join(self.datafile_pqn, 'data.mat')
        resultfile = os.path.join(self.resultfile_pqn, 'result.mat')

        for rho, mu in itertools.product(rho_values, mu_values):
            acc_list = []
            for fold in folds:
                train_indices = np.setdiff1d(indices, fold)
                test_indices = fold
                X_train, y_train = X[train_indices], y[train_indices]
                # X_test, y_test = X[test_indices], y[test_indices]
                self._save_mat_pqn(X_train, y_train, L, datafile)
                self._call_gfl(datafile, resultfile, rho, mu)
                u, _ = self._read_result(resultfile)
                u = u.flatten()
                acc_score = self.recovery_accuracy(u)
                acc_list.append(acc_score)
                

            avg = np.mean(acc_list)
            results.append((rho, mu, avg))
            print(f"rho: {rho}, mu: {mu}, acc: {avg}")
        
        
        best_rho, best_mu, _ = max(results, key=lambda x: x[2])
        # print(f"Best rho: {best_rho}, Best mu: {best_mu}")
        return best_rho, best_mu

    def _read_result(self, resultfile):
        result = sio.loadmat(resultfile)
        beta, funcVal = result['beta'], result['funcVal']
        return beta, funcVal
        
    def _solver_proximal(self, X, y, A, i):
        # rho1_values = [0.1, 0.5, 1.0, 5.0]
        # rho2_values = [0.1, 0.5, 1.0, 5.0]
        # if i == 0: # we only do cross validation once and use the best rho1 and rho2 for the rest of the replications
        #     self.best_rho1, self.best_rho2 = self._cross_validation(X, y, A, rho1_values, rho2_values)
        #     print(f"Best rho1: {self.best_rho1}, Best rho2: {self.best_rho2}")

        datafile_name = os.path.join(self.datafile, f'data_{i}.mat')
        resultfile_name = os.path.join(self.resultfile, f'result_{i}.mat')
        self._save_mat(X, y, A, datafile_name)
        self._call_proximal(datafile_name, resultfile_name, self.best_rho1, self.best_rho2)
        u, funcVal = self._read_result(resultfile_name)
        return u.flatten() # the original return a vector with shape (d,1), will not work with recovery_accuracy

    def recovery_accuracy(self, u):
        # evaluate the support recovery accuracy
        # we take top k for u
        selected_features_true = np.arange(self.k)
        selected_features_pred = np.argsort(np.abs(u))[-self.k:] # take absolute value for proximal method
        correct_pred = np.intersect1d(selected_features_true, selected_features_pred)
        accuracy = len(correct_pred) / self.k
        return accuracy
    
    def _save_mat(self, X, y, A, filename=None):
        # save the data to .mat file so that the matlab code of proxiaml can use it
        # print("X.shape", X.shape)   
        # print("y.shape", y.shape)
        # print("A.shape", A.shape)
        if y.ndim == 1:
            y = y[:, np.newaxis]
        data = {
            "X": X,
            "y": y,
            "AdjMat": A.toarray() if sp.issparse(A) else A,  # we store the adjacency matrix as dense matrix
        }
        sio.savemat(filename, data)

    def _report(self, model_accuracy):
        for model, accuracy in model_accuracy.items():
            avg_accuracy = np.mean(accuracy)
            std_accuracy = np.std(accuracy)
            print(f"Model: {model}, Avg. Accuracy: {avg_accuracy}, Std. Accuracy: {std_accuracy}")

    def main(self):
        # models = ["Proximal", "Lasso", "GroupLasso", "GeneralizedFusedLasso"]
        # models = ["GeneralizedFusedLasso", "Proximal"]
        if self.models is None:
            models = ["GFL_Matlab", "Lasso", "Proximal", "Lasso_Sklearn"]
        else:
            models = self.models
        # models = ["Lasso_Sklearn"]
        model_accuracy = defaultdict(list)
        for i in range(self.num_replications):
            L, w, X, y, clusters, A = self._generate_data()
            for model in models:
                print(f"Synthetic dataset {i+1}: Running {model} model")
                u = self.solver(model, X, y, clusters, L, A, i)
                accuracy = self.recovery_accuracy(u)
                model_accuracy[model].append(accuracy)

        self._report(model_accuracy)
        return model_accuracy
    
# TODO: solve the orginal problem and calculate the MSE?


class RandomEnsembleWeight(RandomEnsemble):
    def _generate_w(self, clusters):
        w = np.zeros(self.d)
        cluster_weights = []

        # Generate non-zero random weights for clusters
        for _ in range(self.h_selected):
            cluster_sign = np.random.choice([-1, 1])
            cluster_weight = np.random.choice([0.5, 1.0, 2.0, 99.0, 100.0])
            cluster_weights.append(cluster_sign * cluster_weight)

        # Normalize the cluster weights to ensure the sum of squares is 1
        cluster_weights = np.array(cluster_weights)
        cluster_weights /= np.linalg.norm(cluster_weights)  # Normalize to make sum of squares = 1

        # Assign the same weight to all nodes in each cluster
        for i, cluster in enumerate(clusters[:self.h_selected]):
            for node in cluster:
                w[node] = cluster_weights[i]

        return w

# %%
sample_sizes = np.arange(50, 250, 50)
accuracy = []
for n in sample_sizes:
    random_ensemble = RandomEnsemble(n=n, d=1000, k=50, 
                                     h_total=40, h_selected=2, h_rest=38, 
                                     gamma=0.05, p=0.95, q=0.1, 
                                     num_replications=5, 
                                     models=["GFL_Matlab", "Proximal", "Lasso"])
    accuracy.append(random_ensemble.main())
# Out:
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 7.0710678118654755, mu: 0.01, acc: 0.164
# rho: 7.0710678118654755, mu: 0.1, acc: 0.172
# rho: 7.0710678118654755, mu: 1.0, acc: 0.168
# rho: 48.08326112068523, mu: 0.01, acc: 0.17200000000000001
# rho: 48.08326112068523, mu: 0.1, acc: 0.168
# rho: 48.08326112068523, mu: 1.0, acc: 0.17200000000000001
# Best rho: 48.08326112068523, Best mu: 0.01
# Synthetic dataset 1: Running Proximal model
# 1 3
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Proximal model
# 1 3
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Proximal model
# 1 3
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Proximal model
# 1 3
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Proximal model
# 1 3
# Synthetic dataset 5: Running Lasso model
# Model: GFL_Matlab, Avg. Accuracy: 0.196, Std. Accuracy: 0.026532998322843195
# Model: Proximal, Avg. Accuracy: 0.0, Std. Accuracy: 0.0
# Model: Lasso, Avg. Accuracy: 0.17200000000000001, Std. Accuracy: 0.020396078054371138
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 10.0, mu: 0.01, acc: 0.244
# rho: 10.0, mu: 0.1, acc: 0.22799999999999998
# rho: 10.0, mu: 1.0, acc: 0.23199999999999998
# rho: 68.0, mu: 0.01, acc: 0.236
# rho: 68.0, mu: 0.1, acc: 0.236
# rho: 68.0, mu: 1.0, acc: 0.236
# Best rho: 10.0, Best mu: 0.01
# Synthetic dataset 1: Running Proximal model
# 7 9
# 7 9
# 7 9
# 7 9
# 7 9
# 7 9
# 7 9
# 7 9
# 7 9
# 5 7
# 5 7
# 5 7
# 5 7
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Proximal model
# 20 22
# 20 22
# 20 22
# 20 22
# 20 22
# 20 22
# 20 22
# 20 22
# 20 22
# 12 14
# 12 14
# 11 13
# 12 14
# 12 14
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Proximal model
# 15 17
# 15 17
# 15 17
# 15 17
# 15 17
# 15 17
# 15 17
# 15 17
# 15 17
# 11 13
# 11 13
# 10 12
# 10 12
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Proximal model
# 10 12
# 10 12
# 10 12
# 10 12
# 10 12
# 10 12
# 10 12
# 10 12
# 10 12
# 9 11
# 8 10
# 9 11
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Proximal model
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# Synthetic dataset 5: Running Lasso model
# Model: GFL_Matlab, Avg. Accuracy: 0.312, Std. Accuracy: 0.041182520563947986
# Model: Proximal, Avg. Accuracy: 0.07999999999999999, Std. Accuracy: 0.0282842712474619
# Model: Lasso, Avg. Accuracy: 0.272, Std. Accuracy: 0.00979795897113272
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 12.24744871391589, mu: 0.01, acc: 0.29600000000000004
# rho: 12.24744871391589, mu: 0.1, acc: 0.30000000000000004
# rho: 12.24744871391589, mu: 1.0, acc: 0.29600000000000004
# rho: 83.28265125462805, mu: 0.01, acc: 0.324
# rho: 83.28265125462805, mu: 0.1, acc: 0.304
# rho: 83.28265125462805, mu: 1.0, acc: 0.30000000000000004
# Best rho: 83.28265125462805, Best mu: 0.01
# Synthetic dataset 1: Running Proximal model
# 9 11
# 9 11
# 9 11
# 9 11
# 9 11
# 9 11
# 9 11
# 9 11
# 9 11
# 8 10
# 7 9
# 6 8
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Proximal model
# 17 19
# 17 19
# 17 19
# 17 19
# 17 19
# 17 19
# 17 19
# 17 19
# 17 19
# 17 19
# 17 19
# 14 16
# 14 16
# 12 14
# 11 13
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Proximal model
# 37 39
# 37 39
# 37 39
# 37 39
# 37 39
# 37 39
# 37 39
# 37 39
# 37 39
# 37 39
# 27 29
# 26 28
# 24 26
# 21 23
# 21 23
# 19 21
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Proximal model
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 27 29
# 21 23
# 20 22
# 17 19
# 18 20
# 17 19
# 15 17
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Proximal model
# 36 38
# 36 38
# 36 38
# 36 38
# 36 38
# 36 38
# 36 38
# 36 38
# 36 38
# 36 38
# 27 29
# 18 20
# 16 18
# 14 16
# 15 17
# 14 16
# Synthetic dataset 5: Running Lasso model
# Model: GFL_Matlab, Avg. Accuracy: 0.396, Std. Accuracy: 0.06621178142898738
# Model: Proximal, Avg. Accuracy: 0.128, Std. Accuracy: 0.09927738916792686
# Model: Lasso, Avg. Accuracy: 0.356, Std. Accuracy: 0.0932952303175248
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 14.142135623730951, mu: 0.01, acc: 0.528
# rho: 14.142135623730951, mu: 0.1, acc: 0.48
# rho: 14.142135623730951, mu: 1.0, acc: 0.4640000000000001
# rho: 96.16652224137046, mu: 0.01, acc: 0.504
# rho: 96.16652224137046, mu: 0.1, acc: 0.472
# rho: 96.16652224137046, mu: 1.0, acc: 0.45200000000000007
# Best rho: 14.142135623730951, Best mu: 0.01
# Synthetic dataset 1: Running Proximal model
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 48 50
# 41 43
# 38 40
# 38 40
# 34 36
# 33 35
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Proximal model
# 55 57
# 55 57
# 55 57
# 55 57
# 55 57
# 55 57
# 55 57
# 55 57
# 55 57
# 55 57
# 39 41
# 36 38
# 28 30
# 26 28
# 22 24
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Proximal model
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 57 59
# 51 53
# 45 47
# 43 45
# 38 40
# 37 39
# 34 36
# 29 31
# 30 32
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Proximal model
# 113 115
# 113 115
# 113 115
# 113 115
# 113 115
# 113 115
# 113 115
# 113 115
# 113 115
# 113 115
# 113 115
# 73 75
# 64 66
# 57 59
# 51 53
# 52 54
# 45 47
# 50 52
# 46 48
# 41 43
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Proximal model
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 42 44
# 34 36
# 32 34
# 30 32
# 29 31
# Synthetic dataset 5: Running Lasso model
# Model: GFL_Matlab, Avg. Accuracy: 0.68, Std. Accuracy: 0.045607017003965515
# Model: Proximal, Avg. Accuracy: 0.548, Std. Accuracy: 0.13481839637082174
# Model: Lasso, Avg. Accuracy: 0.8640000000000001, Std. Accuracy: 0.18304097901836078

# %%
acc_1 = []
acc_2 = []
std_1 = []
std_2 = []
acc_3 = []
std_3 = []


# Extract means and standard deviations for three models:
for i in range(len(accuracy)):
    acc_1.append(np.mean(accuracy[i]["GFL_Matlab"]))
    std_1.append(np.std(accuracy[i]["GFL_Matlab"]))
    acc_2.append(np.mean(accuracy[i]["Proximal"]))
    std_2.append(np.std(accuracy[i]["Proximal"]))
    acc_3.append(np.mean(accuracy[i]["Lasso"]))
    std_3.append(np.std(accuracy[i]["Lasso"]))

# Plot the results
plt.figure(figsize=(8, 6))
plt.errorbar(sample_sizes, acc_1, yerr=std_1, fmt='o-', label='GFL_Matlab')
plt.errorbar(sample_sizes, acc_2, yerr=std_2, fmt='o-', label='Proximal')
plt.errorbar(sample_sizes, acc_3, yerr=std_3, fmt='o-', label='Lasso')
plt.xlabel('Sample Size')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Sample Size')
plt.legend()

plt.show()

# %%
sample_sizes = np.arange(50, 250, 50)
accuracy = []
for n in sample_sizes:
    random_ensemble = RandomEnsemble(n=n, d=1000, k=50, 
                                     h_total=40, h_selected=2, h_rest=38, 
                                     gamma=0.5, p=0.95, q=0.1, 
                                     num_replications=5, 
                                     models=["GFL_Matlab", "Proximal", "Lasso"])
    accuracy.append(random_ensemble.main())
# Out:
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 7.0710678118654755, mu: 0.01, acc: 0.16
# rho: 7.0710678118654755, mu: 0.1, acc: 0.152
# rho: 7.0710678118654755, mu: 1.0, acc: 0.148
# rho: 48.08326112068523, mu: 0.01, acc: 0.16
# rho: 48.08326112068523, mu: 0.1, acc: 0.156
# rho: 48.08326112068523, mu: 1.0, acc: 0.16
# Best rho: 7.0710678118654755, Best mu: 0.01
# Synthetic dataset 1: Running Proximal model
# 1 3
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Proximal model
# 1 3
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Proximal model
# 1 3
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Proximal model
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Proximal model
# 1 3
# Synthetic dataset 5: Running Lasso model
# Model: GFL_Matlab, Avg. Accuracy: 0.16799999999999998, Std. Accuracy: 0.056
# Model: Proximal, Avg. Accuracy: 0.0, Std. Accuracy: 0.0
# Model: Lasso, Avg. Accuracy: 0.156, Std. Accuracy: 0.04963869458396343
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 10.0, mu: 0.01, acc: 0.172
# rho: 10.0, mu: 0.1, acc: 0.176
# rho: 10.0, mu: 1.0, acc: 0.184
# rho: 68.0, mu: 0.01, acc: 0.176
# rho: 68.0, mu: 0.1, acc: 0.18
# rho: 68.0, mu: 1.0, acc: 0.18
# Best rho: 10.0, Best mu: 1.0
# Synthetic dataset 1: Running Proximal model
# 17 19
# 17 19
# 17 19
# 17 19
# 17 19
# 17 19
# 17 19
# 17 19
# 17 19
# 9 11
# 7 9
# 7 9
# 7 9
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Proximal model
# 34 36
# 34 36
# 34 36
# 34 36
# 34 36
# 34 36
# 34 36
# 34 36
# 34 36
# 34 36
# 28 30
# 26 28
# 21 23
# 18 20
# 17 19
# 17 19
# 17 19
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Proximal model
# 24 26
# 24 26
# 24 26
# 24 26
# 24 26
# 24 26
# 24 26
# 24 26
# 24 26
# 19 21
# 16 18
# 15 17
# 15 17
# 15 17
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Proximal model
# 16 18
# 16 18
# 16 18
# 16 18
# 16 18
# 16 18
# 16 18
# 16 18
# 16 18
# 13 15
# 11 13
# 9 11
# 9 11
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Proximal model
# 13 15
# 13 15
# 13 15
# 13 15
# 13 15
# 13 15
# 13 15
# 13 15
# 13 15
# 11 13
# 11 13
# 10 12
# 10 12
# Synthetic dataset 5: Running Lasso model
# Model: GFL_Matlab, Avg. Accuracy: 0.22400000000000003, Std. Accuracy: 0.0571314274283428
# Model: Proximal, Avg. Accuracy: 0.092, Std. Accuracy: 0.06997142273814361
# Model: Lasso, Avg. Accuracy: 0.192, Std. Accuracy: 0.03709447398198281
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 12.24744871391589, mu: 0.01, acc: 0.304
# rho: 12.24744871391589, mu: 0.1, acc: 0.304
# rho: 12.24744871391589, mu: 1.0, acc: 0.312
# rho: 83.28265125462805, mu: 0.01, acc: 0.31200000000000006
# rho: 83.28265125462805, mu: 0.1, acc: 0.3
# rho: 83.28265125462805, mu: 1.0, acc: 0.296
# Best rho: 83.28265125462805, Best mu: 0.01
# Synthetic dataset 1: Running Proximal model
# 50 52
# 50 52
# 50 52
# 50 52
# 50 52
# 50 52
# 50 52
# 50 52
# 50 52
# 50 52
# 32 34
# 29 31
# 30 32
# 27 29
# 26 28
# 27 29
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Proximal model
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 52 54
# 43 45
# 40 42
# 35 37
# 36 38
# 31 33
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Proximal model
# 56 58
# 56 58
# 56 58
# 56 58
# 56 58
# 56 58
# 56 58
# 56 58
# 56 58
# 56 58
# 39 41
# 36 38
# 35 37
# 30 32
# 29 31
# 29 31
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Proximal model
# 27 29
# 27 29
# 27 29
# 27 29
# 27 29
# 27 29
# 27 29
# 27 29
# 27 29
# 27 29
# 17 19
# 18 20
# 13 15
# 12 14
# 11 13
# 11 13
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Proximal model
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 36 38
# 26 28
# 24 26
# 21 23
# 19 21
# 20 22
# 18 20
# Synthetic dataset 5: Running Lasso model
# Model: GFL_Matlab, Avg. Accuracy: 0.35200000000000004, Std. Accuracy: 0.037094473981982824
# Model: Proximal, Avg. Accuracy: 0.23200000000000004, Std. Accuracy: 0.1092520022699813
# Model: Lasso, Avg. Accuracy: 0.292, Std. Accuracy: 0.0574108003776293
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 14.142135623730951, mu: 0.01, acc: 0.384
# rho: 14.142135623730951, mu: 0.1, acc: 0.372
# rho: 14.142135623730951, mu: 1.0, acc: 0.368
# rho: 96.16652224137046, mu: 0.01, acc: 0.384
# rho: 96.16652224137046, mu: 0.1, acc: 0.392
# rho: 96.16652224137046, mu: 1.0, acc: 0.392
# Best rho: 96.16652224137046, Best mu: 0.1
# Synthetic dataset 1: Running Proximal model
# 77 79
# 77 79
# 77 79
# 77 79
# 77 79
# 77 79
# 77 79
# 77 79
# 77 79
# 77 79
# 49 51
# 42 44
# 39 41
# 39 41
# 36 38
# 37 39
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Proximal model
# 157 159
# 157 159
# 157 159
# 157 159
# 157 159
# 157 159
# 157 159
# 157 159
# 157 159
# 157 159
# 157 159
# 114 116
# 104 106
# 86 88
# 78 80
# 77 79
# 65 67
# 58 60
# 58 60
# 55 57
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Proximal model
# 86 88
# 86 88
# 86 88
# 86 88
# 86 88
# 86 88
# 86 88
# 86 88
# 86 88
# 86 88
# 86 88
# 62 64
# 53 55
# 48 50
# 42 44
# 40 42
# 39 41
# 37 39
# 37 39
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Proximal model
# 90 92
# 90 92
# 90 92
# 90 92
# 90 92
# 90 92
# 90 92
# 90 92
# 90 92
# 90 92
# 90 92
# 76 78
# 74 76
# 64 66
# 53 55
# 49 51
# 45 47
# 46 48
# 45 47
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Proximal model
# 111 113
# 111 113
# 111 113
# 111 113
# 111 113
# 111 113
# 111 113
# 111 113
# 111 113
# 111 113
# 111 113
# 82 84
# 61 63
# 54 56
# 46 48
# 45 47
# 40 42
# 40 42
# 33 35
# Synthetic dataset 5: Running Lasso model
# Model: GFL_Matlab, Avg. Accuracy: 0.484, Std. Accuracy: 0.06248199740725324
# Model: Proximal, Avg. Accuracy: 0.516, Std. Accuracy: 0.06740919818541086
# Model: Lasso, Avg. Accuracy: 0.42800000000000005, Std. Accuracy: 0.053065996645686404

# %%
acc_1 = []
acc_2 = []
std_1 = []
std_2 = []
acc_3 = []
std_3 = []


# Extract means and standard deviations for three models:
for i in range(len(accuracy)):
    acc_1.append(np.mean(accuracy[i]["GFL_Matlab"]))
    std_1.append(np.std(accuracy[i]["GFL_Matlab"]))
    acc_2.append(np.mean(accuracy[i]["Proximal"]))
    std_2.append(np.std(accuracy[i]["Proximal"]))
    acc_3.append(np.mean(accuracy[i]["Lasso"]))
    std_3.append(np.std(accuracy[i]["Lasso"]))

# Plot the results
plt.figure(figsize=(8, 6))
plt.errorbar(sample_sizes, acc_1, yerr=std_1, fmt='o-', label='GFL_Matlab', capsize=5)
plt.errorbar(sample_sizes, acc_2, yerr=std_2, fmt='o-', label='Proximal', capsize=5)
plt.errorbar(sample_sizes, acc_3, yerr=std_3, fmt='o-', label='Lasso', capsize=5)
plt.xlabel('Sample Size')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Sample Size')
plt.legend()

plt.show()

# %%
sample_sizes = np.arange(50, 500, 50)
accuracy = []
for n in sample_sizes:
    random_ensemble = RandomEnsemble(n=n, d=1000, k=50, h_total=40, h_selected=2, h_rest=38, gamma=0.05, p=0.5, q=0.1, num_replications=20)
    accuracy.append(random_ensemble.main())
# Out:
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 7.0710678118654755, mu: 0.01, acc: 0.08
# rho: 7.0710678118654755, mu: 0.1, acc: 0.07600000000000001
# rho: 7.0710678118654755, mu: 1.0, acc: 0.07600000000000001
# rho: 48.08326112068523, mu: 0.01, acc: 0.08
# rho: 48.08326112068523, mu: 0.1, acc: 0.076
# rho: 48.08326112068523, mu: 1.0, acc: 0.076
# Best rho: 7.0710678118654755, Best mu: 0.01
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 1 3
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 1 3
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 1 3
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 1 3
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 1 3
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 1 3
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# Synthetic dataset 8: Running Lasso_Sklearn model
# Synthetic dataset 9: Running GFL_Matlab model
# Synthetic dataset 9: Running Lasso model
# Synthetic dataset 9: Running Proximal model
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# Synthetic dataset 9: Running Lasso_Sklearn model
# Synthetic dataset 10: Running GFL_Matlab model
# Synthetic dataset 10: Running Lasso model
# Synthetic dataset 10: Running Proximal model
# 1 3
# Synthetic dataset 10: Running Lasso_Sklearn model
# Synthetic dataset 11: Running GFL_Matlab model
# Synthetic dataset 11: Running Lasso model
# Synthetic dataset 11: Running Proximal model
# 1 3
# Synthetic dataset 11: Running Lasso_Sklearn model
# Synthetic dataset 12: Running GFL_Matlab model
# Synthetic dataset 12: Running Lasso model
# Synthetic dataset 12: Running Proximal model
# 2 4
# Synthetic dataset 12: Running Lasso_Sklearn model
# Synthetic dataset 13: Running GFL_Matlab model
# Synthetic dataset 13: Running Lasso model
# Synthetic dataset 13: Running Proximal model
# 1 3
# 1 3
# 1 3
# 1 3
# 1 3
# 1 3
# 1 3
# 1 3
# 1 3
# Synthetic dataset 13: Running Lasso_Sklearn model
# Synthetic dataset 14: Running GFL_Matlab model
# Synthetic dataset 14: Running Lasso model
# Synthetic dataset 14: Running Proximal model
# 1 3
# Synthetic dataset 14: Running Lasso_Sklearn model
# Synthetic dataset 15: Running GFL_Matlab model
# Synthetic dataset 15: Running Lasso model
# Synthetic dataset 15: Running Proximal model
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# 3 5
# 2 4
# 2 4
# 2 4
# Synthetic dataset 15: Running Lasso_Sklearn model
# Synthetic dataset 16: Running GFL_Matlab model
# Synthetic dataset 16: Running Lasso model
# Synthetic dataset 16: Running Proximal model
# 1 3
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# 3 5
# 3 5
# 3 5
# 3 5
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 1 3
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 1 3
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 3 5
# 3 5
# 3 5
# 3 5
# 3 5
# 3 5
# 3 5
# 3 5
# 3 5
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.171, Std. Accuracy: 0.048774993593028795
# Model: Lasso, Avg. Accuracy: 0.16300000000000003, Std. Accuracy: 0.048280430818293245
# Model: Proximal, Avg. Accuracy: 0.005, Std. Accuracy: 0.010723805294763609
# Model: Lasso_Sklearn, Avg. Accuracy: 0.12900000000000003, Std. Accuracy: 0.05195190083144216
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 10.0, mu: 0.01, acc: 0.22000000000000003
# rho: 10.0, mu: 0.1, acc: 0.20800000000000002
# rho: 10.0, mu: 1.0, acc: 0.20400000000000001
# rho: 68.0, mu: 0.01, acc: 0.20800000000000002
# rho: 68.0, mu: 0.1, acc: 0.20800000000000002
# rho: 68.0, mu: 1.0, acc: 0.19999999999999998
# Best rho: 10.0, Best mu: 0.01
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 13 15
# 13 15
# 13 15
# 13 15
# 13 15
# 13 15
# 13 15
# 13 15
# 13 15
# 13 15
# 11 13
# 10 12
# 11 13
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 11 13
# 11 13
# 11 13
# 11 13
# 11 13
# 11 13
# 11 13
# 11 13
# 11 13
# 11 13
# 7 9
# 7 9
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 12 14
# 12 14
# 12 14
# 12 14
# 12 14
# 12 14
# 12 14
# 12 14
# 12 14
# 8 10
# 8 10
# 8 10
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 9 11
# 9 11
# 9 11
# 9 11
# 9 11
# 9 11
# 9 11
# 9 11
# 9 11
# 6 8
# 6 8
# 6 8
# 6 8
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 7 9
# 7 9
# 7 9
# 7 9
# 7 9
# 7 9
# 7 9
# 7 9
# 7 9
# 7 9
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 16 18
# 18 20
# 15 17
# 15 17
# 15 17
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 16 18
# 16 18
# 16 18
# 16 18
# 16 18
# 16 18
# 16 18
# 16 18
# 16 18
# 13 15
# 10 12
# 10 12
# 10 12
# Synthetic dataset 8: Running Lasso_Sklearn model
# Synthetic dataset 9: Running GFL_Matlab model
# Synthetic dataset 9: Running Lasso model
# Synthetic dataset 9: Running Proximal model
# 15 17
# 15 17
# 15 17
# 15 17
# 15 17
# 15 17
# 15 17
# 15 17
# 15 17
# 11 13
# 10 12
# 9 11
# 10 12
# Synthetic dataset 9: Running Lasso_Sklearn model
# Synthetic dataset 10: Running GFL_Matlab model
# Synthetic dataset 10: Running Lasso model
# Synthetic dataset 10: Running Proximal model
# 18 20
# 18 20
# 18 20
# 18 20
# 18 20
# 18 20
# 18 20
# 18 20
# 18 20
# 16 18
# 14 16
# 13 15
# 13 15
# Synthetic dataset 10: Running Lasso_Sklearn model
# Synthetic dataset 11: Running GFL_Matlab model
# Synthetic dataset 11: Running Lasso model
# Synthetic dataset 11: Running Proximal model
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 16 18
# 15 17
# 15 17
# 14 16
# Synthetic dataset 11: Running Lasso_Sklearn model
# Synthetic dataset 12: Running GFL_Matlab model
# Synthetic dataset 12: Running Lasso model
# Synthetic dataset 12: Running Proximal model
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# Synthetic dataset 12: Running Lasso_Sklearn model
# Synthetic dataset 13: Running GFL_Matlab model
# Synthetic dataset 13: Running Lasso model
# Synthetic dataset 13: Running Proximal model
# 8 10
# 8 10
# 8 10
# 8 10
# 8 10
# 8 10
# 8 10
# 8 10
# 8 10
# 7 9
# 6 8
# 5 7
# Synthetic dataset 13: Running Lasso_Sklearn model
# Synthetic dataset 14: Running GFL_Matlab model
# Synthetic dataset 14: Running Lasso model
# Synthetic dataset 14: Running Proximal model
# 6 8
# 6 8
# 6 8
# 6 8
# 6 8
# 6 8
# 6 8
# 6 8
# 6 8
# 5 7
# 5 7
# 5 7
# Synthetic dataset 14: Running Lasso_Sklearn model
# Synthetic dataset 15: Running GFL_Matlab model
# Synthetic dataset 15: Running Lasso model
# Synthetic dataset 15: Running Proximal model
# 19 21
# 19 21
# 19 21
# 19 21
# 19 21
# 19 21
# 19 21
# 19 21
# 19 21
# 15 17
# 12 14
# 11 13
# 10 12
# Synthetic dataset 15: Running Lasso_Sklearn model
# Synthetic dataset 16: Running GFL_Matlab model
# Synthetic dataset 16: Running Lasso model
# Synthetic dataset 16: Running Proximal model
# 14 16
# 14 16
# 14 16
# 14 16
# 14 16
# 14 16
# 14 16
# 14 16
# 14 16
# 11 13
# 8 10
# 5 7
# 5 7
# 5 7
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 22 24
# 22 24
# 22 24
# 22 24
# 22 24
# 22 24
# 22 24
# 22 24
# 22 24
# 14 16
# 10 12
# 10 12
# 11 13
# 11 13
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 5 7
# 5 7
# 5 7
# 5 7
# 5 7
# 5 7
# 5 7
# 5 7
# 4 6
# 4 6
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 9 11
# 9 11
# 9 11
# 9 11
# 9 11
# 9 11
# 9 11
# 9 11
# 9 11
# 8 10
# 9 11
# 8 10
# 7 9
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 12 14
# 12 14
# 12 14
# 12 14
# 12 14
# 12 14
# 12 14
# 12 14
# 12 14
# 10 12
# 8 10
# 7 9
# 7 9
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.2860000000000001, Std. Accuracy: 0.04862098312457287
# Model: Lasso, Avg. Accuracy: 0.248, Std. Accuracy: 0.0577581163127746
# Model: Proximal, Avg. Accuracy: 0.06800000000000002, Std. Accuracy: 0.04308131845707603
# Model: Lasso_Sklearn, Avg. Accuracy: 0.251, Std. Accuracy: 0.06556675987114202
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 12.24744871391589, mu: 0.01, acc: 0.43600000000000005
# rho: 12.24744871391589, mu: 0.1, acc: 0.41200000000000003
# rho: 12.24744871391589, mu: 1.0, acc: 0.384
# rho: 83.28265125462805, mu: 0.01, acc: 0.42400000000000004
# rho: 83.28265125462805, mu: 0.1, acc: 0.4
# rho: 83.28265125462805, mu: 1.0, acc: 0.388
# Best rho: 12.24744871391589, Best mu: 0.01
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 68 70
# 68 70
# 68 70
# 68 70
# 68 70
# 68 70
# 68 70
# 68 70
# 68 70
# 68 70
# 44 46
# 39 41
# 34 36
# 31 33
# 26 28
# 25 27
# 25 27
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 17 19
# 18 20
# 15 17
# 13 15
# 14 16
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 42 44
# 29 31
# 27 29
# 26 28
# 24 26
# 25 27
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 32 34
# 26 28
# 25 27
# 24 26
# 23 25
# 22 24
# 22 24
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 63 65
# 63 65
# 63 65
# 63 65
# 63 65
# 63 65
# 63 65
# 63 65
# 63 65
# 63 65
# 49 51
# 43 45
# 39 41
# 37 39
# 36 38
# 35 37
# 34 36
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 53 55
# 53 55
# 53 55
# 53 55
# 53 55
# 53 55
# 53 55
# 53 55
# 53 55
# 53 55
# 37 39
# 32 34
# 29 31
# 23 25
# 22 24
# 22 24
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 48 50
# 48 50
# 48 50
# 48 50
# 48 50
# 48 50
# 48 50
# 48 50
# 48 50
# 48 50
# 35 37
# 31 33
# 27 29
# 26 28
# 25 27
# 23 25
# 25 27
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 33 35
# 33 35
# 33 35
# 33 35
# 33 35
# 33 35
# 33 35
# 33 35
# 33 35
# 33 35
# 26 28
# 22 24
# 18 20
# 17 19
# 16 18
# 15 17
# Synthetic dataset 8: Running Lasso_Sklearn model
# Synthetic dataset 9: Running GFL_Matlab model
# Synthetic dataset 9: Running Lasso model
# Synthetic dataset 9: Running Proximal model
# 57 59
# 57 59
# 57 59
# 57 59
# 57 59
# 57 59
# 57 59
# 57 59
# 57 59
# 57 59
# 39 41
# 27 29
# 24 26
# 23 25
# 24 26
# 23 25
# Synthetic dataset 9: Running Lasso_Sklearn model
# Synthetic dataset 10: Running GFL_Matlab model
# Synthetic dataset 10: Running Lasso model
# Synthetic dataset 10: Running Proximal model
# 46 48
# 46 48
# 46 48
# 46 48
# 46 48
# 46 48
# 46 48
# 46 48
# 46 48
# 46 48
# 31 33
# 28 30
# 26 28
# 26 28
# 25 27
# 24 26
# Synthetic dataset 10: Running Lasso_Sklearn model
# Synthetic dataset 11: Running GFL_Matlab model
# Synthetic dataset 11: Running Lasso model
# Synthetic dataset 11: Running Proximal model
# 35 37
# 35 37
# 35 37
# 35 37
# 35 37
# 35 37
# 35 37
# 35 37
# 35 37
# 35 37
# 24 26
# 23 25
# 21 23
# 18 20
# 15 17
# 14 16
# Synthetic dataset 11: Running Lasso_Sklearn model
# Synthetic dataset 12: Running GFL_Matlab model
# Synthetic dataset 12: Running Lasso model
# Synthetic dataset 12: Running Proximal model
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 37 39
# 28 30
# 25 27
# 22 24
# 21 23
# 21 23
# 17 19
# Synthetic dataset 12: Running Lasso_Sklearn model
# Synthetic dataset 13: Running GFL_Matlab model
# Synthetic dataset 13: Running Lasso model
# Synthetic dataset 13: Running Proximal model
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 40 42
# 36 38
# 34 36
# 32 34
# 30 32
# 30 32
# 29 31
# Synthetic dataset 13: Running Lasso_Sklearn model
# Synthetic dataset 14: Running GFL_Matlab model
# Synthetic dataset 14: Running Lasso model
# Synthetic dataset 14: Running Proximal model
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 53 55
# 44 46
# 32 34
# 31 33
# 28 30
# 27 29
# 27 29
# Synthetic dataset 14: Running Lasso_Sklearn model
# Synthetic dataset 15: Running GFL_Matlab model
# Synthetic dataset 15: Running Lasso model
# Synthetic dataset 15: Running Proximal model
# 27 29
# 27 29
# 27 29
# 27 29
# 27 29
# 27 29
# 27 29
# 27 29
# 27 29
# 27 29
# 25 27
# 18 20
# 18 20
# 16 18
# 17 19
# Synthetic dataset 15: Running Lasso_Sklearn model
# Synthetic dataset 16: Running GFL_Matlab model
# Synthetic dataset 16: Running Lasso model
# Synthetic dataset 16: Running Proximal model
# 43 45
# 43 45
# 43 45
# 43 45
# 43 45
# 43 45
# 43 45
# 43 45
# 43 45
# 43 45
# 33 35
# 28 30
# 23 25
# 19 21
# 20 22
# 16 18
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 20 22
# 20 22
# 20 22
# 20 22
# 20 22
# 20 22
# 20 22
# 20 22
# 20 22
# 14 16
# 10 12
# 10 12
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 42 44
# 42 44
# 42 44
# 42 44
# 42 44
# 42 44
# 42 44
# 42 44
# 42 44
# 42 44
# 31 33
# 26 28
# 25 27
# 23 25
# 22 24
# 23 25
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 47 49
# 47 49
# 47 49
# 47 49
# 47 49
# 47 49
# 47 49
# 47 49
# 47 49
# 47 49
# 33 35
# 27 29
# 26 28
# 24 26
# 25 27
# 23 25
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 33 35
# 28 30
# 25 27
# 22 24
# 23 25
# 21 23
# 19 21
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.449, Std. Accuracy: 0.06556675987114204
# Model: Lasso, Avg. Accuracy: 0.44299999999999995, Std. Accuracy: 0.09844287683728062
# Model: Proximal, Avg. Accuracy: 0.252, Std. Accuracy: 0.08182909018191513
# Model: Lasso_Sklearn, Avg. Accuracy: 0.41400000000000003, Std. Accuracy: 0.06421837743200928
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 14.142135623730951, mu: 0.01, acc: 0.492
# rho: 14.142135623730951, mu: 0.1, acc: 0.44799999999999995
# rho: 14.142135623730951, mu: 1.0, acc: 0.41600000000000004
# rho: 96.16652224137046, mu: 0.01, acc: 0.44400000000000006
# rho: 96.16652224137046, mu: 0.1, acc: 0.40800000000000003
# rho: 96.16652224137046, mu: 1.0, acc: 0.388
# Best rho: 14.142135623730951, Best mu: 0.01
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 96 98
# 96 98
# 96 98
# 96 98
# 96 98
# 96 98
# 96 98
# 96 98
# 96 98
# 96 98
# 96 98
# 83 85
# 67 69
# 58 60
# 53 55
# 49 51
# 44 46
# 44 46
# 42 44
# 43 45
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 107 109
# 107 109
# 107 109
# 107 109
# 107 109
# 107 109
# 107 109
# 107 109
# 107 109
# 107 109
# 107 109
# 77 79
# 66 68
# 52 54
# 48 50
# 44 46
# 42 44
# 40 42
# 39 41
# 39 41
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 105 107
# 105 107
# 105 107
# 105 107
# 105 107
# 105 107
# 105 107
# 105 107
# 105 107
# 105 107
# 105 107
# 84 86
# 70 72
# 59 61
# 50 52
# 46 48
# 44 46
# 42 44
# 43 45
# 41 43
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 93 95
# 93 95
# 93 95
# 93 95
# 93 95
# 93 95
# 93 95
# 93 95
# 93 95
# 93 95
# 93 95
# 73 75
# 67 69
# 55 57
# 48 50
# 43 45
# 40 42
# 38 40
# 33 35
# 31 33
# 30 32
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 98 100
# 98 100
# 98 100
# 98 100
# 98 100
# 98 100
# 98 100
# 98 100
# 98 100
# 98 100
# 98 100
# 82 84
# 63 65
# 54 56
# 50 52
# 46 48
# 42 44
# 42 44
# 41 43
# 36 38
# 35 37
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 39 41
# 34 36
# 28 30
# 28 30
# 25 27
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 87 89
# 69 71
# 62 64
# 55 57
# 51 53
# 51 53
# 51 53
# 47 49
# 46 48
# 44 46
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 54 56
# 54 56
# 54 56
# 54 56
# 54 56
# 54 56
# 54 56
# 54 56
# 54 56
# 54 56
# 31 33
# 28 30
# 24 26
# 20 22
# 19 21
# 18 20
# Synthetic dataset 8: Running Lasso_Sklearn model
# Synthetic dataset 9: Running GFL_Matlab model
# Synthetic dataset 9: Running Lasso model
# Synthetic dataset 9: Running Proximal model
# 133 135
# 133 135
# 133 135
# 133 135
# 133 135
# 133 135
# 133 135
# 133 135
# 133 135
# 133 135
# 133 135
# 89 91
# 69 71
# 55 57
# 47 49
# 44 46
# 38 40
# 39 41
# 37 39
# 37 39
# Synthetic dataset 9: Running Lasso_Sklearn model
# Synthetic dataset 10: Running GFL_Matlab model
# Synthetic dataset 10: Running Lasso model
# Synthetic dataset 10: Running Proximal model
# 54 56
# 54 56
# 54 56
# 54 56
# 54 56
# 54 56
# 54 56
# 54 56
# 54 56
# 54 56
# 39 41
# 35 37
# 30 32
# 30 32
# 27 29
# Synthetic dataset 10: Running Lasso_Sklearn model
# Synthetic dataset 11: Running GFL_Matlab model
# Synthetic dataset 11: Running Lasso model
# Synthetic dataset 11: Running Proximal model
# 88 90
# 88 90
# 88 90
# 88 90
# 88 90
# 88 90
# 88 90
# 88 90
# 88 90
# 88 90
# 88 90
# 70 72
# 60 62
# 46 48
# 41 43
# 37 39
# 36 38
# 33 35
# 32 34
# Synthetic dataset 11: Running Lasso_Sklearn model
# Synthetic dataset 12: Running GFL_Matlab model
# Synthetic dataset 12: Running Lasso model
# Synthetic dataset 12: Running Proximal model
# 113 115
# 113 115
# 113 115
# 113 115
# 113 115
# 113 115
# 113 115
# 113 115
# 113 115
# 113 115
# 113 115
# 81 83
# 69 71
# 50 52
# 42 44
# 41 43
# 36 38
# 32 34
# 32 34
# Synthetic dataset 12: Running Lasso_Sklearn model
# Synthetic dataset 13: Running GFL_Matlab model
# Synthetic dataset 13: Running Lasso model
# Synthetic dataset 13: Running Proximal model
# 97 99
# 97 99
# 97 99
# 97 99
# 97 99
# 97 99
# 97 99
# 97 99
# 97 99
# 97 99
# 97 99
# 79 81
# 69 71
# 66 68
# 65 67
# 54 56
# 48 50
# 47 49
# 48 50
# 44 46
# Synthetic dataset 13: Running Lasso_Sklearn model
# Synthetic dataset 14: Running GFL_Matlab model
# Synthetic dataset 14: Running Lasso model
# Synthetic dataset 14: Running Proximal model
# 115 117
# 115 117
# 115 117
# 115 117
# 115 117
# 115 117
# 115 117
# 115 117
# 115 117
# 115 117
# 115 117
# 95 97
# 77 79
# 68 70
# 55 57
# 51 53
# 50 52
# 48 50
# 43 45
# 43 45
# Synthetic dataset 14: Running Lasso_Sklearn model
# Synthetic dataset 15: Running GFL_Matlab model
# Synthetic dataset 15: Running Lasso model
# Synthetic dataset 15: Running Proximal model
# 102 104
# 102 104
# 102 104
# 102 104
# 102 104
# 102 104
# 102 104
# 102 104
# 102 104
# 102 104
# 102 104
# 75 77
# 57 59
# 47 49
# 42 44
# 38 40
# 36 38
# 36 38
# 35 37
# 32 34
# 31 33
# Synthetic dataset 15: Running Lasso_Sklearn model
# Synthetic dataset 16: Running GFL_Matlab model
# Synthetic dataset 16: Running Lasso model
# Synthetic dataset 16: Running Proximal model
# 112 114
# 112 114
# 112 114
# 112 114
# 112 114
# 112 114
# 112 114
# 112 114
# 112 114
# 112 114
# 112 114
# 79 81
# 70 72
# 60 62
# 50 52
# 50 52
# 50 52
# 46 48
# 44 46
# 40 42
# 40 42
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 109 111
# 109 111
# 109 111
# 109 111
# 109 111
# 109 111
# 109 111
# 109 111
# 109 111
# 109 111
# 109 111
# 81 83
# 66 68
# 51 53
# 48 50
# 43 45
# 43 45
# 41 43
# 40 42
# 37 39
# 36 38
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 81 83
# 81 83
# 81 83
# 81 83
# 81 83
# 81 83
# 81 83
# 81 83
# 81 83
# 81 83
# 45 47
# 36 38
# 30 32
# 31 33
# 30 32
# 28 30
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 37 39
# 36 38
# 31 33
# 29 31
# 30 32
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 86 88
# 86 88
# 86 88
# 86 88
# 86 88
# 86 88
# 86 88
# 86 88
# 86 88
# 86 88
# 86 88
# 68 70
# 57 59
# 51 53
# 47 49
# 35 37
# 39 41
# 40 42
# 37 39
# 34 36
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.5940000000000001, Std. Accuracy: 0.05102940328869231
# Model: Lasso, Avg. Accuracy: 0.7619999999999999, Std. Accuracy: 0.1489832205317095
# Model: Proximal, Avg. Accuracy: 0.434, Std. Accuracy: 0.10547037498748167
# Model: Lasso_Sklearn, Avg. Accuracy: 0.5090000000000001, Std. Accuracy: 0.07911384202527394
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 15.811388300841896, mu: 0.01, acc: 0.48
# rho: 15.811388300841896, mu: 0.1, acc: 0.46399999999999997
# rho: 15.811388300841896, mu: 1.0, acc: 0.44000000000000006
# rho: 107.51744044572489, mu: 0.01, acc: 0.476
# rho: 107.51744044572489, mu: 0.1, acc: 0.42399999999999993
# rho: 107.51744044572489, mu: 1.0, acc: 0.40800000000000003
# Best rho: 15.811388300841896, Best mu: 0.01
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 81 83
# 70 72
# 57 59
# 49 51
# 49 51
# 49 51
# 50 52
# 45 47
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 163 165
# 163 165
# 163 165
# 163 165
# 163 165
# 163 165
# 163 165
# 163 165
# 163 165
# 163 165
# 163 165
# 114 116
# 86 88
# 72 74
# 61 63
# 58 60
# 53 55
# 48 50
# 51 53
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 150 152
# 150 152
# 150 152
# 150 152
# 150 152
# 150 152
# 150 152
# 150 152
# 150 152
# 150 152
# 150 152
# 103 105
# 97 99
# 77 79
# 67 69
# 60 62
# 57 59
# 55 57
# 56 58
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 223 225
# 223 225
# 223 225
# 223 225
# 223 225
# 223 225
# 223 225
# 223 225
# 223 225
# 223 225
# 223 225
# 124 126
# 87 89
# 70 72
# 63 65
# 56 58
# 52 54
# 50 52
# 49 51
# 46 48
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 160 162
# 160 162
# 160 162
# 160 162
# 160 162
# 160 162
# 160 162
# 160 162
# 160 162
# 160 162
# 160 162
# 104 106
# 94 96
# 76 78
# 63 65
# 60 62
# 51 53
# 47 49
# 48 50
# 45 47
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 145 147
# 145 147
# 145 147
# 145 147
# 145 147
# 145 147
# 145 147
# 145 147
# 145 147
# 145 147
# 145 147
# 92 94
# 80 82
# 65 67
# 64 66
# 60 62
# 57 59
# 58 60
# 57 59
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 133 135
# 133 135
# 133 135
# 133 135
# 133 135
# 133 135
# 133 135
# 133 135
# 133 135
# 133 135
# 133 135
# 104 106
# 77 79
# 67 69
# 61 63
# 52 54
# 53 55
# 48 50
# 48 50
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 153 155
# 153 155
# 153 155
# 153 155
# 153 155
# 153 155
# 153 155
# 153 155
# 153 155
# 153 155
# 153 155
# 112 114
# 82 84
# 70 72
# 63 65
# 60 62
# 59 61
# 55 57
# 52 54
# 54 56
# Synthetic dataset 8: Running Lasso_Sklearn model
# Synthetic dataset 9: Running GFL_Matlab model
# Synthetic dataset 9: Running Lasso model
# Synthetic dataset 9: Running Proximal model
# 127 129
# 127 129
# 127 129
# 127 129
# 127 129
# 127 129
# 127 129
# 127 129
# 127 129
# 127 129
# 127 129
# 92 94
# 72 74
# 57 59
# 51 53
# 45 47
# 42 44
# 42 44
# 37 39
# 39 41
# Synthetic dataset 9: Running Lasso_Sklearn model
# Synthetic dataset 10: Running GFL_Matlab model
# Synthetic dataset 10: Running Lasso model
# Synthetic dataset 10: Running Proximal model
# 124 126
# 124 126
# 124 126
# 124 126
# 124 126
# 124 126
# 124 126
# 124 126
# 124 126
# 124 126
# 124 126
# 92 94
# 73 75
# 62 64
# 60 62
# 58 60
# 51 53
# 48 50
# 47 49
# Synthetic dataset 10: Running Lasso_Sklearn model
# Synthetic dataset 11: Running GFL_Matlab model
# Synthetic dataset 11: Running Lasso model
# Synthetic dataset 11: Running Proximal model
# 121 123
# 121 123
# 121 123
# 121 123
# 121 123
# 121 123
# 121 123
# 121 123
# 121 123
# 121 123
# 121 123
# 88 90
# 78 80
# 77 79
# 67 69
# 59 61
# 55 57
# 51 53
# 45 47
# Synthetic dataset 11: Running Lasso_Sklearn model
# Synthetic dataset 12: Running GFL_Matlab model
# Synthetic dataset 12: Running Lasso model
# Synthetic dataset 12: Running Proximal model
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 114 116
# 92 94
# 72 74
# 66 68
# 55 57
# 54 56
# 50 52
# 49 51
# 47 49
# Synthetic dataset 12: Running Lasso_Sklearn model
# Synthetic dataset 13: Running GFL_Matlab model
# Synthetic dataset 13: Running Lasso model
# Synthetic dataset 13: Running Proximal model
# 147 149
# 147 149
# 147 149
# 147 149
# 147 149
# 147 149
# 147 149
# 147 149
# 147 149
# 147 149
# 147 149
# 106 108
# 88 90
# 70 72
# 62 64
# 56 58
# 52 54
# 50 52
# 46 48
# 48 50
# Synthetic dataset 13: Running Lasso_Sklearn model
# Synthetic dataset 14: Running GFL_Matlab model
# Synthetic dataset 14: Running Lasso model
# Synthetic dataset 14: Running Proximal model
# 153 155
# 153 155
# 153 155
# 153 155
# 153 155
# 153 155
# 153 155
# 153 155
# 153 155
# 153 155
# 153 155
# 104 106
# 85 87
# 64 66
# 67 69
# 68 70
# 56 58
# 61 63
# 57 59
# 55 57
# Synthetic dataset 14: Running Lasso_Sklearn model
# Synthetic dataset 15: Running GFL_Matlab model
# Synthetic dataset 15: Running Lasso model
# Synthetic dataset 15: Running Proximal model
# 218 220
# 218 220
# 218 220
# 218 220
# 218 220
# 218 220
# 218 220
# 218 220
# 218 220
# 218 220
# 218 220
# 127 129
# 101 103
# 77 79
# 66 68
# 52 54
# 53 55
# 54 56
# 51 53
# 51 53
# Synthetic dataset 15: Running Lasso_Sklearn model
# Synthetic dataset 16: Running GFL_Matlab model
# Synthetic dataset 16: Running Lasso model
# Synthetic dataset 16: Running Proximal model
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 94 96
# 80 82
# 64 66
# 58 60
# 53 55
# 49 51
# 48 50
# 45 47
# 44 46
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 126 128
# 126 128
# 126 128
# 126 128
# 126 128
# 126 128
# 126 128
# 126 128
# 126 128
# 126 128
# 126 128
# 94 96
# 73 75
# 63 65
# 59 61
# 57 59
# 52 54
# 49 51
# 49 51
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 112 114
# 112 114
# 112 114
# 112 114
# 112 114
# 112 114
# 112 114
# 112 114
# 112 114
# 112 114
# 112 114
# 84 86
# 67 69
# 62 64
# 54 56
# 52 54
# 49 51
# 44 46
# 39 41
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 147 149
# 147 149
# 147 149
# 147 149
# 147 149
# 147 149
# 147 149
# 147 149
# 147 149
# 147 149
# 147 149
# 110 112
# 80 82
# 72 74
# 60 62
# 57 59
# 57 59
# 53 55
# 51 53
# 51 53
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 141 143
# 141 143
# 141 143
# 141 143
# 141 143
# 141 143
# 141 143
# 141 143
# 141 143
# 141 143
# 141 143
# 101 103
# 71 73
# 65 67
# 59 61
# 52 54
# 54 56
# 50 52
# 48 50
# 43 45
# 41 43
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.778, Std. Accuracy: 0.060630025564896474
# Model: Lasso, Avg. Accuracy: 1.0, Std. Accuracy: 0.0
# Model: Proximal, Avg. Accuracy: 0.694, Std. Accuracy: 0.07158212067269312
# Model: Lasso_Sklearn, Avg. Accuracy: 0.6050000000000001, Std. Accuracy: 0.07345066371381541
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 17.320508075688775, mu: 0.01, acc: 0.8039999999999999
# rho: 17.320508075688775, mu: 0.1, acc: 0.728
# rho: 17.320508075688775, mu: 1.0, acc: 0.6639999999999999
# rho: 117.77945491468367, mu: 0.01, acc: 0.744
# rho: 117.77945491468367, mu: 0.1, acc: 0.656
# rho: 117.77945491468367, mu: 1.0, acc: 0.596
# Best rho: 17.320508075688775, Best mu: 0.01
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 220 222
# 220 222
# 220 222
# 220 222
# 220 222
# 220 222
# 220 222
# 220 222
# 220 222
# 220 222
# 220 222
# 122 124
# 108 110
# 102 104
# 80 82
# 72 74
# 68 70
# 64 66
# 59 61
# 60 62
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 192 194
# 192 194
# 192 194
# 192 194
# 192 194
# 192 194
# 192 194
# 192 194
# 192 194
# 192 194
# 192 194
# 111 113
# 101 103
# 82 84
# 67 69
# 66 68
# 58 60
# 53 55
# 49 51
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 275 277
# 275 277
# 275 277
# 275 277
# 275 277
# 275 277
# 275 277
# 275 277
# 275 277
# 275 277
# 275 277
# 275 277
# 213 215
# 170 172
# 143 145
# 111 113
# 89 91
# 76 78
# 67 69
# 62 64
# 57 59
# 51 53
# 50 52
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 144 146
# 144 146
# 144 146
# 144 146
# 144 146
# 144 146
# 144 146
# 144 146
# 144 146
# 144 146
# 144 146
# 112 114
# 90 92
# 77 79
# 69 71
# 62 64
# 61 63
# 62 64
# 61 63
# 55 57
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 169 171
# 169 171
# 169 171
# 169 171
# 169 171
# 169 171
# 169 171
# 169 171
# 169 171
# 169 171
# 169 171
# 107 109
# 94 96
# 80 82
# 71 73
# 63 65
# 57 59
# 54 56
# 51 53
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 191 193
# 191 193
# 191 193
# 191 193
# 191 193
# 191 193
# 191 193
# 191 193
# 191 193
# 191 193
# 191 193
# 116 118
# 90 92
# 71 73
# 60 62
# 59 61
# 53 55
# 53 55
# 54 56
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 294 296
# 294 296
# 294 296
# 294 296
# 294 296
# 294 296
# 294 296
# 294 296
# 294 296
# 294 296
# 294 296
# 294 296
# 238 240
# 185 187
# 153 155
# 115 117
# 89 91
# 70 72
# 60 62
# 56 58
# 54 56
# 50 52
# 50 52
# 48 50
# 45 47
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 127 129
# 106 108
# 78 80
# 66 68
# 66 68
# 60 62
# 59 61
# 57 59
# Synthetic dataset 8: Running Lasso_Sklearn model
# Synthetic dataset 9: Running GFL_Matlab model
# Synthetic dataset 9: Running Lasso model
# Synthetic dataset 9: Running Proximal model
# 230 232
# 230 232
# 230 232
# 230 232
# 230 232
# 230 232
# 230 232
# 230 232
# 230 232
# 230 232
# 230 232
# 119 121
# 99 101
# 74 76
# 69 71
# 61 63
# 57 59
# 56 58
# 56 58
# Synthetic dataset 9: Running Lasso_Sklearn model
# Synthetic dataset 10: Running GFL_Matlab model
# Synthetic dataset 10: Running Lasso model
# Synthetic dataset 10: Running Proximal model
# 178 180
# 178 180
# 178 180
# 178 180
# 178 180
# 178 180
# 178 180
# 178 180
# 178 180
# 178 180
# 178 180
# 111 113
# 86 88
# 72 74
# 63 65
# 63 65
# 58 60
# 55 57
# 51 53
# Synthetic dataset 10: Running Lasso_Sklearn model
# Synthetic dataset 11: Running GFL_Matlab model
# Synthetic dataset 11: Running Lasso model
# Synthetic dataset 11: Running Proximal model
# 213 215
# 213 215
# 213 215
# 213 215
# 213 215
# 213 215
# 213 215
# 213 215
# 213 215
# 213 215
# 213 215
# 128 130
# 111 113
# 76 78
# 67 69
# 59 61
# 58 60
# 49 51
# 54 56
# Synthetic dataset 11: Running Lasso_Sklearn model
# Synthetic dataset 12: Running GFL_Matlab model
# Synthetic dataset 12: Running Lasso model
# Synthetic dataset 12: Running Proximal model
# 228 230
# 228 230
# 228 230
# 228 230
# 228 230
# 228 230
# 228 230
# 228 230
# 228 230
# 228 230
# 228 230
# 130 132
# 99 101
# 83 85
# 79 81
# 61 63
# 57 59
# 56 58
# 55 57
# Synthetic dataset 12: Running Lasso_Sklearn model
# Synthetic dataset 13: Running GFL_Matlab model
# Synthetic dataset 13: Running Lasso model
# Synthetic dataset 13: Running Proximal model
# 168 170
# 168 170
# 168 170
# 168 170
# 168 170
# 168 170
# 168 170
# 168 170
# 168 170
# 168 170
# 168 170
# 103 105
# 83 85
# 73 75
# 66 68
# 62 64
# 60 62
# 59 61
# 56 58
# Synthetic dataset 13: Running Lasso_Sklearn model
# Synthetic dataset 14: Running GFL_Matlab model
# Synthetic dataset 14: Running Lasso model
# Synthetic dataset 14: Running Proximal model
# 179 181
# 179 181
# 179 181
# 179 181
# 179 181
# 179 181
# 179 181
# 179 181
# 179 181
# 179 181
# 179 181
# 123 125
# 102 104
# 82 84
# 70 72
# 64 66
# 63 65
# 59 61
# 54 56
# 54 56
# Synthetic dataset 14: Running Lasso_Sklearn model
# Synthetic dataset 15: Running GFL_Matlab model
# Synthetic dataset 15: Running Lasso model
# Synthetic dataset 15: Running Proximal model
# 174 176
# 174 176
# 174 176
# 174 176
# 174 176
# 174 176
# 174 176
# 174 176
# 174 176
# 174 176
# 174 176
# 118 120
# 90 92
# 77 79
# 69 71
# 63 65
# 64 66
# 64 66
# 63 65
# 57 59
# Synthetic dataset 15: Running Lasso_Sklearn model
# Synthetic dataset 16: Running GFL_Matlab model
# Synthetic dataset 16: Running Lasso model
# Synthetic dataset 16: Running Proximal model
# 214 216
# 214 216
# 214 216
# 214 216
# 214 216
# 214 216
# 214 216
# 214 216
# 214 216
# 214 216
# 214 216
# 119 121
# 101 103
# 84 86
# 76 78
# 68 70
# 70 72
# 64 66
# 64 66
# 61 63
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 210 212
# 210 212
# 210 212
# 210 212
# 210 212
# 210 212
# 210 212
# 210 212
# 210 212
# 210 212
# 210 212
# 125 127
# 96 98
# 79 81
# 66 68
# 60 62
# 59 61
# 56 58
# 55 57
# 54 56
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 195 197
# 195 197
# 195 197
# 195 197
# 195 197
# 195 197
# 195 197
# 195 197
# 195 197
# 195 197
# 195 197
# 127 129
# 92 94
# 69 71
# 55 57
# 56 58
# 52 54
# 53 55
# 46 48
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 212 214
# 212 214
# 212 214
# 212 214
# 212 214
# 212 214
# 212 214
# 212 214
# 212 214
# 212 214
# 212 214
# 115 117
# 91 93
# 73 75
# 66 68
# 60 62
# 61 63
# 59 61
# 55 57
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 216 218
# 216 218
# 216 218
# 216 218
# 216 218
# 216 218
# 216 218
# 216 218
# 216 218
# 216 218
# 216 218
# 112 114
# 91 93
# 86 88
# 76 78
# 64 66
# 59 61
# 54 56
# 52 54
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.899, Std. Accuracy: 0.05233545643251809
# Model: Lasso, Avg. Accuracy: 1.0, Std. Accuracy: 0.0
# Model: Proximal, Avg. Accuracy: 0.8480000000000001, Std. Accuracy: 0.07138627319029898
# Model: Lasso_Sklearn, Avg. Accuracy: 0.6809999999999999, Std. Accuracy: 0.07654410493303845
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 18.708286933869708, mu: 0.01, acc: 0.9
# rho: 18.708286933869708, mu: 0.1, acc: 0.7799999999999999
# rho: 18.708286933869708, mu: 1.0, acc: 0.684
# rho: 127.21635115031401, mu: 0.01, acc: 0.7959999999999999
# rho: 127.21635115031401, mu: 0.1, acc: 0.7
# rho: 127.21635115031401, mu: 1.0, acc: 0.628
# Best rho: 18.708286933869708, Best mu: 0.01
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 215 217
# 215 217
# 215 217
# 215 217
# 215 217
# 215 217
# 215 217
# 215 217
# 215 217
# 215 217
# 215 217
# 125 127
# 102 104
# 79 81
# 69 71
# 61 63
# 55 57
# 55 57
# 49 51
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 233 235
# 233 235
# 233 235
# 233 235
# 233 235
# 233 235
# 233 235
# 233 235
# 233 235
# 233 235
# 233 235
# 121 123
# 91 93
# 83 85
# 71 73
# 65 67
# 65 67
# 65 67
# 63 65
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 203 205
# 203 205
# 203 205
# 203 205
# 203 205
# 203 205
# 203 205
# 203 205
# 203 205
# 203 205
# 203 205
# 203 205
# 181 183
# 133 135
# 120 122
# 96 98
# 89 91
# 75 77
# 73 75
# 67 69
# 62 64
# 60 62
# 58 60
# 60 62
# 60 62
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 229 231
# 229 231
# 229 231
# 229 231
# 229 231
# 229 231
# 229 231
# 229 231
# 229 231
# 229 231
# 229 231
# 114 116
# 89 91
# 78 80
# 72 74
# 64 66
# 64 66
# 57 59
# 55 57
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 290 292
# 290 292
# 290 292
# 290 292
# 290 292
# 290 292
# 290 292
# 290 292
# 290 292
# 290 292
# 290 292
# 290 292
# 220 222
# 173 175
# 137 139
# 107 109
# 92 94
# 79 81
# 74 76
# 66 68
# 65 67
# 63 65
# 62 64
# 55 57
# 58 60
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 225 227
# 225 227
# 225 227
# 225 227
# 225 227
# 225 227
# 225 227
# 225 227
# 225 227
# 225 227
# 225 227
# 127 129
# 96 98
# 88 90
# 72 74
# 71 73
# 63 65
# 64 66
# 63 65
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 200 202
# 200 202
# 200 202
# 200 202
# 200 202
# 200 202
# 200 202
# 200 202
# 200 202
# 200 202
# 200 202
# 110 112
# 90 92
# 72 74
# 69 71
# 61 63
# 52 54
# 55 57
# 54 56
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 250 252
# 250 252
# 250 252
# 250 252
# 250 252
# 250 252
# 250 252
# 250 252
# 250 252
# 250 252
# 250 252
# 250 252
# 190 192
# 143 145
# 113 115
# 103 105
# 92 94
# 84 86
# 79 81
# 74 76
# 66 68
# 64 66
# 62 64
# 60 62
# 59 61
# Synthetic dataset 8: Running Lasso_Sklearn model
# Synthetic dataset 9: Running GFL_Matlab model
# Synthetic dataset 9: Running Lasso model
# Synthetic dataset 9: Running Proximal model
# 247 249
# 247 249
# 247 249
# 247 249
# 247 249
# 247 249
# 247 249
# 247 249
# 247 249
# 247 249
# 247 249
# 247 249
# 199 201
# 142 144
# 120 122
# 101 103
# 86 88
# 76 78
# 64 66
# 62 64
# 58 60
# 57 59
# 56 58
# 56 58
# Synthetic dataset 9: Running Lasso_Sklearn model
# Synthetic dataset 10: Running GFL_Matlab model
# Synthetic dataset 10: Running Lasso model
# Synthetic dataset 10: Running Proximal model
# 246 248
# 246 248
# 246 248
# 246 248
# 246 248
# 246 248
# 246 248
# 246 248
# 246 248
# 246 248
# 246 248
# 246 248
# 205 207
# 173 175
# 142 144
# 109 111
# 91 93
# 78 80
# 72 74
# 68 70
# 61 63
# 61 63
# 60 62
# 56 58
# 54 56
# Synthetic dataset 10: Running Lasso_Sklearn model
# Synthetic dataset 11: Running GFL_Matlab model
# Synthetic dataset 11: Running Lasso model
# Synthetic dataset 11: Running Proximal model
# 314 316
# 314 316
# 314 316
# 314 316
# 314 316
# 314 316
# 314 316
# 314 316
# 314 316
# 314 316
# 314 316
# 314 316
# 221 223
# 170 172
# 134 136
# 110 112
# 85 87
# 72 74
# 64 66
# 60 62
# 57 59
# 55 57
# 57 59
# 55 57
# 55 57
# Synthetic dataset 11: Running Lasso_Sklearn model
# Synthetic dataset 12: Running GFL_Matlab model
# Synthetic dataset 12: Running Lasso model
# Synthetic dataset 12: Running Proximal model
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 235 237
# 192 194
# 144 146
# 119 121
# 97 99
# 78 80
# 69 71
# 67 69
# 65 67
# 64 66
# 62 64
# 62 64
# 60 62
# 59 61
# Synthetic dataset 12: Running Lasso_Sklearn model
# Synthetic dataset 13: Running GFL_Matlab model
# Synthetic dataset 13: Running Lasso model
# Synthetic dataset 13: Running Proximal model
# 280 282
# 280 282
# 280 282
# 280 282
# 280 282
# 280 282
# 280 282
# 280 282
# 280 282
# 280 282
# 280 282
# 280 282
# 221 223
# 181 183
# 126 128
# 106 108
# 93 95
# 76 78
# 70 72
# 66 68
# 62 64
# 62 64
# 60 62
# 56 58
# 59 61
# Synthetic dataset 13: Running Lasso_Sklearn model
# Synthetic dataset 14: Running GFL_Matlab model
# Synthetic dataset 14: Running Lasso model
# Synthetic dataset 14: Running Proximal model
# 248 250
# 248 250
# 248 250
# 248 250
# 248 250
# 248 250
# 248 250
# 248 250
# 248 250
# 248 250
# 248 250
# 248 250
# 195 197
# 160 162
# 119 121
# 101 103
# 93 95
# 75 77
# 68 70
# 62 64
# 59 61
# 59 61
# 54 56
# 55 57
# 52 54
# 55 57
# Synthetic dataset 14: Running Lasso_Sklearn model
# Synthetic dataset 15: Running GFL_Matlab model
# Synthetic dataset 15: Running Lasso model
# Synthetic dataset 15: Running Proximal model
# 293 295
# 293 295
# 293 295
# 293 295
# 293 295
# 293 295
# 293 295
# 293 295
# 293 295
# 293 295
# 293 295
# 293 295
# 232 234
# 189 191
# 135 137
# 118 120
# 100 102
# 86 88
# 79 81
# 70 72
# 71 73
# 69 71
# 63 65
# 62 64
# 63 65
# Synthetic dataset 15: Running Lasso_Sklearn model
# Synthetic dataset 16: Running GFL_Matlab model
# Synthetic dataset 16: Running Lasso model
# Synthetic dataset 16: Running Proximal model
# 289 291
# 289 291
# 289 291
# 289 291
# 289 291
# 289 291
# 289 291
# 289 291
# 289 291
# 289 291
# 289 291
# 289 291
# 224 226
# 157 159
# 137 139
# 107 109
# 88 90
# 70 72
# 64 66
# 56 58
# 55 57
# 55 57
# 55 57
# 55 57
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 245 247
# 245 247
# 245 247
# 245 247
# 245 247
# 245 247
# 245 247
# 245 247
# 245 247
# 245 247
# 245 247
# 245 247
# 208 210
# 169 171
# 140 142
# 117 119
# 104 106
# 95 97
# 83 85
# 80 82
# 70 72
# 70 72
# 65 67
# 62 64
# 64 66
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 251 253
# 251 253
# 251 253
# 251 253
# 251 253
# 251 253
# 251 253
# 251 253
# 251 253
# 251 253
# 251 253
# 251 253
# 200 202
# 163 165
# 129 131
# 110 112
# 90 92
# 76 78
# 68 70
# 59 61
# 59 61
# 58 60
# 57 59
# 53 55
# 52 54
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 258 260
# 258 260
# 258 260
# 258 260
# 258 260
# 258 260
# 258 260
# 258 260
# 258 260
# 258 260
# 258 260
# 258 260
# 242 244
# 182 184
# 138 140
# 117 119
# 98 100
# 81 83
# 71 73
# 68 70
# 66 68
# 64 66
# 62 64
# 59 61
# 59 61
# 55 57
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 226 228
# 177 179
# 134 136
# 107 109
# 86 88
# 69 71
# 66 68
# 58 60
# 56 58
# 53 55
# 50 52
# 52 54
# 53 55
# 54 56
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.9780000000000001, Std. Accuracy: 0.03400000000000001
# Model: Lasso, Avg. Accuracy: 1.0, Std. Accuracy: 0.0
# Model: Proximal, Avg. Accuracy: 0.951, Std. Accuracy: 0.05078385570237849
# Model: Lasso_Sklearn, Avg. Accuracy: 0.7020000000000001, Std. Accuracy: 0.07453858061433688
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 20.0, mu: 0.01, acc: 0.9800000000000001
# rho: 20.0, mu: 0.1, acc: 0.8879999999999999
# rho: 20.0, mu: 1.0, acc: 0.808
# rho: 136.0, mu: 0.01, acc: 0.908
# rho: 136.0, mu: 0.1, acc: 0.8039999999999999
# rho: 136.0, mu: 1.0, acc: 0.724
# Best rho: 20.0, Best mu: 0.01
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 324 326
# 324 326
# 324 326
# 324 326
# 324 326
# 324 326
# 324 326
# 324 326
# 324 326
# 324 326
# 324 326
# 324 326
#
Avg. Accuracy: 1.0, Std. Accuracy: 0.0
# Model: Proximal, Avg. Accuracy: 0.993, Std. Accuracy: 0.009539392014169465
# Model: Lasso_Sklearn, Avg. Accuracy: 0.7859999999999999, Std. Accuracy: 0.07186097689288673
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 21.213203435596427, mu: 0.01, acc: 0.976
# rho: 21.213203435596427, mu: 0.1, acc: 0.86
# rho: 21.213203435596427, mu: 1.0, acc: 0.792
# rho: 144.2497833620557, mu: 0.01, acc: 0.8959999999999999
# rho: 144.2497833620557, mu: 0.1, acc: 0.772
# rho: 144.2497833620557, mu: 1.0, acc: 0.7
# Best rho: 21.213203435596427, Best mu: 0.01
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 295 297
# 295 297
# 295 297
# 295 297
# 295 297
# 295 297
# 295 297
# 295 297
# 295 297
# 295 297
# 295 297
# 295 297
# 196 198
# 163 165
# 134 136
# 105 107
# 87 89
# 73 75
# 63 65
# 64 66
# 57 59
# 55 57
# 51 53
# 48 50
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 392 394
# 392 394
# 392 394
# 392 394
# 392 394
# 392 394
# 392 394
# 392 394
# 392 394
# 392 394
# 392 394
# 392 394
# 286 288
# 193 195
# 150 152
# 109 111
# 79 81
# 63 65
# 51 53
# 46 48
# 45 47
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 319 321
# 319 321
# 319 321
# 319 321
# 319 321
# 319 321
# 319 321
# 319 321
# 319 321
# 319 321
# 319 321
# 319 321
# 254 256
# 171 173
# 123 125
# 99 101
# 77 79
# 72 74
# 69 71
# 62 64
# 58 60
# 52 54
# 48 50
# 50 52
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 381 383
# 381 383
# 381 383
# 381 383
# 381 383
# 381 383
# 381 383
# 381 383
# 381 383
# 381 383
# 381 383
# 381 383
# 295 297
# 215 217
# 162 164
# 120 122
# 92 94
# 73 75
# 64 66
# 58 60
# 50 52
# 52 54
# 48 50
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 341 343
# 341 343
# 341 343
# 341 343
# 341 343
# 341 343
# 341 343
# 341 343
# 341 343
# 341 343
# 341 343
# 341 343
# 275 277
# 194 196
# 137 139
# 118 120
# 94 96
# 74 76
# 66 68
# 58 60
# 50 52
# 50 52
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 309 311
# 309 311
# 309 311
# 309 311
# 309 311
# 309 311
# 309 311
# 309 311
# 309 311
# 309 311
# 309 311
# 309 311
# 226 228
# 159 161
# 107 109
# 92 94
# 83 85
# 73 75
# 66 68
# 63 65
# 59 61
# 55 57
# 54 56
# 55 57
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 324 326
# 324 326
# 324 326
# 324 326
# 324 326
# 324 326
# 324 326
# 324 326
# 324 326
# 324 326
# 324 326
# 324 326
# 250 252
# 197 199
# 141 143
# 100 102
# 89 91
# 70 72
# 66 68
# 61 63
# 56 58
# 53 55
# 50 52
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 352 354
# 352 354
# 352 354
# 352 354
# 352 354
# 352 354
# 352 354
# 352 354
# 352 354
# 352 354
# 352 354
# 352 354
# 250 252
# 177 179
# 132 134
# 96 98
# 75 77
# 64 66
# 60 62
# 54 56
# 52 54
# 52 54
# 48 50
# 47 49
# Synthetic dataset 8: Running Lasso_Sklearn model
# Synthetic dataset 9: Running GFL_Matlab model
# Synthetic dataset 9: Running Lasso model
# Synthetic dataset 9: Running Proximal model
# 327 329
# 327 329
# 327 329
# 327 329
# 327 329
# 327 329
# 327 329
# 327 329
# 327 329
# 327 329
# 327 329
# 327 329
# 248 250
# 192 194
# 126 128
# 105 107
# 86 88
# 73 75
# 66 68
# 61 63
# 59 61
# 56 58
# 52 54
# 51 53
# Synthetic dataset 9: Running Lasso_Sklearn model
# Synthetic dataset 10: Running GFL_Matlab model
# Synthetic dataset 10: Running Lasso model
# Synthetic dataset 10: Running Proximal model
# 335 337
# 335 337
# 335 337
# 335 337
# 335 337
# 335 337
# 335 337
# 335 337
# 335 337
# 335 337
# 335 337
# 335 337
# 257 259
# 190 192
# 137 139
# 113 115
# 89 91
# 79 81
# 61 63
# 55 57
# 46 48
# 44 46
# 44 46
# Synthetic dataset 10: Running Lasso_Sklearn model
# Synthetic dataset 11: Running GFL_Matlab model
# Synthetic dataset 11: Running Lasso model
# Synthetic dataset 11: Running Proximal model
# 346 348
# 346 348
# 346 348
# 346 348
# 346 348
# 346 348
# 346 348
# 346 348
# 346 348
# 346 348
# 346 348
# 346 348
# 230 232
# 185 187
# 134 136
# 102 104
# 87 89
# 63 65
# 56 58
# 56 58
# 51 53
# 50 52
# Synthetic dataset 11: Running Lasso_Sklearn model
# Synthetic dataset 12: Running GFL_Matlab model
# Synthetic dataset 12: Running Lasso model
# Synthetic dataset 12: Running Proximal model
# 334 336
# 334 336
# 334 336
# 334 336
# 334 336
# 334 336
# 334 336
# 334 336
# 334 336
# 334 336
# 334 336
# 334 336
# 249 251
# 179 181
# 139 141
# 104 106
# 82 84
# 70 72
# 62 64
# 54 56
# 52 54
# 48 50
# 46 48
# Synthetic dataset 12: Running Lasso_Sklearn model
# Synthetic dataset 13: Running GFL_Matlab model
# Synthetic dataset 13: Running Lasso model
# Synthetic dataset 13: Running Proximal model
# 337 339
# 337 339
# 337 339
# 337 339
# 337 339
# 337 339
# 337 339
# 337 339
# 337 339
# 337 339
# 337 339
# 337 339
# 272 274
# 185 187
# 133 135
# 107 109
# 87 89
# 68 70
# 60 62
# 53 55
# 52 54
# 47 49
# 49 51
# Synthetic dataset 13: Running Lasso_Sklearn model
# Synthetic dataset 14: Running GFL_Matlab model
# Synthetic dataset 14: Running Lasso model
# Synthetic dataset 14: Running Proximal model
# 330 332
# 330 332
# 330 332
# 330 332
# 330 332
# 330 332
# 330 332
# 330 332
# 330 332
# 330 332
# 330 332
# 330 332
# 249 251
# 190 192
# 150 152
# 123 125
# 101 103
# 81 83
# 68 70
# 61 63
# 60 62
# 57 59
# 58 60
# 55 57
# Synthetic dataset 14: Running Lasso_Sklearn model
# Synthetic dataset 15: Running GFL_Matlab model
# Synthetic dataset 15: Running Lasso model
# Synthetic dataset 15: Running Proximal model
# 318 320
# 318 320
# 318 320
# 318 320
# 318 320
# 318 320
# 318 320
# 318 320
# 318 320
# 318 320
# 318 320
# 318 320
# 225 227
# 184 186
# 150 152
# 124 126
# 90 92
# 79 81
# 73 75
# 67 69
# 63 65
# 62 64
# 61 63
# 61 63
# Synthetic dataset 15: Running Lasso_Sklearn model
# Synthetic dataset 16: Running GFL_Matlab model
# Synthetic dataset 16: Running Lasso model
# Synthetic dataset 16: Running Proximal model
# 338 340
# 338 340
# 338 340
# 338 340
# 338 340
# 338 340
# 338 340
# 338 340
# 338 340
# 338 340
# 338 340
# 338 340
# 250 252
# 174 176
# 127 129
# 89 91
# 71 73
# 68 70
# 59 61
# 51 53
# 48 50
# 50 52
# 50 52
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 348 350
# 348 350
# 348 350
# 348 350
# 348 350
# 348 350
# 348 350
# 348 350
# 348 350
# 348 350
# 348 350
# 348 350
# 257 259
# 185 187
# 152 154
# 118 120
# 92 94
# 79 81
# 70 72
# 61 63
# 58 60
# 55 57
# 57 59
# 55 57
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 302 304
# 302 304
# 302 304
# 302 304
# 302 304
# 302 304
# 302 304
# 302 304
# 302 304
# 302 304
# 302 304
# 302 304
# 241 243
# 187 189
# 140 142
# 107 109
# 90 92
# 76 78
# 64 66
# 58 60
# 52 54
# 51 53
# 47 49
# 40 42
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 292 294
# 292 294
# 292 294
# 292 294
# 292 294
# 292 294
# 292 294
# 292 294
# 292 294
# 292 294
# 292 294
# 292 294
# 218 220
# 176 178
# 139 141
# 109 111
# 86 88
# 76 78
# 65 67
# 61 63
# 58 60
# 53 55
# 49 51
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 339 341
# 339 341
# 339 341
# 339 341
# 339 341
# 339 341
# 339 341
# 339 341
# 339 341
# 339 341
# 339 341
# 339 341
# 280 282
# 196 198
# 144 146
# 116 118
# 95 97
# 77 79
# 66 68
# 60 62
# 55 57
# 49 51
# 48 50
# 43 45
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 1.0, Std. Accuracy: 0.0
# Model: Lasso, Avg. Accuracy: 1.0, Std. Accuracy: 0.0
# Model: Proximal, Avg. Accuracy: 0.9969999999999999, Std. Accuracy: 0.009539392014169467
# Model: Lasso_Sklearn, Avg. Accuracy: 0.776, Std. Accuracy: 0.072

# %% [markdown]
# 1. correlation: lasso (todo)
# 2. q: proximal
# 3. gamma: lasso, our method
# 4. same cluster, almost same weights (fair), negative weights(not fair),
# q = 0.01
# q = 0.1

# %%
acc_1 = []
acc_2 = []
std_1 = []
std_2 = []
acc_3 = []
std_3 = []


# Extract means and standard deviations for three models:
for i in range(len(accuracy)):
    acc_1.append(np.mean(accuracy[i]["GFL_Matlab"]))
    std_1.append(np.std(accuracy[i]["GFL_Matlab"]))
    acc_2.append(np.mean(accuracy[i]["Proximal"]))
    std_2.append(np.std(accuracy[i]["Proximal"]))
    acc_3.append(np.mean(accuracy[i]["Lasso"]))
    std_3.append(np.std(accuracy[i]["Lasso"]))

# Plot the results
plt.figure(figsize=(8, 6))
plt.errorbar(sample_sizes, acc_1, yerr=std_1, fmt='o-', label='GFL_Matlab', capsize=5)
plt.errorbar(sample_sizes, acc_2, yerr=std_2, fmt='o-', label='Proximal', capsize=5)
plt.errorbar(sample_sizes, acc_3, yerr=std_3, fmt='o-', label='Lasso', capsize=5)
plt.xlabel('Sample Size')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Sample Size')
plt.legend()

plt.show()

# %%
sample_sizes = np.arange(50, 250, 50)
accuracy = []
for n in sample_sizes:
    random_ensemble = RandomEnsemble(n=n, d=1000, k=50, 
                                     h_total=10, h_selected=2, h_rest=8, 
                                     gamma=0.5, p=0.95, q=0.02, 
                                     num_replications=20)
    accuracy.append(random_ensemble.main())
# Out:
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 7.0710678118654755, mu: 0.01, acc: 0.504
# rho: 7.0710678118654755, mu: 0.1, acc: 0.54
# rho: 7.0710678118654755, mu: 1.0, acc: 0.548
# rho: 48.08326112068523, mu: 0.01, acc: 0.488
# rho: 48.08326112068523, mu: 0.1, acc: 0.54
# rho: 48.08326112068523, mu: 1.0, acc: 0.556
# Best rho: 48.08326112068523, Best mu: 1.0
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 28 30
# 28 30
# 28 30
# 28 30
# 28 30
# 28 30
# 28 30
# 28 30
# 28 30
# 23 25
# 21 23
# 20 22
# 20 22
# 17 19
# 17 19
# 13 15
# 12 14
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 20 22
# 15 17
# 12 14
# 11 13
# 10 12
# 10 12
# 10 12
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 14 16
# 14 16
# 14 16
# 14 16
# 14 16
# 14 16
# 14 16
# 14 16
# 13 15
# 12 14
# 10 12
# 10 12
# 10 12
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 31 33
# 31 33
# 31 33
# 31 33
# 31 33
# 31 33
# 31 33
# 31 33
# 31 33
# 25 27
# 25 27
# 21 23
# 20 22
# 18 20
# 15 17
# 15 17
# 13 15
# 14 16
# 13 15
# 12 14
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 21 23
# 24 26
# 22 24
# 22 24
# 20 22
# 16 18
# 14 16
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 22 24
# 22 24
# 22 24
# 22 24
# 22 24
# 22 24
# 22 24
# 22 24
# 13 15
# 12 14
# 12 14
# 9 11
# 9 11
# 9 11
# 9 11
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 31 33
# 31 33
# 31 33
# 31 33
# 31 33
# 31 33
# 31 33
# 31 33
# 23 25
# 24 26
# 18 20
# 18 20
# 17 19
# 16 18
# 15 17
# 16 18
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 48 50
# 48 50
# 48 50
# 48 50
# 48 50
# 48 50
# 48 50
# 48 50
# 48 50
# 31 33
# 24 26
# 21 23
# 16 18
# 15 17
# 13 15
# 12 14
# 12 14
# 13 15
# Synthetic dataset 8: Running Lasso_Sklearn model
# Synthetic dataset 9: Running GFL_Matlab model
# Synthetic dataset 9: Running Lasso model
# Synthetic dataset 9: Running Proximal model
# 34 36
# 34 36
# 34 36
# 34 36
# 34 36
# 34 36
# 34 36
# 34 36
# 34 36
# 33 35
# 29 31
# 23 25
# 18 20
# 15 17
# 14 16
# 13 15
# 14 16
# 13 15
# 14 16
# 13 15
# Synthetic dataset 9: Running Lasso_Sklearn model
# Synthetic dataset 10: Running GFL_Matlab model
# Synthetic dataset 10: Running Lasso model
# Synthetic dataset 10: Running Proximal model
# 41 43
# 41 43
# 41 43
# 41 43
# 41 43
# 41 43
# 41 43
# 41 43
# 41 43
# 31 33
# 27 29
# 26 28
# 25 27
# 23 25
# 19 21
# 19 21
# 21 23
# 17 19
# 21 23
# 20 22
# 21 23
# Synthetic dataset 10: Running Lasso_Sklearn model
# Synthetic dataset 11: Running GFL_Matlab model
# Synthetic dataset 11: Running Lasso model
# Synthetic dataset 11: Running Proximal model
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 24 26
# 19 21
# 17 19
# 15 17
# 17 19
# 16 18
# 14 16
# 13 15
# Synthetic dataset 11: Running Lasso_Sklearn model
# Synthetic dataset 12: Running GFL_Matlab model
# Synthetic dataset 12: Running Lasso model
# Synthetic dataset 12: Running Proximal model
# 19 21
# 19 21
# 19 21
# 19 21
# 19 21
# 19 21
# 19 21
# 19 21
# 15 17
# 13 15
# 13 15
# 12 14
# 12 14
# 12 14
# Synthetic dataset 12: Running Lasso_Sklearn model
# Synthetic dataset 13: Running GFL_Matlab model
# Synthetic dataset 13: Running Lasso model
# Synthetic dataset 13: Running Proximal model
# 6 8
# 6 8
# 6 8
# 6 8
# 6 8
# 6 8
# 6 8
# 6 8
# 6 8
# 6 8
# 6 8
# 6 8
# 6 8
# Synthetic dataset 13: Running Lasso_Sklearn model
# Synthetic dataset 14: Running GFL_Matlab model
# Synthetic dataset 14: Running Lasso model
# Synthetic dataset 14: Running Proximal model
# 44 46
# 44 46
# 44 46
# 44 46
# 44 46
# 44 46
# 44 46
# 44 46
# 44 46
# 34 36
# 26 28
# 27 29
# 22 24
# 19 21
# 19 21
# 16 18
# 17 19
# 16 18
# 17 19
# 16 18
# Synthetic dataset 14: Running Lasso_Sklearn model
# Synthetic dataset 15: Running GFL_Matlab model
# Synthetic dataset 15: Running Lasso model
# Synthetic dataset 15: Running Proximal model
# 19 21
# 19 21
# 19 21
# 19 21
# 19 21
# 19 21
# 19 21
# 19 21
# 13 15
# 13 15
# 12 14
# 10 12
# 10 12
# 10 12
# Synthetic dataset 15: Running Lasso_Sklearn model
# Synthetic dataset 16: Running GFL_Matlab model
# Synthetic dataset 16: Running Lasso model
# Synthetic dataset 16: Running Proximal model
# 20 22
# 20 22
# 20 22
# 20 22
# 20 22
# 20 22
# 20 22
# 20 22
# 20 22
# 21 23
# 17 19
# 16 18
# 13 15
# 13 15
# 14 16
# 14 16
# 13 15
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 26 28
# 26 28
# 26 28
# 26 28
# 26 28
# 26 28
# 26 28
# 26 28
# 17 19
# 17 19
# 16 18
# 16 18
# 15 17
# 15 17
# 16 18
# 16 18
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 14 16
# 14 16
# 14 16
# 14 16
# 14 16
# 14 16
# 14 16
# 14 16
# 10 12
# 9 11
# 7 9
# 7 9
# 7 9
# 7 9
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 21 23
# 21 23
# 21 23
# 21 23
# 21 23
# 21 23
# 21 23
# 21 23
# 21 23
# 22 24
# 20 22
# 17 19
# 14 16
# 14 16
# 14 16
# 14 16
# 13 15
# 13 15
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 18 20
# 18 20
# 18 20
# 18 20
# 18 20
# 18 20
# 18 20
# 18 20
# 14 16
# 11 13
# 10 12
# 11 13
# 12 14
# 12 14
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.4440000000000001, Std. Accuracy: 0.17165080832900265
# Model: Lasso, Avg. Accuracy: 0.13000000000000003, Std. Accuracy: 0.04538722287164087
# Model: Proximal, Avg. Accuracy: 0.49400000000000005, Std. Accuracy: 0.34745359402371995
# Model: Lasso_Sklearn, Avg. Accuracy: 0.09800000000000002, Std. Accuracy: 0.03091924966748062
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 10.0, mu: 0.01, acc: 0.596
# rho: 10.0, mu: 0.1, acc: 0.6479999999999999
# rho: 10.0, mu: 1.0, acc: 0.6719999999999999
# rho: 68.0, mu: 0.01, acc: 0.5720000000000001
# rho: 68.0, mu: 0.1, acc: 0.632
# rho: 68.0, mu: 1.0, acc: 0.664
# Best rho: 10.0, Best mu: 1.0
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 65 67
# 64 66
# 59 61
# 59 61
# 52 54
# 51 53
# 48 50
# 48 50
# 54 56
# 48 50
# 44 46
# 43 45
# 37 39
# 38 40
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 46 48
# 34 36
# 34 36
# 28 30
# 28 30
# 31 33
# 27 29
# 27 29
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 61 63
# 61 63
# 61 63
# 61 63
# 61 63
# 61 63
# 61 63
# 61 63
# 61 63
# 41 43
# 29 31
# 22 24
# 20 22
# 15 17
# 17 19
# 18 20
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 62 64
# 62 64
# 62 64
# 62 64
# 62 64
# 62 64
# 62 64
# 62 64
# 62 64
# 40 42
# 32 34
# 31 33
# 26 28
# 25 27
# 23 25
# 24 26
# 25 27
# 23 25
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 77 79
# 77 79
# 77 79
# 77 79
# 77 79
# 77 79
# 77 79
# 77 79
# 77 79
# 77 79
# 62 64
# 52 54
# 50 52
# 44 46
# 35 37
# 34 36
# 28 30
# 25 27
# 21 23
# 22 24
# 21 23
# 20 22
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 44 46
# 44 46
# 44 46
# 44 46
# 44 46
# 44 46
# 44 46
# 44 46
# 44 46
# 41 43
# 34 36
# 27 29
# 25 27
# 25 27
# 20 22
# 18 20
# 17 19
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 43 45
# 43 45
# 43 45
# 43 45
# 43 45
# 43 45
# 43 45
# 43 45
# 43 45
# 32 34
# 37 39
# 34 36
# 24 26
# 23 25
# 26 28
# 27 29
# 23 25
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 74 76
# 74 76
# 74 76
# 74 76
# 74 76
# 74 76
# 74 76
# 74 76
# 74 76
# 54 56
# 45 47
# 36 38
# 39 41
# 34 36
# 35 37
# 31 33
# 30 32
# 27 29
# Synthetic dataset 8: Running Lasso_Sklearn model
# Synthetic dataset 9: Running GFL_Matlab model
# Synthetic dataset 9: Running Lasso model
# Synthetic dataset 9: Running Proximal model
# 76 78
# 76 78
# 76 78
# 76 78
# 76 78
# 76 78
# 76 78
# 76 78
# 76 78
# 76 78
# 64 66
# 63 65
# 56 58
# 53 55
# 50 52
# 47 49
# 40 42
# 35 37
# 34 36
# 29 31
# 27 29
# 26 28
# Synthetic dataset 9: Running Lasso_Sklearn model
# Synthetic dataset 10: Running GFL_Matlab model
# Synthetic dataset 10: Running Lasso model
# Synthetic dataset 10: Running Proximal model
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 42 44
# 34 36
# 20 22
# 19 21
# 17 19
# 17 19
# 15 17
# 15 17
# Synthetic dataset 10: Running Lasso_Sklearn model
# Synthetic dataset 11: Running GFL_Matlab model
# Synthetic dataset 11: Running Lasso model
# Synthetic dataset 11: Running Proximal model
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 66 68
# 47 49
# 43 45
# 34 36
# 23 25
# 20 22
# 20 22
# 19 21
# 19 21
# 17 19
# 16 18
# Synthetic dataset 11: Running Lasso_Sklearn model
# Synthetic dataset 12: Running GFL_Matlab model
# Synthetic dataset 12: Running Lasso model
# Synthetic dataset 12: Running Proximal model
# 63 65
# 63 65
# 63 65
# 63 65
# 63 65
# 63 65
# 63 65
# 63 65
# 63 65
# 63 65
# 47 49
# 35 37
# 35 37
# 32 34
# 27 29
# 26 28
# 25 27
# 23 25
# 21 23
# 21 23
# 18 20
# 18 20
# Synthetic dataset 12: Running Lasso_Sklearn model
# Synthetic dataset 13: Running GFL_Matlab model
# Synthetic dataset 13: Running Lasso model
# Synthetic dataset 13: Running Proximal model
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 40 42
# 38 40
# 34 36
# 34 36
# 31 33
# 26 28
# 26 28
# 25 27
# Synthetic dataset 13: Running Lasso_Sklearn model
# Synthetic dataset 14: Running GFL_Matlab model
# Synthetic dataset 14: Running Lasso model
# Synthetic dataset 14: Running Proximal model
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 70 72
# 58 60
# 53 55
# 47 49
# 39 41
# 33 35
# 36 38
# 33 35
# 34 36
# 31 33
# 32 34
# 34 36
# 34 36
# Synthetic dataset 14: Running Lasso_Sklearn model
# Synthetic dataset 15: Running GFL_Matlab model
# Synthetic dataset 15: Running Lasso model
# Synthetic dataset 15: Running Proximal model
# 56 58
# 56 58
# 56 58
# 56 58
# 56 58
# 56 58
# 56 58
# 56 58
# 56 58
# 42 44
# 38 40
# 36 38
# 32 34
# 31 33
# 30 32
# 30 32
# 27 29
# Synthetic dataset 15: Running Lasso_Sklearn model
# Synthetic dataset 16: Running GFL_Matlab model
# Synthetic dataset 16: Running Lasso model
# Synthetic dataset 16: Running Proximal model
# 55 57
# 55 57
# 55 57
# 55 57
# 55 57
# 55 57
# 55 57
# 55 57
# 55 57
# 35 37
# 26 28
# 24 26
# 17 19
# 14 16
# 12 14
# 12 14
# 11 13
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 62 64
# 62 64
# 49 51
# 48 50
# 42 44
# 39 41
# 39 41
# 39 41
# 36 38
# 34 36
# 33 35
# 34 36
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 66 68
# 66 68
# 66 68
# 66 68
# 66 68
# 66 68
# 66 68
# 66 68
# 66 68
# 66 68
# 63 65
# 57 59
# 47 49
# 42 44
# 28 30
# 22 24
# 17 19
# 19 21
# 18 20
# 16 18
# 13 15
# 13 15
# 13 15
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 44 46
# 44 46
# 44 46
# 44 46
# 44 46
# 44 46
# 44 46
# 44 46
# 44 46
# 41 43
# 40 42
# 42 44
# 41 43
# 38 40
# 36 38
# 33 35
# 32 34
# 33 35
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 60 62
# 40 42
# 30 32
# 24 26
# 21 23
# 16 18
# 17 19
# 15 17
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.7310000000000001, Std. Accuracy: 0.0917551088495894
# Model: Lasso, Avg. Accuracy: 0.20500000000000002, Std. Accuracy: 0.04685082710048991
# Model: Proximal, Avg. Accuracy: 0.9550000000000001, Std. Accuracy: 0.03993745109543171
# Model: Lasso_Sklearn, Avg. Accuracy: 0.20900000000000002, Std. Accuracy: 0.04958830507286976
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 12.24744871391589, mu: 0.01, acc: 0.82
# rho: 12.24744871391589, mu: 0.1, acc: 0.8880000000000001
# rho: 12.24744871391589, mu: 1.0, acc: 0.924
# rho: 83.28265125462805, mu: 0.01, acc: 0.8
# rho: 83.28265125462805, mu: 0.1, acc: 0.892
# rho: 83.28265125462805, mu: 1.0, acc: 0.9199999999999999
# Best rho: 12.24744871391589, Best mu: 1.0
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 67 69
# 57 59
# 49 51
# 46 48
# 40 42
# 33 35
# 27 29
# 25 27
# 20 22
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 71 73
# 63 65
# 56 58
# 53 55
# 49 51
# 40 42
# 41 43
# 36 38
# 33 35
# 34 36
# 33 35
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 63 65
# 63 65
# 63 65
# 63 65
# 63 65
# 63 65
# 63 65
# 63 65
# 63 65
# 63 65
# 47 49
# 32 34
# 31 33
# 23 25
# 18 20
# 15 17
# 13 15
# 14 16
# 13 15
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 108 110
# 108 110
# 108 110
# 108 110
# 108 110
# 108 110
# 108 110
# 108 110
# 108 110
# 108 110
# 80 82
# 63 65
# 56 58
# 46 48
# 46 48
# 43 45
# 38 40
# 32 34
# 29 31
# 33 35
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 71 73
# 63 65
# 54 56
# 49 51
# 39 41
# 35 37
# 28 30
# 26 28
# 24 26
# 23 25
# 25 27
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 77 79
# 77 79
# 77 79
# 77 79
# 77 79
# 77 79
# 77 79
# 77 79
# 77 79
# 77 79
# 72 74
# 60 62
# 47 49
# 45 47
# 41 43
# 34 36
# 31 33
# 29 31
# 27 29
# 29 31
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 108 110
# 108 110
# 108 110
# 108 110
# 108 110
# 108 110
# 108 110
# 108 110
# 108 110
# 108 110
# 86 88
# 68 70
# 48 50
# 40 42
# 29 31
# 25 27
# 23 25
# 19 21
# 17 19
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 71 73
# 64 66
# 56 58
# 48 50
# 43 45
# 34 36
# 30 32
# 27 29
# 27 29
# 27 29
# Synthetic dataset 8: Running Lasso_Sklearn model
# Synthetic dataset 9: Running GFL_Matlab model
# Synthetic dataset 9: Running Lasso model
# Synthetic dataset 9: Running Proximal model
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 68 70
# 52 54
# 42 44
# 30 32
# 25 27
# 23 25
# 23 25
# 24 26
# 19 21
# Synthetic dataset 9: Running Lasso_Sklearn model
# Synthetic dataset 10: Running GFL_Matlab model
# Synthetic dataset 10: Running Lasso model
# Synthetic dataset 10: Running Proximal model
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 60 62
# 45 47
# 39 41
# 30 32
# 27 29
# 26 28
# 22 24
# 21 23
# 20 22
# 19 21
# Synthetic dataset 10: Running Lasso_Sklearn model
# Synthetic dataset 11: Running GFL_Matlab model
# Synthetic dataset 11: Running Lasso model
# Synthetic dataset 11: Running Proximal model
# 61 63
# 61 63
# 61 63
# 61 63
# 61 63
# 61 63
# 61 63
# 61 63
# 61 63
# 36 38
# 38 40
# 27 29
# 26 28
# 19 21
# 18 20
# Synthetic dataset 11: Running Lasso_Sklearn model
# Synthetic dataset 12: Running GFL_Matlab model
# Synthetic dataset 12: Running Lasso model
# Synthetic dataset 12: Running Proximal model
# 53 55
# 53 55
# 53 55
# 53 55
# 53 55
# 53 55
# 53 55
# 53 55
# 53 55
# 53 55
# 46 48
# 46 48
# 38 40
# 44 46
# 45 47
# 41 43
# 39 41
# 34 36
# 29 31
# Synthetic dataset 12: Running Lasso_Sklearn model
# Synthetic dataset 13: Running GFL_Matlab model
# Synthetic dataset 13: Running Lasso model
# Synthetic dataset 13: Running Proximal model
# 73 75
# 73 75
# 73 75
# 73 75
# 73 75
# 73 75
# 73 75
# 73 75
# 73 75
# 73 75
# 69 71
# 64 66
# 63 65
# 56 58
# 50 52
# 45 47
# 36 38
# 35 37
# 31 33
# Synthetic dataset 13: Running Lasso_Sklearn model
# Synthetic dataset 14: Running GFL_Matlab model
# Synthetic dataset 14: Running Lasso model
# Synthetic dataset 14: Running Proximal model
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 79 81
# 68 70
# 57 59
# 47 49
# 39 41
# 32 34
# 28 30
# 29 31
# 28 30
# 26 28
# Synthetic dataset 14: Running Lasso_Sklearn model
# Synthetic dataset 15: Running GFL_Matlab model
# Synthetic dataset 15: Running Lasso model
# Synthetic dataset 15: Running Proximal model
# 100 102
# 100 102
# 100 102
# 100 102
# 100 102
# 100 102
# 100 102
# 100 102
# 100 102
# 100 102
# 77 79
# 62 64
# 47 49
# 46 48
# 36 38
# 34 36
# 28 30
# 31 33
# 28 30
# 28 30
# 25 27
# Synthetic dataset 15: Running Lasso_Sklearn model
# Synthetic dataset 16: Running GFL_Matlab model
# Synthetic dataset 16: Running Lasso model
# Synthetic dataset 16: Running Proximal model
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 64 66
# 56 58
# 51 53
# 38 40
# 38 40
# 37 39
# 31 33
# 27 29
# 28 30
# 23 25
# 24 26
# 24 26
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 59 61
# 45 47
# 50 52
# 43 45
# 37 39
# 35 37
# 32 34
# 28 30
# 29 31
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 72 74
# 72 74
# 72 74
# 72 74
# 72 74
# 72 74
# 72 74
# 72 74
# 72 74
# 72 74
# 51 53
# 49 51
# 47 49
# 44 46
# 34 36
# 34 36
# 29 31
# 27 29
# 26 28
# 21 23
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 101 103
# 101 103
# 101 103
# 101 103
# 101 103
# 101 103
# 101 103
# 101 103
# 101 103
# 101 103
# 74 76
# 62 64
# 56 58
# 49 51
# 45 47
# 41 43
# 35 37
# 30 32
# 28 30
# 29 31
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 94 96
# 94 96
# 94 96
# 94 96
# 94 96
# 94 96
# 94 96
# 94 96
# 94 96
# 94 96
# 66 68
# 51 53
# 53 55
# 51 53
# 42 44
# 38 40
# 30 32
# 30 32
# 26 28
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.8949999999999999, Std. Accuracy: 0.05094114250780012
# Model: Lasso, Avg. Accuracy: 0.318, Std. Accuracy: 0.07743384273042377
# Model: Proximal, Avg. Accuracy: 0.982, Std. Accuracy: 0.024413111231467412
# Model: Lasso_Sklearn, Avg. Accuracy: 0.333, Std. Accuracy: 0.05908468498688979
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 14.142135623730951, mu: 0.01, acc: 0.788
# rho: 14.142135623730951, mu: 0.1, acc: 0.8400000000000001
# rho: 14.142135623730951, mu: 1.0, acc: 0.876
# rho: 96.16652224137046, mu: 0.01, acc: 0.772
# rho: 96.16652224137046, mu: 0.1, acc: 0.852
# rho: 96.16652224137046, mu: 1.0, acc: 0.8800000000000001
# Best rho: 96.16652224137046, Best mu: 1.0
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 75 77
# 63 65
# 57 59
# 49 51
# 49 51
# 34 36
# 25 27
# 22 24
# 22 24
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 123 125
# 123 125
# 123 125
# 123 125
# 123 125
# 123 125
# 123 125
# 123 125
# 123 125
# 123 125
# 80 82
# 68 70
# 56 58
# 53 55
# 49 51
# 46 48
# 43 45
# 39 41
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 127 129
# 127 129
# 127 129
# 127 129
# 127 129
# 127 129
# 127 129
# 127 129
# 127 129
# 127 129
# 70 72
# 52 54
# 48 50
# 47 49
# 43 45
# 45 47
# 40 42
# 41 43
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 105 107
# 105 107
# 105 107
# 105 107
# 105 107
# 105 107
# 105 107
# 105 107
# 105 107
# 105 107
# 70 72
# 64 66
# 57 59
# 47 49
# 45 47
# 43 45
# 38 40
# 33 35
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 129 131
# 129 131
# 129 131
# 129 131
# 129 131
# 129 131
# 129 131
# 129 131
# 129 131
# 129 131
# 73 75
# 53 55
# 52 54
# 48 50
# 46 48
# 41 43
# 42 44
# 38 40
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 63 65
# 51 53
# 42 44
# 31 33
# 29 31
# 28 30
# 30 32
# 31 33
# 26 28
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 88 90
# 88 90
# 88 90
# 88 90
# 88 90
# 88 90
# 88 90
# 88 90
# 88 90
# 88 90
# 64 66
# 48 50
# 35 37
# 39 41
# 36 38
# 31 33
# 26 28
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 98 100
# 98 100
# 98 100
# 98 100
# 98 100
# 98 100
# 98 100
# 98 100
# 98 100
# 98 100
# 63 65
# 55 57
# 44 46
# 34 36
# 33 35
# 27 29
# 22 24
# 23 25
# 24 26
# Synthetic dataset 8: Running Lasso_Sklearn model
# Synthetic dataset 9: Running GFL_Matlab model
# Synthetic dataset 9: Running Lasso model
# Synthetic dataset 9: Running Proximal model
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 84 86
# 55 57
# 49 51
# 43 45
# 38 40
# 36 38
# 31 33
# 23 25
# 25 27
# 24 26
# Synthetic dataset 9: Running Lasso_Sklearn model
# Synthetic dataset 10: Running GFL_Matlab model
# Synthetic dataset 10: Running Lasso model
# Synthetic dataset 10: Running Proximal model
# 127 129
# 127 129
# 127 129
# 127 129
# 127 129
# 127 129
# 127 129
# 127 129
# 127 129
# 127 129
# 127 129
# 119 121
# 109 111
# 88 90
# 73 75
# 69 71
# 60 62
# 58 60
# 58 60
# 51 53
# 41 43
# 43 45
# Synthetic dataset 10: Running Lasso_Sklearn model
# Synthetic dataset 11: Running GFL_Matlab model
# Synthetic dataset 11: Running Lasso model
# Synthetic dataset 11: Running Proximal model
# 110 112
# 110 112
# 110 112
# 110 112
# 110 112
# 110 112
# 110 112
# 110 112
# 110 112
# 110 112
# 69 71
# 57 59
# 45 47
# 46 48
# 39 41
# 41 43
# 34 36
# 32 34
# Synthetic dataset 11: Running Lasso_Sklearn model
# Synthetic dataset 12: Running GFL_Matlab model
# Synthetic dataset 12: Running Lasso model
# Synthetic dataset 12: Running Proximal model
# 91 93
# 91 93
# 91 93
# 91 93
# 91 93
# 91 93
# 91 93
# 91 93
# 91 93
# 91 93
# 56 58
# 40 42
# 31 33
# 29 31
# 26 28
# 21 23
# 18 20
# 17 19
# Synthetic dataset 12: Running Lasso_Sklearn model
# Synthetic dataset 13: Running GFL_Matlab model
# Synthetic dataset 13: Running Lasso model
# Synthetic dataset 13: Running Proximal model
# 87 89
# 87 89
# 87 89
# 87 89
# 87 89
# 87 89
# 87 89
# 87 89
# 87 89
# 87 89
# 59 61
# 47 49
# 44 46
# 42 44
# 40 42
# 32 34
# 27 29
# 26 28
# 25 27
# Synthetic dataset 13: Running Lasso_Sklearn model
# Synthetic dataset 14: Running GFL_Matlab model
# Synthetic dataset 14: Running Lasso model
# Synthetic dataset 14: Running Proximal model
# 119 121
# 119 121
# 119 121
# 119 121
# 119 121
# 119 121
# 119 121
# 119 121
# 119 121
# 119 121
# 77 79
# 64 66
# 47 49
# 44 46
# 39 41
# 32 34
# 32 34
# 32 34
# Synthetic dataset 14: Running Lasso_Sklearn model
# Synthetic dataset 15: Running GFL_Matlab model
# Synthetic dataset 15: Running Lasso model
# Synthetic dataset 15: Running Proximal model
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 78 80
# 69 71
# 57 59
# 53 55
# 55 57
# 50 52
# 45 47
# 45 47
# Synthetic dataset 15: Running Lasso_Sklearn model
# Synthetic dataset 16: Running GFL_Matlab model
# Synthetic dataset 16: Running Lasso model
# Synthetic dataset 16: Running Proximal model
# 107 109
# 107 109
# 107 109
# 107 109
# 107 109
# 107 109
# 107 109
# 107 109
# 107 109
# 107 109
# 71 73
# 63 65
# 55 57
# 36 38
# 36 38
# 29 31
# 25 27
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 69 71
# 66 68
# 53 55
# 38 40
# 35 37
# 30 32
# 29 31
# 29 31
# 30 32
# 29 31
# 29 31
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 87 89
# 87 89
# 87 89
# 87 89
# 87 89
# 87 89
# 87 89
# 87 89
# 87 89
# 87 89
# 60 62
# 48 50
# 41 43
# 37 39
# 39 41
# 38 40
# 31 33
# 32 34
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 111 113
# 111 113
# 111 113
# 111 113
# 111 113
# 111 113
# 111 113
# 111 113
# 111 113
# 111 113
# 89 91
# 69 71
# 56 58
# 41 43
# 32 34
# 29 31
# 27 29
# 25 27
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 88 90
# 79 81
# 60 62
# 55 57
# 55 57
# 53 55
# 48 50
# 40 42
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.93, Std. Accuracy: 0.02932575659723034
# Model: Lasso, Avg. Accuracy: 0.40700000000000003, Std. Accuracy: 0.0788098978555359
# Model: Proximal, Avg. Accuracy: 0.999, Std. Accuracy: 0.004358898943540678
# Model: Lasso_Sklearn, Avg. Accuracy: 0.42400000000000004, Std. Accuracy: 0.06343500610861483

# %%
accuracy_1 = []
for n in sample_sizes:
    random_ensemble = RandomEnsemble(n=n, d=1000, k=50, 
                                     h_total=40, h_selected=2, h_rest=38, 
                                     gamma=0.5, p=0.95, q=0.02, 
                                     num_replications=20)
    accuracy_1.append(random_ensemble.main())
# Out:
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 7.0710678118654755, mu: 0.01, acc: 0.10400000000000001
# rho: 7.0710678118654755, mu: 0.1, acc: 0.1
# rho: 7.0710678118654755, mu: 1.0, acc: 0.096
# rho: 48.08326112068523, mu: 0.01, acc: 0.11199999999999999
# rho: 48.08326112068523, mu: 0.1, acc: 0.10800000000000001
# rho: 48.08326112068523, mu: 1.0, acc: 0.10400000000000001
# Best rho: 48.08326112068523, Best mu: 0.01
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 234 236
# 234 236
# 234 236
# 234 236
# 234 236
# 234 236
# 234 236
# 234 236
# 234 236
# 234 236
# 234 236
# 158 160
# 124 126
# 101 103
# 74 76
# 63 65
# 62 64
# 58 60
# 55 57
# 46 48
# 47 49
# 46 48
# 42 44
# 39 41
# 38 40
# 36 38
# 37 39
# 36 38
# 34 36
# 35 37
# 32 34
# 33 35
# 34 36
# 32 34
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 180 182
# 180 182
# 180 182
# 180 182
# 180 182
# 180 182
# 180 182
# 180 182
# 180 182
# 180 182
# 83 85
# 68 70
# 52 54
# 42 44
# 32 34
# 28 30
# 26 28
# 24 26
# 22 24
# 22 24
# 21 23
# 25 27
# 23 25
# 25 27
# 26 28
# 25 27
# 25 27
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 219 221
# 219 221
# 219 221
# 219 221
# 219 221
# 219 221
# 219 221
# 219 221
# 219 221
# 219 221
# 219 221
# 175 177
# 128 130
# 101 103
# 88 90
# 73 75
# 56 58
# 52 54
# 46 48
# 41 43
# 37 39
# 34 36
# 31 33
# 29 31
# 28 30
# 28 30
# 28 30
# 27 29
# 27 29
# 26 28
# 25 27
# 24 26
# 24 26
# 25 27
# 24 26
# 24 26
# 24 26
# 23 25
# 23 25
# 24 26
# 23 25
# 22 24
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 313 315
# 313 315
# 313 315
# 313 315
# 313 315
# 313 315
# 313 315
# 313 315
# 313 315
# 313 315
# 313 315
# 223 225
# 172 174
# 139 141
# 116 118
# 89 91
# 76 78
# 70 72
# 62 64
# 58 60
# 55 57
# 49 51
# 49 51
# 41 43
# 41 43
# 41 43
# 42 44
# 39 41
# 39 41
# 38 40
# 35 37
# 33 35
# 34 36
# 33 35
# 32 34
# 30 32
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 311 313
# 311 313
# 311 313
# 311 313
# 311 313
# 311 313
# 311 313
# 311 313
# 311 313
# 311 313
# 311 313
# 213 215
# 159 161
# 133 135
# 108 110
# 93 95
# 79 81
# 77 79
# 64 66
# 55 57
# 47 49
# 45 47
# 40 42
# 41 43
# 41 43
# 36 38
# 35 37
# 37 39
# 37 39
# 38 40
# 33 35
# 37 39
# 37 39
# 36 38
# 38 40
# 37 39
# 39 41
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 303 305
# 303 305
# 303 305
# 303 305
# 303 305
# 303 305
# 303 305
# 303 305
# 303 305
# 303 305
# 303 305
# 231 233
# 182 184
# 123 125
# 107 109
# 89 91
# 78 80
# 78 80
# 74 76
# 66 68
# 56 58
# 49 51
# 49 51
# 47 49
# 46 48
# 44 46
# 47 49
# 46 48
# 48 50
# 48 50
# 49 51
# 47 49
# 47 49
# 46 48
# 45 47
# 42 44
# 43 45
# 42 44
# 41 43
# 39 41
# 39 41
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 264 266
# 264 266
# 264 266
# 264 266
# 264 266
# 264 266
# 264 266
# 264 266
# 264 266
# 264 266
# 264 266
# 177 179
# 151 153
# 113 115
# 87 89
# 75 77
# 70 72
# 55 57
# 52 54
# 47 49
# 48 50
# 42 44
# 39 41
# 40 42
# 38 40
# 37 39
# 36 38
# 34 36
# 34 36
# 33 35
# 31 33
# 31 33
# 31 33
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 31 33
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 351 353
# 351 353
# 351 353
# 351 353
# 351 353
# 351 353
# 351 353
# 351 353
# 351 353
# 351 353
# 351 353
# 259 261
# 178 180
# 147 149
# 118 120
# 96 98
# 73 75
# 65 67
# 62 64
# 56 58
# 52 54
# 50 52
# 49 51
# 45 47
# 41 43
# 40 42
# 38 40
# 31 33
# 31 33
# 31 33
# 30 32
# 28 30
# 29 31
# 29 31
# 29 31
# 29 31
# 28 30
# 27 29
# Synthetic dataset 8: Running Lasso_Sklearn model
# Synthetic dataset 9: Running GFL_Matlab model
# Synthetic dataset 9: Running Lasso model
# Synthetic dataset 9: Running Proximal model
# 232 234
# 232 234
# 232 234
# 232 234
# 232 234
# 232 234
# 232 234
# 232 234
# 232 234
# 232 234
# 232 234
# 161 163
# 127 129
# 108 110
# 94 96
# 80 82
# 74 76
# 62 64
# 51 53
# 45 47
# 44 46
# 39 41
# 39 41
# 34 36
# 34 36
# 32 34
# 32 34
# 31 33
# 34 36
# 33 35
# 32 34
# 31 33
# 32 34
# 29 31
# 28 30
# 28 30
# Synthetic dataset 9: Running Lasso_Sklearn model
# Synthetic dataset 10: Running GFL_Matlab model
# Synthetic dataset 10: Running Lasso model
# Synthetic dataset 10: Running Proximal model
# 224 226
# 224 226
# 224 226
# 224 226
# 224 226
# 224 226
# 224 226
# 224 226
# 224 226
# 224 226
# 224 226
# 168 170
# 131 133
# 102 104
# 80 82
# 65 67
# 59 61
# 51 53
# 49 51
# 45 47
# 41 43
# 36 38
# 34 36
# 34 36
# 31 33
# 30 32
# 28 30
# 28 30
# 28 30
# 27 29
# 28 30
# 28 30
# 27 29
# 25 27
# 24 26
# 25 27
# 24 26
# Synthetic dataset 10: Running Lasso_Sklearn model
# Synthetic dataset 11: Running GFL_Matlab model
# Synthetic dataset 11: Running Lasso model
# Synthetic dataset 11: Running Proximal model
# 280 282
# 280 282
# 280 282
# 280 282
# 280 282
# 280 282
# 280 282
# 280 282
# 280 282
# 280 282
# 280 282
# 187 189
# 143 145
# 107 109
# 80 82
# 74 76
# 66 68
# 51 53
# 44 46
# 38 40
# 38 40
# 34 36
# 37 39
# 31 33
# 32 34
# 32 34
# 30 32
# 28 30
# 25 27
# 26 28
# 30 32
# 28 30
# 27 29
# 29 31
# 29 31
# Synthetic dataset 11: Running Lasso_Sklearn model
# Synthetic dataset 12: Running GFL_Matlab model
# Synthetic dataset 12: Running Lasso model
# Synthetic dataset 12: Running Proximal model
# 387 389
# 387 389
# 387 389
# 387 389
# 387 389
# 387 389
# 387 389
# 387 389
# 387 389
# 387 389
# 387 389
# 261 263
# 204 206
# 147 149
# 109 111
# 104 106
# 89 91
# 75 77
# 66 68
# 60 62
# 52 54
# 50 52
# 49 51
# 43 45
# 38 40
# 37 39
# 35 37
# 30 32
# 35 37
# 35 37
# 34 36
# 33 35
# 33 35
# Synthetic dataset 12: Running Lasso_Sklearn model
# Synthetic dataset 13: Running GFL_Matlab model
# Synthetic dataset 13: Running Lasso model
# Synthetic dataset 13: Running Proximal model
# 261 263
# 261 263
# 261 263
# 261 263
# 261 263
# 261 263
# 261 263
# 261 263
# 261 263
# 261 263
# 261 263
# 171 173
# 133 135
# 97 99
# 86 88
# 69 71
# 63 65
# 55 57
# 53 55
# 51 53
# 45 47
# 45 47
# 42 44
# 43 45
# 41 43
# 41 43
# 39 41
# 39 41
# 38 40
# 38 40
# 36 38
# 34 36
# 34 36
# 35 37
# 34 36
# 34 36
# Synthetic dataset 13: Running Lasso_Sklearn model
# Synthetic dataset 14: Running GFL_Matlab model
# Synthetic dataset 14: Running Lasso model
# Synthetic dataset 14: Running Proximal model
# 225 227
# 225 227
# 225 227
# 225 227
# 225 227
# 225 227
# 225 227
# 225 227
# 225 227
# 225 227
# 225 227
# 169 171
# 130 132
# 104 106
# 76 78
# 68 70
# 56 58
# 50 52
# 45 47
# 35 37
# 34 36
# 32 34
# 29 31
# 29 31
# 30 32
# 31 33
# 29 31
# 28 30
# 28 30
# 29 31
# 29 31
# 31 33
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 30 32
# 29 31
# 28 30
# Synthetic dataset 14: Running Lasso_Sklearn model
# Synthetic dataset 15: Running GFL_Matlab model
# Synthetic dataset 15: Running Lasso model
# Synthetic dataset 15: Running Proximal model
# 222 224
# 222 224
# 222 224
# 222 224
# 222 224
# 222 224
# 222 224
# 222 224
# 222 224
# 222 224
# 222 224
# 156 158
# 112 114
# 91 93
# 76 78
# 69 71
# 63 65
# 52 54
# 47 49
# 43 45
# 43 45
# 43 45
# 41 43
# 36 38
# 38 40
# 35 37
# 35 37
# 31 33
# 30 32
# Synthetic dataset 15: Running Lasso_Sklearn model
# Synthetic dataset 16: Running GFL_Matlab model
# Synthetic dataset 16: Running Lasso model
# Synthetic dataset 16: Running Proximal model
# 259 261
# 259 261
# 259 261
# 259 261
# 259 261
# 259 261
# 259 261
# 259 261
# 259 261
# 259 261
# 259 261
# 211 213
# 152 154
# 129 131
# 115 117
# 85 87
# 75 77
# 66 68
# 60 62
# 53 55
# 47 49
# 46 48
# 41 43
# 40 42
# 38 40
# 39 41
# 38 40
# 37 39
# 38 40
# 31 33
# 33 35
# 34 36
# 32 34
# 34 36
# 34 36
# 31 33
# 33 35
# 34 36
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 321 323
# 321 323
# 321 323
# 321 323
# 321 323
# 321 323
# 321 323
# 321 323
# 321 323
# 321 323
# 321 323
# 224 226
# 162 164
# 141 143
# 116 118
# 98 100
# 85 87
# 69 71
# 57 59
# 48 50
# 42 44
# 38 40
# 35 37
# 35 37
# 33 35
# 32 34
# 31 33
# 30 32
# 29 31
# 28 30
# 28 30
# 27 29
# 29 31
# 30 32
# 33 35
# 31 33
# 30 32
# 31 33
# 30 32
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 313 315
# 313 315
# 313 315
# 313 315
# 313 315
# 313 315
# 313 315
# 313 315
# 313 315
# 313 315
# 313 315
# 213 215
# 158 160
# 127 129
# 113 115
# 95 97
# 79 81
# 70 72
# 66 68
# 60 62
# 56 58
# 52 54
# 45 47
# 39 41
# 38 40
# 36 38
# 33 35
# 34 36
# 34 36
# 33 35
# 32 34
# 32 34
# 32 34
# 30 32
# 31 33
# 31 33
# 33 35
# 31 33
# 31 33
# 31 33
# 31 33
# 29 31
# 29 31
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 253 255
# 253 255
# 253 255
# 253 255
# 253 255
# 253 255
# 253 255
# 253 255
# 253 255
# 253 255
# 253 255
# 183 185
# 129 131
# 102 104
# 90 92
# 72 74
# 72 74
# 64 66
# 51 53
# 42 44
# 39 41
# 36 38
# 33 35
# 31 33
# 30 32
# 29 31
# 27 29
# 26 28
# 27 29
# 26 28
# 26 28
# 25 27
# 23 25
# 21 23
# 22 24
# 22 24
# 21 23
# 22 24
# 22 24
# 22 24
# 22 24
# 22 24
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 323 325
# 323 325
# 323 325
# 323 325
# 323 325
# 323 325
# 323 325
# 323 325
# 323 325
# 323 325
# 323 325
# 222 224
# 175 177
# 128 130
# 104 106
# 83 85
# 75 77
# 68 70
# 59 61
# 57 59
# 57 59
# 56 58
# 54 56
# 49 51
# 48 50
# 46 48
# 43 45
# 42 44
# 40 42
# 34 36
# 32 34
# 35 37
# 30 32
# 31 33
# 33 35
# 33 35
# 33 35
# 33 35
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.174, Std. Accuracy: 0.07378346698278687
# Model: Lasso, Avg. Accuracy: 0.11600000000000003, Std. Accuracy: 0.05003998401278722
# Model: Proximal, Avg. Accuracy: 0.21500000000000002, Std. Accuracy: 0.18631961786135137
# Model: Lasso_Sklearn, Avg. Accuracy: 0.09200000000000001, Std. Accuracy: 0.037094473981982824
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 10.0, mu: 0.01, acc: 0.29200000000000004
# rho: 10.0, mu: 0.1, acc: 0.31999999999999995
# rho: 10.0, mu: 1.0, acc: 0.31200000000000006
# rho: 68.0, mu: 0.01, acc: 0.26
# rho: 68.0, mu: 0.1, acc: 0.30800000000000005
# rho: 68.0, mu: 1.0, acc: 0.32400000000000007
# Best rho: 68.0, Best mu: 1.0
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 554 556
# 554 556
# 554 556
# 554 556
# 554 556
# 554 556
# 554 556
# 554 556
# 554 556
# 554 556
# 554 556
# 554 556
# 543 545
# 520 522
# 431 433
# 347 349
# 261 263
# 217 219
# 200 202
# 186 188
# 174 176
# 157 159
# 140 142
# 129 131
# 122 124
# 119 121
# 113 115
# 101 103
# 94 96
# 93 95
# 81 83
# 74 76
# 75 77
# 72 74
# 65 67
# 68 70
# 70 72
# 68 70
# 68 70
# 63 65
# 63 65
# 65 67
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 473 475
# 473 475
# 473 475
# 473 475
# 473 475
# 473 475
# 473 475
# 473 475
# 473 475
# 473 475
# 473 475
# 473 475
# 493 495
# 452 454
# 352 354
# 299 301
# 251 253
# 212 214
# 184 186
# 160 162
# 155 157
# 139 141
# 127 129
# 118 120
# 108 110
# 102 104
# 94 96
# 88 90
# 86 88
# 80 82
# 80 82
# 78 80
# 76 78
# 76 78
# 75 77
# 71 73
# 76 78
# 77 79
# 80 82
# 76 78
# 74 76
# 71 73
# 69 71
# 66 68
# 70 72
# 67 69
# 65 67
# 63 65
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 429 431
# 429 431
# 429 431
# 429 431
# 429 431
# 429 431
# 429 431
# 429 431
# 429 431
# 429 431
# 429 431
# 429 431
# 432 434
# 368 370
# 286 288
# 245 247
# 198 200
# 170 172
# 149 151
# 134 136
# 115 117
# 104 106
# 90 92
# 95 97
# 84 86
# 79 81
# 77 79
# 80 82
# 78 80
# 74 76
# 75 77
# 72 74
# 65 67
# 64 66
# 64 66
# 61 63
# 64 66
# 65 67
# 65 67
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 512 514
# 512 514
# 512 514
# 512 514
# 512 514
# 512 514
# 512 514
# 512 514
# 512 514
# 512 514
# 512 514
# 512 514
# 534 536
# 495 497
# 418 420
# 354 356
# 282 284
# 242 244
# 202 204
# 179 181
# 168 170
# 159 161
# 138 140
# 135 137
# 116 118
# 103 105
# 99 101
# 93 95
# 87 89
# 81 83
# 86 88
# 79 81
# 82 84
# 79 81
# 78 80
# 75 77
# 70 72
# 68 70
# 69 71
# 70 72
# 70 72
# 64 66
# 63 65
# 64 66
# 61 63
# 63 65
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 430 432
# 430 432
# 430 432
# 430 432
# 430 432
# 430 432
# 430 432
# 430 432
# 430 432
# 430 432
# 430 432
# 338 340
# 256 258
# 203 205
# 163 165
# 140 142
# 124 126
# 105 107
# 96 98
# 82 84
# 77 79
# 76 78
# 72 74
# 74 76
# 75 77
# 74 76
# 74 76
# 69 71
# 65 67
# 63 65
# 64 66
# 63 65
# 60 62
# 60 62
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 559 561
# 559 561
# 559 561
# 559 561
# 559 561
# 559 561
# 559 561
# 559 561
# 559 561
# 559 561
# 559 561
# 559 561
# 562 564
# 527 529
# 422 424
# 347 349
# 294 296
# 240 242
# 215 217
# 180 182
# 160 162
# 138 140
# 125 127
# 106 108
# 102 104
# 98 100
# 83 85
# 83 85
# 76 78
# 73 75
# 71 73
# 72 74
# 67 69
# 62 64
# 62 64
# 64 66
# 60 62
# 59 61
# 55 57
# 52 54
# 49 51
# 48 50
# 49 51
# 49 51
# 48 50
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 485 487
# 485 487
# 485 487
# 485 487
# 485 487
# 485 487
# 485 487
# 485 487
# 485 487
# 485 487
# 485 487
# 485 487
# 488 490
# 437 439
# 376 378
# 300 302
# 241 243
# 198 200
# 180 182
# 159 161
# 148 150
# 134 136
# 116 118
# 104 106
# 96 98
# 92 94
# 90 92
# 84 86
# 81 83
# 79 81
# 74 76
# 72 74
# 70 72
# 71 73
# 71 73
# 66 68
# 62 64
# 63 65
# 63 65
# 61 63
# 61 63
# 60 62
# 64 66
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 500 502
# 500 502
# 500 502
# 500 502
# 500 502
# 500 502
# 500 502
# 500 502
# 500 502
# 500 502
# 500 502
#
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 479 481
# 479 481
# 479 481
# 479 481
# 479 481
# 479 481
# 479 481
# 479 481
# 479 481
# 479 481
# 479 481
# 381 383
# 321 323
# 230 232
# 177 179
# 151 153
# 128 130
# 112 114
# 101 103
# 94 96
# 82 84
# 74 76
# 73 75
# 74 76
# 72 74
# 73 75
# 63 65
# 64 66
# 60 62
# 60 62
# 62 64
# 62 64
# 60 62
# 57 59
# 53 55
# 53 55
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 444 446
# 444 446
# 444 446
# 444 446
# 444 446
# 444 446
# 444 446
# 444 446
# 444 446
# 444 446
# 444 446
# 349 351
# 262 264
# 193 195
# 154 156
# 114 116
# 88 90
# 74 76
# 76 78
# 63 65
# 53 55
# 52 54
# 53 55
# 50 52
# 48 50
# 44 46
# 46 48
# 47 49
# 46 48
# 45 47
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 397 399
# 397 399
# 397 399
# 397 399
# 397 399
# 397 399
# 397 399
# 397 399
# 397 399
# 397 399
# 397 399
# 289 291
# 203 205
# 160 162
# 130 132
# 111 113
# 100 102
# 93 95
# 86 88
# 83 85
# 80 82
# 79 81
# 73 75
# 80 82
# 74 76
# 76 78
# 74 76
# 70 72
# 66 68
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 415 417
# 415 417
# 415 417
# 415 417
# 415 417
# 415 417
# 415 417
# 415 417
# 415 417
# 415 417
# 415 417
# 332 334
# 264 266
# 205 207
# 156 158
# 127 129
# 117 119
# 104 106
# 91 93
# 82 84
# 79 81
# 72 74
# 77 79
# 70 72
# 67 69
# 67 69
# 65 67
# 68 70
# 70 72
# 70 72
# 66 68
# 66 68
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.37, Std. Accuracy: 0.0705691150575094
# Model: Lasso, Avg. Accuracy: 0.202, Std. Accuracy: 0.042379240200834174
# Model: Proximal, Avg. Accuracy: 0.7470000000000001, Std. Accuracy: 0.13134306224540374
# Model: Lasso_Sklearn, Avg. Accuracy: 0.20500000000000002, Std. Accuracy: 0.03456877203488721
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 12.24744871391589, mu: 0.01, acc: 0.46799999999999997
# rho: 12.24744871391589, mu: 0.1, acc: 0.48
# rho: 12.24744871391589, mu: 1.0, acc: 0.472
# rho: 83.28265125462805, mu: 0.01, acc: 0.41200000000000003
# rho: 83.28265125462805, mu: 0.1, acc: 0.48
# rho: 83.28265125462805, mu: 1.0, acc: 0.472
# Best rho: 12.24744871391589, Best mu: 0.1
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 546 548
# 546 548
# 546 548
# 546 548
# 546 548
# 546 548
# 546 548
# 546 548
# 546 548
# 546 548
# 546 548
# 546 548
# 580 582
# 571 573
# 524 526
# 422 424
# 353 355
# 300 302
# 246 248
# 223 225
# 194 196
# 178 180
# 157 159
# 142 144
# 124 126
# 122 124
# 116 118
# 109 111
# 109 111
# 100 102
# 98 100
# 95 97
# 91 93
# 87 89
# 87 89
# 86 88
# 87 89
# 86 88
# 85 87
# 83 85
# 82 84
# 80 82
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 582 584
# 582 584
# 582 584
# 582 584
# 582 584
# 582 584
# 582 584
# 582 584
# 582 584
# 582 584
# 582 584
# 582 584
# 598 600
# 542 544
# 449 451
# 388 390
# 327 329
# 255 257
# 226 228
# 191 193
# 164 166
# 147 149
# 138 140
# 127 129
# 114 116
# 109 111
# 111 113
# 101 103
# 95 97
# 93 95
# 85 87
# 83 85
# 83 85
# 77 79
# 76 78
# 76 78
# 72 74
# 74 76
# 73 75
# 70 72
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 595 597
# 595 597
# 595 597
# 595 597
# 595 597
# 595 597
# 595 597
# 595 597
# 595 597
# 595 597
# 595 597
# 595 597
# 615 617
# 572 574
# 485 487
# 409 411
# 339 341
# 294 296
# 264 266
# 227 229
# 196 198
# 185 187
# 167 169
# 158 160
# 143 145
# 143 145
# 134 136
# 124 126
# 113 115
# 114 116
# 114 116
# 114 116
# 103 105
# 102 104
# 98 100
# 100 102
# 95 97
# 94 96
# 93 95
# 90 92
# 90 92
# 85 87
# 87 89
# 86 88
# 84 86
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 590 592
# 590 592
# 590 592
# 590 592
# 590 592
# 590 592
# 590 592
# 590 592
# 590 592
# 590 592
# 590 592
# 590 592
#
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 631 633
# 631 633
# 631 633
# 631 633
# 631 633
# 631 633
# 631 633
# 631 633
# 631 633
# 631 633
# 631 633
# 631 633
# 658 660
# 624 626
# 582 584
# 511 513
# 431 433
# 383 385
# 328 330
# 286 288
# 245 247
# 224 226
# 199 201
# 176 178
# 163 165
# 158 160
# 145 147
# 141 143
# 140 142
# 132 134
# 138 140
# 129 131
# 129 131
# 122 124
# 122 124
# 117 119
# 118 120
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 649 651
# 649 651
# 649 651
# 649 651
# 649 651
# 649 651
# 649 651
# 649 651
# 649 651
# 649 651
# 649 651
# 649 651
# 681 683
# 649 651
# 593 595
# 499 501
# 436 438
# 356 358
# 303 305
# 247 249
# 216 218
# 204 206
# 190 192
# 166 168
# 150 152
# 141 143
# 142 144
# 136 138
# 130 132
# 120 122
# 116 118
# 113 115
# 113 115
# 110 112
# 107 109
# 113 115
# 110 112
# 110 112
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.693, Std. Accuracy: 0.07218725649309579
# Model: Lasso, Avg. Accuracy: 0.406, Std. Accuracy: 0.08604649905719579
# Model: Proximal, Avg. Accuracy: 0.9680000000000002, Std. Accuracy: 0.027129319932501075
# Model: Lasso_Sklearn, Avg. Accuracy: 0.41000000000000003, Std. Accuracy: 0.06826419266350404

# %%
accuracy_2 = []
for n in sample_sizes:
    random_ensemble = RandomEnsemble(n=n, d=1000, k=50, 
                                     h_total=10, h_selected=2, h_rest=8, 
                                     gamma=0.05, p=0.95, q=0.02, 
                                     num_replications=20)
    accuracy_2.append(random_ensemble.main())
# Out:
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 7.0710678118654755, mu: 0.01, acc: 0.41200000000000003
# rho: 7.0710678118654755, mu: 0.1, acc: 0.42399999999999993
# rho: 7.0710678118654755, mu: 1.0, acc: 0.42399999999999993
# rho: 48.08326112068523, mu: 0.01, acc: 0.40800000000000003
# rho: 48.08326112068523, mu: 0.1, acc: 0.41600000000000004
# rho: 48.08326112068523, mu: 1.0, acc: 0.41600000000000004
# Best rho: 7.0710678118654755, Best mu: 0.1
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 13 15
# 13 15
# 13 15
# 13 15
# 13 15
# 13 15
# 13 15
# 13 15
# 6 8
# 6 8
# 6 8
# 6 8
# 6 8
# 6 8
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 18 20
# 18 20
# 18 20
# 18 20
# 18 20
# 18 20
# 18 20
# 18 20
# 13 15
# 10 12
# 10 12
# 8 10
# 7 9
# 7 9
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 21 23
# 21 23
# 21 23
# 21 23
# 21 23
# 21 23
# 21 23
# 21 23
# 15 17
# 13 15
# 13 15
# 13 15
# 14 16
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 18 20
# 17 19
# 17 19
# 16 18
# 16 18
# 14 16
# 16 18
# 13 15
# 13 15
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 29 31
# 29 31
# 29 31
# 29 31
# 29 31
# 29 31
# 29 31
# 29 31
# 29 31
# 27 29
# 24 26
# 21 23
# 17 19
# 17 19
# 16 18
# 17 19
# 16 18
# 16 18
# 15 17
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 34 36
# 34 36
# 34 36
# 34 36
# 34 36
# 34 36
# 34 36
# 34 36
# 34 36
# 24 26
# 24 26
# 21 23
# 15 17
# 14 16
# 13 15
# 12 14
# 11 13
# 12 14
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 21 23
# 21 23
# 21 23
# 21 23
# 21 23
# 21 23
# 21 23
# 21 23
# 14 16
# 10 12
# 7 9
# 6 8
# 7 9
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 13 15
# 13 15
# 13 15
# 13 15
# 13 15
# 13 15
# 13 15
# 13 15
# 9 11
# 7 9
# 6 8
# 6 8
# 6 8
# Synthetic dataset 8: Running Lasso_Sklearn model
# Synthetic dataset 9: Running GFL_Matlab model
# Synthetic dataset 9: Running Lasso model
# Synthetic dataset 9: Running Proximal model
# 14 16
# 14 16
# 14 16
# 14 16
# 14 16
# 14 16
# 14 16
# 14 16
# 11 13
# 9 11
# 10 12
# 8 10
# 8 10
# 8 10
# 8 10
# 8 10
# Synthetic dataset 9: Running Lasso_Sklearn model
# Synthetic dataset 10: Running GFL_Matlab model
# Synthetic dataset 10: Running Lasso model
# Synthetic dataset 10: Running Proximal model
# 15 17
# 15 17
# 15 17
# 15 17
# 15 17
# 15 17
# 15 17
# 15 17
# 11 13
# 8 10
# 8 10
# 8 10
# Synthetic dataset 10: Running Lasso_Sklearn model
# Synthetic dataset 11: Running GFL_Matlab model
# Synthetic dataset 11: Running Lasso model
# Synthetic dataset 11: Running Proximal model
# 23 25
# 23 25
# 23 25
# 23 25
# 23 25
# 23 25
# 23 25
# 23 25
# 21 23
# 20 22
# 17 19
# 18 20
# 15 17
# 16 18
# Synthetic dataset 11: Running Lasso_Sklearn model
# Synthetic dataset 12: Running GFL_Matlab model
# Synthetic dataset 12: Running Lasso model
# Synthetic dataset 12: Running Proximal model
# 21 23
# 21 23
# 21 23
# 21 23
# 21 23
# 21 23
# 21 23
# 21 23
# 16 18
# 14 16
# 15 17
# 13 15
# 12 14
# 12 14
# 11 13
# 11 13
# Synthetic dataset 12: Running Lasso_Sklearn model
# Synthetic dataset 13: Running GFL_Matlab model
# Synthetic dataset 13: Running Lasso model
# Synthetic dataset 13: Running Proximal model
# 32 34
# 32 34
# 32 34
# 32 34
# 32 34
# 32 34
# 32 34
# 32 34
# 32 34
# 27 29
# 24 26
# 21 23
# 20 22
# 20 22
# 17 19
# 18 20
# 18 20
# 16 18
# 17 19
# 17 19
# 16 18
# Synthetic dataset 13: Running Lasso_Sklearn model
# Synthetic dataset 14: Running GFL_Matlab model
# Synthetic dataset 14: Running Lasso model
# Synthetic dataset 14: Running Proximal model
# 26 28
# 26 28
# 26 28
# 26 28
# 26 28
# 26 28
# 26 28
# 26 28
# 24 26
# 24 26
# 19 21
# 18 20
# 19 21
# 18 20
# 19 21
# 20 22
# Synthetic dataset 14: Running Lasso_Sklearn model
# Synthetic dataset 15: Running GFL_Matlab model
# Synthetic dataset 15: Running Lasso model
# Synthetic dataset 15: Running Proximal model
# 22 24
# 22 24
# 22 24
# 22 24
# 22 24
# 22 24
# 22 24
# 22 24
# 13 15
# 10 12
# 10 12
# 10 12
# 11 13
# 11 13
# 11 13
# 10 12
# Synthetic dataset 15: Running Lasso_Sklearn model
# Synthetic dataset 16: Running GFL_Matlab model
# Synthetic dataset 16: Running Lasso model
# Synthetic dataset 16: Running Proximal model
# 8 10
# 8 10
# 8 10
# 8 10
# 8 10
# 8 10
# 8 10
# 8 10
# 8 10
# 8 10
# 9 11
# 9 11
# 9 11
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 39 41
# 39 41
# 39 41
# 39 41
# 39 41
# 39 41
# 39 41
# 39 41
# 39 41
# 29 31
# 22 24
# 21 23
# 22 24
# 21 23
# 19 21
# 19 21
# 18 20
# 18 20
# 18 20
# 19 21
# 19 21
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 23 25
# 23 25
# 23 25
# 23 25
# 23 25
# 23 25
# 23 25
# 23 25
# 23 25
# 20 22
# 17 19
# 14 16
# 14 16
# 14 16
# 14 16
# 14 16
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 35 37
# 35 37
# 35 37
# 35 37
# 35 37
# 35 37
# 35 37
# 35 37
# 35 37
# 28 30
# 21 23
# 19 21
# 20 22
# 18 20
# 17 19
# 15 17
# 14 16
# 15 17
# 15 17
# 15 17
# 14 16
# 14 16
# 15 17
# 15 17
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 34 36
# 34 36
# 34 36
# 34 36
# 34 36
# 34 36
# 34 36
# 34 36
# 33 35
# 32 34
# 24 26
# 22 24
# 21 23
# 20 22
# 21 23
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.531, Std. Accuracy: 0.10343597053249899
# Model: Lasso, Avg. Accuracy: 0.13500000000000004, Std. Accuracy: 0.03090307428072489
# Model: Proximal, Avg. Accuracy: 0.6329999999999999, Std. Accuracy: 0.32386880059678486
# Model: Lasso_Sklearn, Avg. Accuracy: 0.09500000000000001, Std. Accuracy: 0.03217141588429083
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 10.0, mu: 0.01, acc: 0.696
# rho: 10.0, mu: 0.1, acc: 0.72
# rho: 10.0, mu: 1.0, acc: 0.74
# rho: 68.0, mu: 0.01, acc: 0.6799999999999999
# rho: 68.0, mu: 0.1, acc: 0.716
# rho: 68.0, mu: 1.0, acc: 0.716
# Best rho: 10.0, Best mu: 1.0
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 38 40
# 38 40
# 38 40
# 38 40
# 38 40
# 38 40
# 38 40
# 38 40
# 38 40
# 28 30
# 20 22
# 16 18
# 16 18
# 14 16
# 9 11
# 9 11
# 9 11
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 80 82
# 80 82
# 80 82
# 80 82
# 80 82
# 80 82
# 80 82
# 80 82
# 80 82
# 80 82
# 62 64
# 56 58
# 46 48
# 39 41
# 34 36
# 28 30
# 26 28
# 25 27
# 20 22
# 19 21
# 19 21
# 18 20
# 15 17
# 15 17
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 25 27
# 14 16
# 14 16
# 17 19
# 14 16
# 14 16
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 20 22
# 7 9
# 5 7
# 5 7
# 5 7
# 4 6
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 32 34
# 19 21
# 13 15
# 13 15
# 12 14
# 9 11
# 7 9
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 41 43
# 31 33
# 28 30
# 23 25
# 20 22
# 20 22
# 17 19
# 15 17
# 15 17
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 67 69
# 48 50
# 40 42
# 33 35
# 24 26
# 17 19
# 10 12
# 8 10
# 6 8
# 6 8
# 6 8
# 6 8
# 6 8
# 6 8
# 6 8
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 49 51
# 43 45
# 32 34
# 27 29
# 22 24
# 22 24
# 21 23
# 18 20
# 18 20
# 18 20
# 19 21
# Synthetic dataset 8: Running Lasso_Sklearn model
# Synthetic dataset 9: Running GFL_Matlab model
# Synthetic dataset 9: Running Lasso model
# Synthetic dataset 9: Running Proximal model
# 51 53
# 51 53
# 51 53
# 51 53
# 51 53
# 51 53
# 51 53
# 51 53
# 51 53
# 37 39
# 32 34
# 30 32
# 27 29
# 24 26
# 21 23
# 22 24
# 19 21
# Synthetic dataset 9: Running Lasso_Sklearn model
# Synthetic dataset 10: Running GFL_Matlab model
# Synthetic dataset 10: Running Lasso model
# Synthetic dataset 10: Running Proximal model
# 37 39
# 37 39
# 37 39
# 37 39
# 37 39
# 37 39
# 37 39
# 37 39
# 37 39
# 30 32
# 25 27
# 27 29
# 25 27
# 22 24
# 19 21
# 17 19
# 17 19
# 15 17
# Synthetic dataset 10: Running Lasso_Sklearn model
# Synthetic dataset 11: Running GFL_Matlab model
# Synthetic dataset 11: Running Lasso model
# Synthetic dataset 11: Running Proximal model
# 45 47
# 45 47
# 45 47
# 45 47
# 45 47
# 45 47
# 45 47
# 45 47
# 45 47
# 14 16
# 9 11
# 7 9
# 4 6
# 3 5
# 3 5
# 3 5
# 3 5
# 3 5
# Synthetic dataset 11: Running Lasso_Sklearn model
# Synthetic dataset 12: Running GFL_Matlab model
# Synthetic dataset 12: Running Lasso model
# Synthetic dataset 12: Running Proximal model
# 50 52
# 50 52
# 50 52
# 50 52
# 50 52
# 50 52
# 50 52
# 50 52
# 50 52
# 40 42
# 38 40
# 33 35
# 25 27
# 23 25
# 20 22
# 18 20
# 16 18
# 14 16
# Synthetic dataset 12: Running Lasso_Sklearn model
# Synthetic dataset 13: Running GFL_Matlab model
# Synthetic dataset 13: Running Lasso model
# Synthetic dataset 13: Running Proximal model
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 58 60
# 51 53
# 38 40
# 29 31
# 21 23
# 16 18
# 12 14
# 9 11
# 5 7
# 6 8
# Synthetic dataset 13: Running Lasso_Sklearn model
# Synthetic dataset 14: Running GFL_Matlab model
# Synthetic dataset 14: Running Lasso model
# Synthetic dataset 14: Running Proximal model
# 43 45
# 43 45
# 43 45
# 43 45
# 43 45
# 43 45
# 43 45
# 43 45
# 43 45
# 25 27
# 21 23
# 18 20
# 14 16
# 14 16
# 11 13
# 11 13
# 11 13
# Synthetic dataset 14: Running Lasso_Sklearn model
# Synthetic dataset 15: Running GFL_Matlab model
# Synthetic dataset 15: Running Lasso model
# Synthetic dataset 15: Running Proximal model
# 31 33
# 31 33
# 31 33
# 31 33
# 31 33
# 31 33
# 31 33
# 31 33
# 31 33
# 23 25
# 15 17
# 12 14
# 11 13
# 9 11
# 8 10
# 8 10
# Synthetic dataset 15: Running Lasso_Sklearn model
# Synthetic dataset 16: Running GFL_Matlab model
# Synthetic dataset 16: Running Lasso model
# Synthetic dataset 16: Running Proximal model
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 21 23
# 15 17
# 13 15
# 11 13
# 10 12
# 9 11
# 8 10
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 45 47
# 45 47
# 45 47
# 45 47
# 45 47
# 45 47
# 45 47
# 45 47
# 45 47
# 34 36
# 24 26
# 14 16
# 12 14
# 12 14
# 11 13
# 8 10
# 8 10
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 43 45
# 31 33
# 26 28
# 19 21
# 15 17
# 14 16
# 15 17
# 15 17
# 15 17
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 57 59
# 57 59
# 57 59
# 57 59
# 57 59
# 57 59
# 57 59
# 57 59
# 57 59
# 57 59
# 51 53
# 41 43
# 23 25
# 15 17
# 11 13
# 8 10
# 7 9
# 7 9
# 6 8
# 6 8
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 39 41
# 39 41
# 39 41
# 39 41
# 39 41
# 39 41
# 39 41
# 39 41
# 39 41
# 26 28
# 23 25
# 16 18
# 11 13
# 10 12
# 10 12
# 10 12
# 10 12
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.851, Std. Accuracy: 0.052335456432518114
# Model: Lasso, Avg. Accuracy: 0.255, Std. Accuracy: 0.04043513323831146
# Model: Proximal, Avg. Accuracy: 0.99, Std. Accuracy: 0.016124515496597113
# Model: Lasso_Sklearn, Avg. Accuracy: 0.24699999999999997, Std. Accuracy: 0.0391279950930277
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 12.24744871391589, mu: 0.01, acc: 0.8879999999999999
# rho: 12.24744871391589, mu: 0.1, acc: 0.892
# rho: 12.24744871391589, mu: 1.0, acc: 0.892
# rho: 83.28265125462805, mu: 0.01, acc: 0.8719999999999999
# rho: 83.28265125462805, mu: 0.1, acc: 0.884
# rho: 83.28265125462805, mu: 1.0, acc: 0.892
# Best rho: 12.24744871391589, Best mu: 0.1
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 50 52
# 50 52
# 50 52
# 50 52
# 50 52
# 50 52
# 50 52
# 50 52
# 50 52
# 21 23
# 15 17
# 13 15
# 10 12
# 10 12
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 68 70
# 68 70
# 68 70
# 68 70
# 68 70
# 68 70
# 68 70
# 68 70
# 68 70
# 68 70
# 60 62
# 43 45
# 33 35
# 24 26
# 18 20
# 13 15
# 9 11
# 8 10
# 6 8
# 5 7
# 6 8
# 6 8
# 6 8
# 7 9
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 62 64
# 62 64
# 62 64
# 62 64
# 62 64
# 62 64
# 62 64
# 62 64
# 62 64
# 33 35
# 24 26
# 19 21
# 19 21
# 8 10
# 6 8
# 6 8
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 106 108
# 68 70
# 46 48
# 35 37
# 28 30
# 17 19
# 8 10
# 4 6
# 3 5
# 2 4
# 4 6
# 4 6
# 4 6
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 83 85
# 83 85
# 83 85
# 83 85
# 83 85
# 83 85
# 83 85
# 83 85
# 83 85
# 83 85
# 69 71
# 61 63
# 46 48
# 33 35
# 30 32
# 22 24
# 16 18
# 15 17
# 11 13
# 9 11
# 7 9
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 69 71
# 69 71
# 69 71
# 69 71
# 69 71
# 69 71
# 69 71
# 69 71
# 69 71
# 69 71
# 58 60
# 50 52
# 38 40
# 30 32
# 22 24
# 15 17
# 13 15
# 13 15
# 9 11
# 10 12
# 8 10
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 51 53
# 51 53
# 51 53
# 51 53
# 51 53
# 51 53
# 51 53
# 51 53
# 51 53
# 51 53
# 46 48
# 32 34
# 24 26
# 21 23
# 9 11
# 10 12
# 7 9
# 7 9
# 7 9
# 6 8
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 76 78
# 76 78
# 76 78
# 76 78
# 76 78
# 76 78
# 76 78
# 76 78
# 76 78
# 76 78
# 49 51
# 34 36
# 28 30
# 24 26
# 17 19
# 9 11
# 8 10
# 9 11
# 8 10
# Synthetic dataset 8: Running Lasso_Sklearn model
# Synthetic dataset 9: Running GFL_Matlab model
# Synthetic dataset 9: Running Lasso model
# Synthetic dataset 9: Running Proximal model
# 53 55
# 53 55
# 53 55
# 53 55
# 53 55
# 53 55
# 53 55
# 53 55
# 53 55
# 53 55
# 39 41
# 19 21
# 10 12
# 7 9
# 6 8
# 6 8
# 6 8
# 5 7
# 5 7
# 6 8
# Synthetic dataset 9: Running Lasso_Sklearn model
# Synthetic dataset 10: Running GFL_Matlab model
# Synthetic dataset 10: Running Lasso model
# Synthetic dataset 10: Running Proximal model
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 54 56
# 38 40
# 28 30
# 21 23
# 15 17
# 15 17
# 10 12
# 10 12
# Synthetic dataset 10: Running Lasso_Sklearn model
# Synthetic dataset 11: Running GFL_Matlab model
# Synthetic dataset 11: Running Lasso model
# Synthetic dataset 11: Running Proximal model
# 73 75
# 73 75
# 73 75
# 73 75
# 73 75
# 73 75
# 73 75
# 73 75
# 73 75
# 73 75
# 52 54
# 38 40
# 29 31
# 17 19
# 12 14
# 12 14
# 10 12
# 9 11
# 9 11
# 10 12
# Synthetic dataset 11: Running Lasso_Sklearn model
# Synthetic dataset 12: Running GFL_Matlab model
# Synthetic dataset 12: Running Lasso model
# Synthetic dataset 12: Running Proximal model
# 71 73
# 71 73
# 71 73
# 71 73
# 71 73
# 71 73
# 71 73
# 71 73
# 71 73
# 71 73
# 56 58
# 42 44
# 33 35
# 33 35
# 26 28
# 22 24
# 15 17
# 10 12
# 10 12
# 11 13
# 10 12
# 10 12
# 10 12
# 10 12
# 10 12
# Synthetic dataset 12: Running Lasso_Sklearn model
# Synthetic dataset 13: Running GFL_Matlab model
# Synthetic dataset 13: Running Lasso model
# Synthetic dataset 13: Running Proximal model
# 82 84
# 82 84
# 82 84
# 82 84
# 82 84
# 82 84
# 82 84
# 82 84
# 82 84
# 82 84
# 66 68
# 54 56
# 33 35
# 26 28
# 20 22
# 13 15
# 11 13
# 9 11
# Synthetic dataset 13: Running Lasso_Sklearn model
# Synthetic dataset 14: Running GFL_Matlab model
# Synthetic dataset 14: Running Lasso model
# Synthetic dataset 14: Running Proximal model
# 73 75
# 73 75
# 73 75
# 73 75
# 73 75
# 73 75
# 73 75
# 73 75
# 73 75
# 73 75
# 61 63
# 43 45
# 42 44
# 26 28
# 22 24
# 17 19
# 12 14
# 7 9
# 5 7
# 6 8
# 8 10
# 9 11
# 10 12
# Synthetic dataset 14: Running Lasso_Sklearn model
# Synthetic dataset 15: Running GFL_Matlab model
# Synthetic dataset 15: Running Lasso model
# Synthetic dataset 15: Running Proximal model
# 62 64
# 62 64
# 62 64
# 62 64
# 62 64
# 62 64
# 62 64
# 62 64
# 62 64
# 62 64
# 53 55
# 57 59
# 47 49
# 39 41
# 29 31
# 22 24
# 22 24
# 18 20
# 13 15
# 11 13
# 9 11
# 9 11
# Synthetic dataset 15: Running Lasso_Sklearn model
# Synthetic dataset 16: Running GFL_Matlab model
# Synthetic dataset 16: Running Lasso model
# Synthetic dataset 16: Running Proximal model
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 52 54
# 43 45
# 29 31
# 21 23
# 16 18
# 13 15
# 10 12
# 8 10
# 7 9
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 52 54
# 29 31
# 18 20
# 14 16
# 12 14
# 9 11
# 9 11
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 83 85
# 83 85
# 83 85
# 83 85
# 83 85
# 83 85
# 83 85
# 83 85
# 83 85
# 83 85
# 75 77
# 46 48
# 38 40
# 29 31
# 18 20
# 14 16
# 12 14
# 8 10
# 8 10
# 8 10
# 7 9
# 10 12
# 10 12
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 76 78
# 76 78
# 76 78
# 76 78
# 76 78
# 76 78
# 76 78
# 76 78
# 76 78
# 76 78
# 64 66
# 52 54
# 46 48
# 37 39
# 25 27
# 20 22
# 17 19
# 15 17
# 11 13
# 10 12
# 10 12
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 75 77
# 75 77
# 75 77
# 75 77
# 75 77
# 75 77
# 75 77
# 75 77
# 75 77
# 75 77
# 73 75
# 60 62
# 43 45
# 35 37
# 24 26
# 14 16
# 11 13
# 6 8
# 5 7
# 6 8
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.9349999999999999, Std. Accuracy: 0.043301270189221926
# Model: Lasso, Avg. Accuracy: 0.4050000000000001, Std. Accuracy: 0.07921489758877431
# Model: Proximal, Avg. Accuracy: 1.0, Std. Accuracy: 0.0
# Model: Lasso_Sklearn, Avg. Accuracy: 0.387, Std. Accuracy: 0.0667158152164837
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 14.142135623730951, mu: 0.01, acc: 0.9640000000000001
# rho: 14.142135623730951, mu: 0.1, acc: 0.944
# rho: 14.142135623730951, mu: 1.0, acc: 0.924
# rho: 96.16652224137046, mu: 0.01, acc: 0.944
# rho: 96.16652224137046, mu: 0.1, acc: 0.9279999999999999
# rho: 96.16652224137046, mu: 1.0, acc: 0.9039999999999999
# Best rho: 14.142135623730951, Best mu: 0.01
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 103 105
# 103 105
# 103 105
# 103 105
# 103 105
# 103 105
# 103 105
# 103 105
# 103 105
# 103 105
# 68 70
# 42 44
# 28 30
# 14 16
# 12 14
# 9 11
# 6 8
# 6 8
# 7 9
# 7 9
# 7 9
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 58 60
# 45 47
# 27 29
# 16 18
# 10 12
# 5 7
# 3 5
# 4 6
# 4 6
# 5 7
# 5 7
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 72 74
# 72 74
# 72 74
# 72 74
# 72 74
# 72 74
# 72 74
# 72 74
# 72 74
# 72 74
# 59 61
# 46 48
# 34 36
# 21 23
# 12 14
# 8 10
# 8 10
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 95 97
# 95 97
# 95 97
# 95 97
# 95 97
# 95 97
# 95 97
# 95 97
# 95 97
# 95 97
# 56 58
# 32 34
# 19 21
# 12 14
# 10 12
# 9 11
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 56 58
# 35 37
# 30 32
# 21 23
# 12 14
# 11 13
# 9 11
# 6 8
# 7 9
# 6 8
# 5 7
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 78 80
# 57 59
# 45 47
# 39 41
# 32 34
# 20 22
# 12 14
# 8 10
# 8 10
# 8 10
# 7 9
# 8 10
# 8 10
# 8 10
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 93 95
# 93 95
# 93 95
# 93 95
# 93 95
# 93 95
# 93 95
# 93 95
# 93 95
# 93 95
# 73 75
# 43 45
# 26 28
# 15 17
# 13 15
# 9 11
# 6 8
# 6 8
# 7 9
# 7 9
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 74 76
# 74 76
# 74 76
# 74 76
# 74 76
# 74 76
# 74 76
# 74 76
# 74 76
# 74 76
# 57 59
# 43 45
# 32 34
# 19 21
# 14 16
# 13 15
# 10 12
# Synthetic dataset 8: Running Lasso_Sklearn model
# Synthetic dataset 9: Running GFL_Matlab model
# Synthetic dataset 9: Running Lasso model
# Synthetic dataset 9: Running Proximal model
# 107 109
# 107 109
# 107 109
# 107 109
# 107 109
# 107 109
# 107 109
# 107 109
# 107 109
# 107 109
# 70 72
# 59 61
# 41 43
# 29 31
# 21 23
# 8 10
# 5 7
# 4 6
# 4 6
# 5 7
# 5 7
# 5 7
# Synthetic dataset 9: Running Lasso_Sklearn model
# Synthetic dataset 10: Running GFL_Matlab model
# Synthetic dataset 10: Running Lasso model
# Synthetic dataset 10: Running Proximal model
# 68 70
# 68 70
# 68 70
# 68 70
# 68 70
# 68 70
# 68 70
# 68 70
# 68 70
# 68 70
# 54 56
# 37 39
# 19 21
# 12 14
# 9 11
# 7 9
# 6 8
# 8 10
# 7 9
# 8 10
# Synthetic dataset 10: Running Lasso_Sklearn model
# Synthetic dataset 11: Running GFL_Matlab model
# Synthetic dataset 11: Running Lasso model
# Synthetic dataset 11: Running Proximal model
# 119 121
# 119 121
# 119 121
# 119 121
# 119 121
# 119 121
# 119 121
# 119 121
# 119 121
# 119 121
# 72 74
# 58 60
# 39 41
# 32 34
# 27 29
# 19 21
# 12 14
# 8 10
# 5 7
# Synthetic dataset 11: Running Lasso_Sklearn model
# Synthetic dataset 12: Running GFL_Matlab model
# Synthetic dataset 12: Running Lasso model
# Synthetic dataset 12: Running Proximal model
# 83 85
# 83 85
# 83 85
# 83 85
# 83 85
# 83 85
# 83 85
# 83 85
# 83 85
# 83 85
# 56 58
# 43 45
# 35 37
# 13 15
# 4 6
# 3 5
# Synthetic dataset 12: Running Lasso_Sklearn model
# Synthetic dataset 13: Running GFL_Matlab model
# Synthetic dataset 13: Running Lasso model
# Synthetic dataset 13: Running Proximal model
# 121 123
# 121 123
# 121 123
# 121 123
# 121 123
# 121 123
# 121 123
# 121 123
# 121 123
# 121 123
# 70 72
# 55 57
# 31 33
# 22 24
# 13 15
# 4 6
# 3 5
# 3 5
# 3 5
# 4 6
# 4 6
# Synthetic dataset 13: Running Lasso_Sklearn model
# Synthetic dataset 14: Running GFL_Matlab model
# Synthetic dataset 14: Running Lasso model
# Synthetic dataset 14: Running Proximal model
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 89 91
# 50 52
# 35 37
# 25 27
# 17 19
# 12 14
# 9 11
# 10 12
# Synthetic dataset 14: Running Lasso_Sklearn model
# Synthetic dataset 15: Running GFL_Matlab model
# Synthetic dataset 15: Running Lasso model
# Synthetic dataset 15: Running Proximal model
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 70 72
# 50 52
# 34 36
# 29 31
# 21 23
# 12 14
# 5 7
# 4 6
# 4 6
# 4 6
# 4 6
# 3 5
# Synthetic dataset 15: Running Lasso_Sklearn model
# Synthetic dataset 16: Running GFL_Matlab model
# Synthetic dataset 16: Running Lasso model
# Synthetic dataset 16: Running Proximal model
# 103 105
# 103 105
# 103 105
# 103 105
# 103 105
# 103 105
# 103 105
# 103 105
# 103 105
# 103 105
# 49 51
# 31 33
# 22 24
# 16 18
# 8 10
# 5 7
# 3 5
# 3 5
# 4 6
# 4 6
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 99 101
# 58 60
# 45 47
# 26 28
# 13 15
# 11 13
# 8 10
# 5 7
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 81 83
# 81 83
# 81 83
# 81 83
# 81 83
# 81 83
# 81 83
# 81 83
# 81 83
# 81 83
# 46 48
# 38 40
# 30 32
# 17 19
# 10 12
# 10 12
# 9 11
# 9 11
# 7 9
# 7 9
# 8 10
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 112 114
# 112 114
# 112 114
# 112 114
# 112 114
# 112 114
# 112 114
# 112 114
# 112 114
# 112 114
# 50 52
# 34 36
# 14 16
# 8 10
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 97 99
# 97 99
# 97 99
# 97 99
# 97 99
# 97 99
# 97 99
# 97 99
# 97 99
# 97 99
# 56 58
# 40 42
# 32 34
# 19 21
# 8 10
# 6 8
# 4 6
# 4 6
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.9969999999999999, Std. Accuracy: 0.007141428428542858
# Model: Lasso, Avg. Accuracy: 0.8150000000000001, Std. Accuracy: 0.16623778150588991
# Model: Proximal, Avg. Accuracy: 1.0, Std. Accuracy: 0.0
# Model: Lasso_Sklearn, Avg. Accuracy: 0.5609999999999998, Std. Accuracy: 0.08160269603389339

# %%
accuracy_3 = []
for n in sample_sizes:
    random_ensemble = RandomEnsemble(n=n, d=1000, k=50, 
                                     h_total=40, h_selected=2, h_rest=38, 
                                     gamma=0.05, p=0.95, q=0.02, 
                                     num_replications=20)
    accuracy_3.append(random_ensemble.main())
# Out:
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 7.0710678118654755, mu: 0.01, acc: 0.20800000000000002
# rho: 7.0710678118654755, mu: 0.1, acc: 0.2
# rho: 7.0710678118654755, mu: 1.0, acc: 0.196
# rho: 48.08326112068523, mu: 0.01, acc: 0.20800000000000002
# rho: 48.08326112068523, mu: 0.1, acc: 0.196
# rho: 48.08326112068523, mu: 1.0, acc: 0.192
# Best rho: 7.0710678118654755, Best mu: 0.01
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 189 191
# 140 142
# 109 111
# 75 77
# 59 61
# 47 49
# 46 48
# 39 41
# 32 34
# 29 31
# 24 26
# 24 26
# 23 25
# 22 24
# 23 25
# 23 25
# 21 23
# 22 24
# 22 24
# 21 23
# 22 24
# 22 24
# 21 23
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 221 223
# 221 223
# 221 223
# 221 223
# 221 223
# 221 223
# 221 223
# 221 223
# 221 223
# 221 223
# 221 223
# 152 154
# 123 125
# 96 98
# 74 76
# 71 73
# 60 62
# 54 56
# 47 49
# 40 42
# 37 39
# 36 38
# 31 33
# 32 34
# 30 32
# 27 29
# 26 28
# 26 28
# 26 28
# 28 30
# 27 29
# 27 29
# 28 30
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 259 261
# 259 261
# 259 261
# 259 261
# 259 261
# 259 261
# 259 261
# 259 261
# 259 261
# 259 261
# 259 261
# 182 184
# 139 141
# 112 114
# 88 90
# 75 77
# 65 67
# 56 58
# 55 57
# 53 55
# 49 51
# 50 52
# 50 52
# 46 48
# 47 49
# 44 46
# 41 43
# 43 45
# 42 44
# 44 46
# 44 46
# 43 45
# 43 45
# 40 42
# 39 41
# 38 40
# 34 36
# 37 39
# 39 41
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 173 175
# 173 175
# 173 175
# 173 175
# 173 175
# 173 175
# 173 175
# 173 175
# 173 175
# 173 175
# 92 94
# 71 73
# 56 58
# 42 44
# 40 42
# 33 35
# 32 34
# 29 31
# 26 28
# 24 26
# 21 23
# 21 23
# 20 22
# 20 22
# 20 22
# 19 21
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 155 157
# 155 157
# 155 157
# 155 157
# 155 157
# 155 157
# 155 157
# 155 157
# 155 157
# 155 157
# 155 157
# 128 130
# 102 104
# 84 86
# 66 68
# 50 52
# 45 47
# 40 42
# 38 40
# 36 38
# 35 37
# 32 34
# 28 30
# 27 29
# 27 29
# 25 27
# 24 26
# 23 25
# 22 24
# 22 24
# 25 27
# 24 26
# 22 24
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 169 171
# 169 171
# 169 171
# 169 171
# 169 171
# 169 171
# 169 171
# 169 171
# 169 171
# 169 171
# 169 171
# 111 113
# 95 97
# 75 77
# 67 69
# 52 54
# 47 49
# 43 45
# 38 40
# 36 38
# 32 34
# 33 35
# 32 34
# 31 33
# 31 33
# 31 33
# 28 30
# 25 27
# 24 26
# 25 27
# 24 26
# 22 24
# 21 23
# 24 26
# 24 26
# 25 27
# 26 28
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 211 213
# 160 162
# 115 117
# 95 97
# 88 90
# 73 75
# 63 65
# 55 57
# 53 55
# 47 49
# 45 47
# 38 40
# 36 38
# 32 34
# 35 37
# 34 36
# 36 38
# 34 36
# 35 37
# 41 43
# 37 39
# 38 40
# 39 41
# 37 39
# 36 38
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 204 206
# 204 206
# 204 206
# 204 206
# 204 206
# 204 206
# 204 206
# 204 206
# 204 206
# 204 206
# 204 206
# 155 157
# 113 115
# 93 95
# 72 74
# 70 72
# 57 59
# 48 50
# 44 46
# 42 44
# 38 40
# 37 39
# 33 35
# 33 35
# 29 31
# 28 30
# 27 29
# 28 30
# 28 30
# 27 29
# 29 31
# 28 30
# 29 31
# Synthetic dataset 8: Running Lasso_Sklearn model
# Synthetic dataset 9: Running GFL_Matlab model
# Synthetic dataset 9: Running Lasso model
# Synthetic dataset 9: Running Proximal model
# 203 205
# 203 205
# 203 205
# 203 205
# 203 205
# 203 205
# 203 205
# 203 205
# 203 205
# 203 205
# 203 205
# 150 152
# 114 116
# 87 89
# 78 80
# 69 71
# 59 61
# 47 49
# 41 43
# 41 43
# 36 38
# 34 36
# 36 38
# 33 35
# 34 36
# 26 28
# 25 27
# 24 26
# 26 28
# 24 26
# 24 26
# Synthetic dataset 9: Running Lasso_Sklearn model
# Synthetic dataset 10: Running GFL_Matlab model
# Synthetic dataset 10: Running Lasso model
# Synthetic dataset 10: Running Proximal model
# 142 144
# 142 144
# 142 144
# 142 144
# 142 144
# 142 144
# 142 144
# 142 144
# 142 144
# 142 144
# 70 72
# 53 55
# 45 47
# 39 41
# 33 35
# 28 30
# 27 29
# 24 26
# 23 25
# 21 23
# 23 25
# 24 26
# 24 26
# 23 25
# 24 26
# 22 24
# 22 24
# Synthetic dataset 10: Running Lasso_Sklearn model
# Synthetic dataset 11: Running GFL_Matlab model
# Synthetic dataset 11: Running Lasso model
# Synthetic dataset 11: Running Proximal model
# 253 255
# 253 255
# 253 255
# 253 255
# 253 255
# 253 255
# 253 255
# 253 255
# 253 255
# 253 255
# 253 255
# 169 171
# 136 138
# 116 118
# 85 87
# 70 72
# 57 59
# 50 52
# 44 46
# 44 46
# 42 44
# 41 43
# 41 43
# 41 43
# 38 40
# 35 37
# 33 35
# 35 37
# 32 34
# 32 34
# 32 34
# 31 33
# 31 33
# 31 33
# 33 35
# 29 31
# 29 31
# Synthetic dataset 11: Running Lasso_Sklearn model
# Synthetic dataset 12: Running GFL_Matlab model
# Synthetic dataset 12: Running Lasso model
# Synthetic dataset 12: Running Proximal model
# 334 336
# 334 336
# 334 336
# 334 336
# 334 336
# 334 336
# 334 336
# 334 336
# 334 336
# 334 336
# 334 336
# 224 226
# 168 170
# 134 136
# 110 112
# 102 104
# 90 92
# 84 86
# 75 77
# 66 68
# 57 59
# 51 53
# 48 50
# 48 50
# 46 48
# 46 48
# 46 48
# 43 45
# 42 44
# 41 43
# 39 41
# 38 40
# 35 37
# 32 34
# 33 35
# 32 34
# 31 33
# Synthetic dataset 12: Running Lasso_Sklearn model
# Synthetic dataset 13: Running GFL_Matlab model
# Synthetic dataset 13: Running Lasso model
# Synthetic dataset 13: Running Proximal model
# 151 153
# 151 153
# 151 153
# 151 153
# 151 153
# 151 153
# 151 153
# 151 153
# 151 153
# 151 153
# 93 95
# 74 76
# 60 62
# 52 54
# 48 50
# 44 46
# 40 42
# 38 40
# 42 44
# 42 44
# 38 40
# 40 42
# 41 43
# 39 41
# 36 38
# Synthetic dataset 13: Running Lasso_Sklearn model
# Synthetic dataset 14: Running GFL_Matlab model
# Synthetic dataset 14: Running Lasso model
# Synthetic dataset 14: Running Proximal model
# 177 179
# 177 179
# 177 179
# 177 179
# 177 179
# 177 179
# 177 179
# 177 179
# 177 179
# 177 179
# 89 91
# 65 67
# 56 58
# 50 52
# 45 47
# 41 43
# 36 38
# 35 37
# 37 39
# 34 36
# 35 37
# 33 35
# 31 33
# 31 33
# Synthetic dataset 14: Running Lasso_Sklearn model
# Synthetic dataset 15: Running GFL_Matlab model
# Synthetic dataset 15: Running Lasso model
# Synthetic dataset 15: Running Proximal model
# 154 156
# 154 156
# 154 156
# 154 156
# 154 156
# 154 156
# 154 156
# 154 156
# 154 156
# 154 156
# 77 79
# 62 64
# 48 50
# 36 38
# 27 29
# 25 27
# 24 26
# 21 23
# 19 21
# 17 19
# 16 18
# 16 18
# 14 16
# 15 17
# 15 17
# 15 17
# 14 16
# Synthetic dataset 15: Running Lasso_Sklearn model
# Synthetic dataset 16: Running GFL_Matlab model
# Synthetic dataset 16: Running Lasso model
# Synthetic dataset 16: Running Proximal model
# 243 245
# 243 245
# 243 245
# 243 245
# 243 245
# 243 245
# 243 245
# 243 245
# 243 245
# 243 245
# 243 245
# 158 160
# 117 119
# 98 100
# 74 76
# 60 62
# 57 59
# 53 55
# 48 50
# 42 44
# 41 43
# 36 38
# 33 35
# 31 33
# 30 32
# 31 33
# 29 31
# 28 30
# 28 30
# 28 30
# 27 29
# 28 30
# 28 30
# 26 28
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 296 298
# 199 201
# 149 151
# 113 115
# 94 96
# 74 76
# 68 70
# 61 63
# 59 61
# 54 56
# 52 54
# 47 49
# 48 50
# 42 44
# 42 44
# 39 41
# 39 41
# 40 42
# 41 43
# 43 45
# 40 42
# 41 43
# 42 44
# 42 44
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 131 133
# 131 133
# 131 133
# 131 133
# 131 133
# 131 133
# 131 133
# 131 133
# 131 133
# 131 133
# 71 73
# 58 60
# 49 51
# 42 44
# 32 34
# 23 25
# 21 23
# 19 21
# 19 21
# 19 21
# 19 21
# 20 22
# 18 20
# 18 20
# 18 20
# 19 21
# 19 21
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 246 248
# 246 248
# 246 248
# 246 248
# 246 248
# 246 248
# 246 248
# 246 248
# 246 248
# 246 248
# 246 248
# 179 181
# 134 136
# 107 109
# 83 85
# 79 81
# 65 67
# 48 50
# 46 48
# 43 45
# 40 42
# 34 36
# 38 40
# 36 38
# 35 37
# 32 34
# 33 35
# 31 33
# 32 34
# 31 33
# 31 33
# 32 34
# 32 34
# 33 35
# 32 34
# 32 34
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 279 281
# 279 281
# 279 281
# 279 281
# 279 281
# 279 281
# 279 281
# 279 281
# 279 281
# 279 281
# 279 281
# 193 195
# 154 156
# 120 122
# 102 104
# 83 85
# 71 73
# 66 68
# 62 64
# 53 55
# 48 50
# 49 51
# 46 48
# 43 45
# 40 42
# 38 40
# 38 40
# 38 40
# 36 38
# 36 38
# 36 38
# 33 35
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.23399999999999999, Std. Accuracy: 0.038
# Model: Lasso, Avg. Accuracy: 0.15000000000000005, Std. Accuracy: 0.027202941017470887
# Model: Proximal, Avg. Accuracy: 0.29700000000000004, Std. Accuracy: 0.21026411962101382
# Model: Lasso_Sklearn, Avg. Accuracy: 0.12100000000000002, Std. Accuracy: 0.03923009049186607
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 10.0, mu: 0.01, acc: 0.37600000000000006
# rho: 10.0, mu: 0.1, acc: 0.36800000000000005
# rho: 10.0, mu: 1.0, acc: 0.36400000000000005
# rho: 68.0, mu: 0.01, acc: 0.34800000000000003
# rho: 68.0, mu: 0.1, acc: 0.34400000000000003
# rho: 68.0, mu: 1.0, acc: 0.36000000000000004
# Best rho: 10.0, Best mu: 0.01
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 432 434
# 432 434
# 432 434
# 432 434
# 432 434
# 432 434
# 432 434
# 432 434
# 432 434
# 432 434
# 432 434
# 432 434
# 425 427
# 360 362
# 293 295
# 226 228
# 198 200
# 168 170
# 141 143
# 125 127
# 114 116
# 96 98
# 83 85
# 83 85
# 80 82
# 77 79
# 70 72
# 68 70
# 64 66
# 62 64
# 60 62
# 58 60
# 54 56
# 50 52
# 50 52
# 46 48
# 46 48
# 44 46
# 45 47
# 41 43
# 41 43
# 40 42
# 39 41
# 37 39
# 34 36
# 34 36
# 32 34
# 30 32
# 28 30
# 26 28
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 451 453
# 451 453
# 451 453
# 451 453
# 451 453
# 451 453
# 451 453
# 451 453
# 451 453
# 451 453
# 451 453
# 451 453
# 425 427
# 392 394
# 298 300
# 256 258
# 201 203
# 173 175
# 143 145
# 124 126
# 104 106
# 93 95
# 80 82
# 75 77
# 64 66
# 59 61
# 54 56
# 53 55
# 50 52
# 44 46
# 44 46
# 40 42
# 38 40
# 38 40
# 37 39
# 33 35
# 29 31
# 30 32
# 30 32
# 29 31
# 27 29
# 29 31
# 29 31
# 28 30
# 27 29
# 28 30
# 28 30
# 28 30
# 26 28
# 25 27
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 465 467
# 465 467
# 465 467
# 465 467
# 465 467
# 465 467
# 465 467
# 465 467
# 465 467
# 465 467
# 465 467
# 465 467
# 472 474
# 399 401
# 342 344
# 256 258
# 221 223
# 191 193
# 151 153
# 142 144
# 126 128
# 114 116
# 104 106
# 97 99
# 89 91
# 80 82
# 77 79
# 71 73
# 62 64
# 53 55
# 51 53
# 47 49
# 41 43
# 42 44
# 34 36
# 33 35
# 31 33
# 33 35
# 31 33
# 29 31
# 28 30
# 27 29
# 28 30
# 28 30
# 25 27
# 27 29
# 28 30
# 27 29
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 494 496
# 494 496
# 494 496
# 494 496
# 494 496
# 494 496
# 494 496
# 494 496
# 494 496
# 494 496
# 494 496
# 494 496
# 493 495
# 419 421
# 353 355
# 296 298
# 222 224
# 189 191
# 163 165
# 140 142
# 132 134
# 112 114
# 103 105
# 89 91
# 75 77
# 67 69
# 64 66
# 59 61
# 55 57
# 49 51
# 44 46
# 45 47
# 40 42
# 39 41
# 35 37
# 35 37
# 35 37
# 35 37
# 33 35
# 29 31
# 27 29
# 26 28
# 26 28
# 23 25
# 21 23
# 20 22
# 20 22
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 408 410
# 408 410
# 408 410
# 408 410
# 408 410
# 408 410
# 408 410
# 408 410
# 408 410
# 408 410
# 408 410
# 322 324
# 224 226
# 181 183
# 148 150
# 106 108
# 84 86
# 80 82
# 76 78
# 67 69
# 61 63
# 56 58
# 50 52
# 47 49
# 42 44
# 39 41
# 39 41
# 40 42
# 37 39
# 32 34
# 31 33
# 30 32
# 29 31
# 27 29
# 25 27
# 26 28
# 23 25
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 417 419
# 417 419
# 417 419
# 417 419
# 417 419
# 417 419
# 417 419
# 417 419
# 417 419
# 417 419
# 417 419
# 311 313
# 222 224
# 186 188
# 140 142
# 123 125
# 106 108
# 93 95
# 79 81
# 73 75
# 60 62
# 57 59
# 53 55
# 47 49
# 45 47
# 43 45
# 43 45
# 36 38
# 32 34
# 39 41
# 37 39
# 37 39
# 38 40
# 36 38
# 35 37
# 34 36
# 34 36
# 33 35
# 32 34
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 484 486
# 484 486
# 484 486
# 484 486
# 484 486
# 484 486
# 484 486
# 484 486
# 484 486
# 484 486
# 484 486
# 484 486
# 506 508
# 463 465
# 352 354
# 254 256
# 208 210
# 175 177
# 149 151
# 138 140
# 119 121
# 108 110
# 87 89
# 84 86
# 80 82
# 71 73
# 63 65
# 64 66
# 58 60
# 51 53
# 49 51
# 47 49
# 44 46
# 43 45
# 40 42
# 36 38
# 33 35
# 35 37
# 37 39
# 36 38
# 34 36
# 33 35
# 29 31
# 29 31
# 24 26
# 23 25
# 23 25
# 22 24
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 412 414
# 412 414
# 412 414
# 412 414
# 412 414
# 412 414
# 412 414
# 412 414
# 412 414
# 412 414
# 412 414
# 323 325
# 242 244
# 169 171
# 138 140
# 111 113
# 89 91
# 77 79
# 69 71
# 68 70
# 63 65
# 59 61
# 54 56
# 50 52
# 45 47
# 43 45
# 31 33
# 28 30
# 28 30
# 27 29
# 28 30
# 25 27
# 20 22
# 21 23
# 20 22
# 18 20
# 15 17
# Synthetic dataset 8: Running Lasso_Sklearn model
# Synthetic dataset 9: Running GFL_Matlab model
# Synthetic dataset 9: Running Lasso model
# Synthetic dataset 9: Running Proximal model
# 367 369
# 367 369
# 367 369
# 367 369
# 367 369
# 367 369
# 367 369
# 367 369
# 367 369
# 367 369
# 367 369
# 250 252
# 185 187
# 147 149
# 117 119
# 102 104
# 86 88
# 72 74
# 68 70
# 60 62
# 54 56
# 51 53
# 44 46
# 42 44
# 39 41
# 40 42
# 37 39
# 36 38
# 35 37
# 35 37
# 34 36
# 33 35
# 34 36
# 35 37
# 34 36
# 35 37
# 32 34
# Synthetic dataset 9: Running Lasso_Sklearn model
# Synthetic dataset 10: Running GFL_Matlab model
# Synthetic dataset 10: Running Lasso model
# Synthetic dataset 10: Running Proximal model
# 461 463
# 461 463
# 461 463
# 461 463
# 461 463
# 461 463
# 461 463
# 461 463
# 461 463
# 461 463
# 461 463
# 461 463
# 452 454
# 386 388
# 296 298
# 244 246
# 217 219
# 186 188
# 158 160
# 144 146
# 127 129
# 110 112
# 96 98
# 97 99
# 82 84
# 77 79
# 69 71
# 65 67
# 60 62
# 55 57
# 50 52
# 45 47
# 46 48
# 43 45
# 40 42
# 38 40
# 38 40
# 32 34
# 30 32
# 28 30
# 26 28
# 25 27
# 24 26
# 23 25
# 19 21
# 14 16
# 14 16
# 12 14
# 12 14
# Synthetic dataset 10: Running Lasso_Sklearn model
# Synthetic dataset 11: Running GFL_Matlab model
# Synthetic dataset 11: Running Lasso model
# Synthetic dataset 11: Running Proximal model
# 364 366
# 364 366
# 364 366
# 364 366
# 364 366
# 364 366
# 364 366
# 364 366
# 364 366
# 364 366
#
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 397 399
# 397 399
# 397 399
# 397 399
# 397 399
# 397 399
# 397 399
# 397 399
# 397 399
# 397 399
# 397 399
# 397 399
# 418 420
# 337 339
# 274 276
# 234 236
# 183 185
# 145 147
# 120 122
# 109 111
# 104 106
# 99 101
# 87 89
# 82 84
# 77 79
# 69 71
# 67 69
# 64 66
# 59 61
# 59 61
# 57 59
# 56 58
# 51 53
# 50 52
# 48 50
# 47 49
# 47 49
# 47 49
# 47 49
# 47 49
# 48 50
# 46 48
# 40 42
# 43 45
# 41 43
# 39 41
# 37 39
# 38 40
# 33 35
# 36 38
# 35 37
# 34 36
# 35 37
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.493, Std. Accuracy: 0.09945350672550465
# Model: Lasso, Avg. Accuracy: 0.29500000000000004, Std. Accuracy: 0.06192737682156414
# Model: Proximal, Avg. Accuracy: 0.9610000000000001, Std. Accuracy: 0.0881986394452885
# Model: Lasso_Sklearn, Avg. Accuracy: 0.271, Std. Accuracy: 0.06825686778632609
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 12.24744871391589, mu: 0.01, acc: 0.692
# rho: 12.24744871391589, mu: 0.1, acc: 0.6839999999999999
# rho: 12.24744871391589, mu: 1.0, acc: 0.6719999999999999
# rho: 83.28265125462805, mu: 0.01, acc: 0.644
# rho: 83.28265125462805, mu: 0.1, acc: 0.672
# rho: 83.28265125462805, mu: 1.0, acc: 0.66
# Best rho: 12.24744871391589, Best mu: 0.01
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 550 552
# 550 552
# 550 552
# 550 552
# 550 552
# 550 552
# 550 552
# 550 552
# 550 552
# 550 552
# 550 552
# 550 552
# 543 545
# 474 476
# 380 382
# 304 306
# 247 249
# 194 196
# 170 172
# 137 139
# 119 121
# 93 95
# 89 91
# 76 78
# 63 65
# 55 57
# 50 52
# 47 49
# 41 43
# 36 38
# 30 32
# 25 27
# 17 19
# 14 16
# 13 15
# 10 12
# 7 9
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 477 479
# 477 479
# 477 479
# 477 479
# 477 479
# 477 479
# 477 479
# 477 479
# 477 479
# 477 479
# 477 479
# 477 479
# 471 473
# 436 438
# 328 330
# 266 268
# 221 223
# 182 184
# 158 160
# 131 133
# 116 118
# 98 100
# 91 93
# 76 78
# 72 74
# 59 61
# 50 52
# 51 53
# 42 44
# 31 33
# 26 28
# 21 23
# 16 18
# 15 17
# 13 15
# 10 12
# 8 10
# 6 8
# 4 6
# 3 5
# 3 5
# 4 6
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 515 517
# 515 517
# 515 517
# 515 517
# 515 517
# 515 517
# 515 517
# 515 517
# 515 517
# 515 517
# 515 517
# 515 517
# 506 508
# 442 444
# 359 361
# 295 297
# 242 244
# 199 201
# 169 171
# 140 142
# 126 128
# 116 118
# 102 104
# 98 100
# 89 91
# 77 79
# 66 68
# 61 63
# 56 58
# 50 52
# 50 52
# 44 46
# 40 42
# 42 44
# 37 39
# 29 31
# 27 29
# 29 31
# 25 27
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 502 504
# 502 504
# 502 504
# 502 504
# 502 504
# 502 504
# 502 504
# 502 504
# 502 504
# 502 504
# 502 504
# 502 504
# 480 482
# 431 433
# 352 354
# 280 282
# 238 240
# 203 205
# 182 184
# 150 152
# 128 130
# 121 123
# 106 108
# 100 102
# 84 86
# 75 77
# 61 63
# 54 56
# 47 49
# 45 47
# 43 45
# 39 41
# 35 37
# 34 36
# 32 34
# 28 30
# 24 26
# 19 21
# 18 20
# 16 18
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 519 521
# 519 521
# 519 521
# 519 521
# 519 521
# 519 521
# 519 521
# 519 521
# 519 521
# 519 521
# 519 521
# 519 521
# 523 525
# 473 475
# 385 387
# 280 282
# 220 222
# 173 175
# 147 149
# 131 133
# 111 113
# 103 105
# 91 93
# 79 81
# 74 76
# 60 62
# 51 53
# 48 50
# 47 49
# 46 48
# 39 41
# 34 36
# 33 35
# 28 30
# 20 22
# 16 18
# 16 18
# 11 13
# 10 12
# 10 12
# 9 11
# 9 11
# 9 11
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 548 550
# 548 550
# 548 550
# 548 550
# 548 550
# 548 550
# 548 550
# 548 550
# 548 550
# 548 550
# 548 550
#
# Synthetic dataset 14: Running Lasso_Sklearn model
# Synthetic dataset 15: Running GFL_Matlab model
# Synthetic dataset 15: Running Lasso model
# Synthetic dataset 15: Running Proximal model
# 501 503
# 501 503
# 501 503
# 501 503
# 501 503
# 501 503
# 501 503
# 501 503
# 501 503
# 501 503
# 501 503
# 501 503
# 523 525
# 434 436
# 378 380
# 272 274
# 226 228
# 183 185
# 158 160
# 139 141
# 112 114
# 107 109
# 94 96
# 84 86
# 76 78
# 68 70
# 65 67
# 56 58
# 52 54
# 47 49
# 46 48
# 35 37
# 32 34
# 28 30
# 29 31
# 23 25
# 20 22
# 21 23
# 21 23
# 17 19
# Synthetic dataset 15: Running Lasso_Sklearn model
# Synthetic dataset 16: Running GFL_Matlab model
# Synthetic dataset 16: Running Lasso model
# Synthetic dataset 16: Running Proximal model
# 472 474
# 472 474
# 472 474
# 472 474
# 472 474
# 472 474
# 472 474
# 472 474
# 472 474
# 472 474
# 472 474
# 472 474
# 463 465
# 382 384
# 302 304
# 268 270
# 223 225
# 176 178
# 159 161
# 139 141
# 123 125
# 107 109
# 98 100
# 86 88
# 76 78
# 75 77
# 68 70
# 63 65
# 56 58
# 54 56
# 53 55
# 49 51
# 46 48
# 45 47
# 43 45
# 40 42
# 35 37
# 28 30
# 28 30
# 27 29
# 25 27
# 25 27
# 25 27
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 570 572
# 570 572
# 570 572
# 570 572
# 570 572
# 570 572
# 570 572
# 570 572
# 570 572
# 570 572
# 570 572
# 570 572
# 581 583
# 531 533
# 426 428
# 347 349
# 261 263
# 197 199
# 172 174
# 146 148
# 127 129
# 111 113
# 100 102
# 90 92
# 77 79
# 65 67
# 52 54
# 41 43
# 31 33
# 30 32
# 23 25
# 11 13
# 6 8
# 6 8
# 5 7
# 4 6
# 3 5
# 3 5
# 3 5
# 3 5
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 504 506
# 504 506
# 504 506
# 504 506
# 504 506
# 504 506
# 504 506
# 504 506
# 504 506
# 504 506
# 504 506
# 504 506
# 517 519
# 465 467
# 376 378
# 282 284
# 236 238
# 188 190
# 149 151
# 127 129
# 109 111
# 92 94
# 77 79
# 67 69
# 57 59
# 51 53
# 46 48
# 40 42
# 36 38
# 31 33
# 35 37
# 34 36
# 26 28
# 22 24
# 20 22
# 16 18
# 12 14
# 9 11
# 9 11
# 8 10
# 9 11
# 9 11
# 9 11
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 513 515
# 513 515
# 513 515
# 513 515
# 513 515
# 513 515
# 513 515
# 513 515
# 513 515
# 513 515
# 513 515
# 513 515
# 541 543
# 513 515
# 446 448
# 330 332
# 287 289
# 234 236
# 195 197
# 156 158
# 130 132
# 107 109
# 90 92
# 75 77
# 69 71
# 63 65
# 50 52
# 44 46
# 38 40
# 32 34
# 28 30
# 20 22
# 15 17
# 13 15
# 9 11
# 8 10
# 6 8
# 5 7
# 5 7
# 5 7
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 549 551
# 549 551
# 549 551
# 549 551
# 549 551
# 549 551
# 549 551
# 549 551
# 549 551
# 549 551
# 549 551
# 549 551
# 565 567
# 508 510
# 424 426
# 332 334
# 267 269
# 212 214
# 180 182
# 158 160
# 135 137
# 118 120
# 104 106
# 91 93
# 85 87
# 79 81
# 62 64
# 55 57
# 42 44
# 32 34
# 26 28
# 23 25
# 18 20
# 15 17
# 8 10
# 7 9
# 6 8
# 6 8
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.728, Std. Accuracy: 0.0828009661779378
# Model: Lasso, Avg. Accuracy: 0.425, Std. Accuracy: 0.08291561975888499
# Model: Proximal, Avg. Accuracy: 0.999, Std. Accuracy: 0.004358898943540678
# Model: Lasso_Sklearn, Avg. Accuracy: 0.41000000000000003, Std. Accuracy: 0.05039841267341661
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 14.142135623730951, mu: 0.01, acc: 0.772
# rho: 14.142135623730951, mu: 0.1, acc: 0.756
# rho: 14.142135623730951, mu: 1.0, acc: 0.7120000000000001
# rho: 96.16652224137046, mu: 0.01, acc: 0.6880000000000001
# rho: 96.16652224137046, mu: 0.1, acc: 0.708
# rho: 96.16652224137046, mu: 1.0, acc: 0.6759999999999999
# Best rho: 14.142135623730951, Best mu: 0.01
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 574 576
# 574 576
# 574 576
# 574 576
# 574 576
# 574 576
# 574 576
# 574 576
# 574 576
# 574 576
# 574 576
# 574 576
#
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.9100000000000001, Std. Accuracy: 0.055317266743757317
# Model: Lasso, Avg. Accuracy: 0.7809999999999999, Std. Accuracy: 0.17279756942735044
# Model: Proximal, Avg. Accuracy: 1.0, Std. Accuracy: 0.0
# Model: Lasso_Sklearn, Avg. Accuracy: 0.5050000000000001, Std. Accuracy: 0.08411301920630361

# %%
accuracy_4 = []
for n in sample_sizes:
    random_ensemble = RandomEnsemble(n=n, d=1000, k=50, 
                                     h_total=40, h_selected=2, h_rest=38, 
                                     gamma=0.5, p=0.5, q=0.01, 
                                     num_replications=20)
    accuracy_4.append(random_ensemble.main())
# Out:
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 7.0710678118654755, mu: 0.01, acc: 0.248
# rho: 7.0710678118654755, mu: 0.1, acc: 0.256
# rho: 7.0710678118654755, mu: 1.0, acc: 0.256
# rho: 48.08326112068523, mu: 0.01, acc: 0.23199999999999998
# rho: 48.08326112068523, mu: 0.1, acc: 0.256
# rho: 48.08326112068523, mu: 1.0, acc: 0.264
# Best rho: 48.08326112068523, Best mu: 1.0
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 662 664
# 662 664
# 662 664
# 662 664
# 662 664
# 662 664
# 662 664
# 662 664
# 662 664
# 662 664
# 662 664
# 662 664
# 657 659
# 626 628
# 552 554
# 449 451
# 395 397
# 326 328
# 280 282
# 245 247
# 215 217
# 189 191
# 170 172
# 152 154
# 147 149
# 136 138
# 137 139
# 129 131
# 120 122
# 116 118
# 113 115
# 108 110
# 101 103
# 94 96
# 91 93
# 85 87
# 88 90
# 88 90
# 87 89
# 85 87
# 87 89
# 84 86
# 78 80
# 81 83
# 79 81
# 75 77
# 73 75
# 71 73
# 68 70
# 69 71
# 67 69
# 66 68
# 70 72
# 69 71
# 69 71
# 72 74
# 71 73
# 70 72
# 70 72
# 71 73
# 73 75
# 70 72
# 70 72
# 72 74
# 69 71
# 65 67
# 66 68
# 64 66
# 60 62
# 60 62
# 61 63
# 61 63
# 61 63
# 60 62
# 54 56
# 52 54
# 54 56
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 628 630
# 628 630
# 628 630
# 628 630
# 628 630
# 628 630
# 628 630
# 628 630
# 628 630
# 628 630
# 628 630
# 628 630
# 627 629
# 579 581
# 484 486
# 399 401
# 358 360
# 307 309
# 254 256
# 212 214
# 185 187
# 161 163
# 150 152
# 144 146
# 135 137
# 125 127
# 123 125
# 117 119
# 107 109
# 98 100
# 96 98
# 96 98
# 94 96
# 94 96
# 91 93
# 91 93
# 92 94
# 92 94
# 90 92
# 89 91
# 90 92
# 89 91
# 87 89
# 89 91
# 86 88
# 86 88
# 78 80
# 77 79
# 81 83
# 80 82
# 75 77
# 73 75
# 75 77
# 75 77
# 72 74
# 69 71
# 69 71
# 71 73
# 73 75
# 71 73
# 70 72
# 70 72
# 66 68
# 66 68
# 66 68
# 64 66
# 63 65
# 64 66
# 64 66
# 64 66
# 65 67
# 64 66
# 62 64
# 61 63
# 59 61
# 59 61
# 60 62
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 596 598
# 596 598
# 596 598
# 596 598
# 596 598
# 596 598
# 596 598
# 596 598
# 596 598
# 596 598
# 596 598
# 543 545
# 422 424
# 343 345
# 285 287
# 221 223
# 179 181
# 157 159
# 136 138
# 118 120
# 120 122
# 110 112
# 102 104
# 94 96
# 89 91
# 83 85
# 84 86
# 82 84
# 81 83
# 79 81
# 82 84
# 77 79
# 72 74
# 77 79
# 78 80
# 76 78
# 75 77
# 70 72
# 67 69
# 63 65
# 60 62
# 59 61
# 59 61
# 60 62
# 60 62
# 61 63
# 64 66
# 64 66
# 61 63
# 59 61
# 59 61
# 60 62
# 59 61
# 58 60
# 59 61
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 713 715
# 713 715
# 713 715
# 713 715
# 713 715
# 713 715
# 713 715
# 713 715
# 713 715
# 713 715
# 713 715
# 713 715
#
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 615 617
# 615 617
# 615 617
# 615 617
# 615 617
# 615 617
# 615 617
# 615 617
# 615 617
# 615 617
# 615 617
# 615 617
# 613 615
# 594 596
# 499 501
# 423 425
# 375 377
# 329 331
# 290 292
# 257 259
# 232 234
# 209 211
# 191 193
# 173 175
# 159 161
# 144 146
# 140 142
# 133 135
# 125 127
# 115 117
# 114 116
# 112 114
# 107 109
# 100 102
# 94 96
# 88 90
# 81 83
# 79 81
# 84 86
# 81 83
# 77 79
# 74 76
# 77 79
# 69 71
# 69 71
# 68 70
# 67 69
# 64 66
# 62 64
# 60 62
# 55 57
# 56 58
# 55 57
# 54 56
# 52 54
# 54 56
# 56 58
# 56 58
# 53 55
# 58 60
# 59 61
# 56 58
# 51 53
# 51 53
# 50 52
# 52 54
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.192, Std. Accuracy: 0.08885943956609224
# Model: Lasso, Avg. Accuracy: 0.10900000000000003, Std. Accuracy: 0.04264973622427224
# Model: Proximal, Avg. Accuracy: 0.21600000000000003, Std. Accuracy: 0.1351443672522092
# Model: Lasso_Sklearn, Avg. Accuracy: 0.08900000000000001, Std. Accuracy: 0.03192177939902474
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 10.0, mu: 0.01, acc: 0.296
# rho: 10.0, mu: 0.1, acc: 0.32
# rho: 10.0, mu: 1.0, acc: 0.34400000000000003
# rho: 68.0, mu: 0.01, acc: 0.256
# rho: 68.0, mu: 0.1, acc: 0.32
# rho: 68.0, mu: 1.0, acc: 0.336
# Best rho: 10.0, Best mu: 1.0
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 713 715
# 713 715
# 713 715
# 713 715
# 713 715
# 713 715
# 713 715
# 713 715
# 713 715
# 713 715
# 713 715
# 713 715
# 762 764
# 757 759
# 719 721
# 653 655
# 572 574
# 502 504
# 440 442
# 389 391
# 354 356
# 316 318
# 296 298
# 275 277
# 246 248
# 235 237
# 215 217
# 201 203
# 191 193
# 181 183
# 171 173
# 156 158
# 152 154
# 147 149
# 146 148
# 141 143
# 145 147
# 139 141
# 129 131
# 128 130
# 127 129
# 128 130
# 129 131
# 128 130
# 129 131
# 127 129
# 119 121
# 119 121
# 113 115
# 114 116
# 113 115
# 115 117
# 118 120
# 117 119
# 117 119
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 677 679
# 677 679
# 677 679
# 677 679
# 677 679
# 677 679
# 677 679
# 677 679
# 677 679
# 677 679
# 677 679
# 677 679
# 700 702
# 632 634
# 595 597
# 528 530
# 433 435
# 355 357
# 302 304
# 278 280
# 255 257
# 219 221
# 195 197
# 178 180
# 160 162
# 152 154
# 150 152
# 138 140
# 135 137
# 122 124
# 114 116
# 117 119
# 119 121
# 116 118
# 112 114
# 106 108
# 106 108
# 107 109
# 106 108
# 107 109
# 103 105
# 102 104
# 104 106
# 98 100
# 101 103
# 101 103
# 100 102
# 98 100
# 94 96
# 95 97
# 94 96
# 97 99
# 96 98
# 93 95
# 91 93
# 91 93
# 94 96
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 772 774
# 772 774
# 772 774
# 772 774
# 772 774
# 772 774
# 772 774
# 772 774
# 772 774
# 772 774
# 772 774
# 772 774
# 784 786
# 792 794
# 753 755
# 694 696
# 640 642
# 552 554
# 512 514
# 444 446
# 406 408
# 346 348
# 303 305
# 278 280
# 260 262
# 242 244
# 226 228
# 208 210
# 195 197
# 186 188
# 181 183
# 181 183
# 181 183
# 176 178
# 167 169
# 157 159
# 150 152
# 147 149
# 132 134
# 128 130
# 127 129
# 126 128
# 125 127
# 124 126
# 126 128
# 126 128
# 126 128
# 126 128
# 125 127
# 126 128
# 125 127
# 131 133
# 129 131
# 132 134
# 129 131
# 125 127
# 124 126
# 126 128
# 124 126
# 123 125
# 122 124
# 119 121
# 122 124
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 764 766
# 764 766
# 764 766
# 764 766
# 764 766
# 764 766
# 764 766
# 764 766
# 764 766
# 764 766
# 764 766
#
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.72, Std. Accuracy: 0.07183313998427189
# Model: Lasso, Avg. Accuracy: 0.394, Std. Accuracy: 0.078
# Model: Proximal, Avg. Accuracy: 0.9500000000000002, Std. Accuracy: 0.042190046219457954
# Model: Lasso_Sklearn, Avg. Accuracy: 0.413, Std. Accuracy: 0.056665686266028754

# %%
accuracy_5 = []
for n in sample_sizes:
    random_ensemble = RandomEnsemble(n=n, d=1000, k=50, 
                                     h_total=40, h_selected=2, h_rest=38, 
                                     gamma=0.5, p=0.5, q=0.01, 
                                     num_replications=20)
    accuracy_5.append(random_ensemble.main())
# Out:
# Synthetic dataset 1: Running GFL_Matlab model
# rho: 7.0710678118654755, mu: 0.01, acc: 0.164
# rho: 7.0710678118654755, mu: 0.1, acc: 0.176
# rho: 7.0710678118654755, mu: 1.0, acc: 0.188
# rho: 48.08326112068523, mu: 0.01, acc: 0.16
# rho: 48.08326112068523, mu: 0.1, acc: 0.172
# rho: 48.08326112068523, mu: 1.0, acc: 0.188
# Best rho: 7.0710678118654755, Best mu: 1.0
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 549 551
# 549 551
# 549 551
# 549 551
# 549 551
# 549 551
# 549 551
# 549 551
# 549 551
# 549 551
# 549 551
# 485 487
# 365 367
# 261 263
# 224 226
# 182 184
# 158 160
# 139 141
# 126 128
# 112 114
# 98 100
# 90 92
# 85 87
# 84 86
# 78 80
# 76 78
# 68 70
# 64 66
# 64 66
# 64 66
# 70 72
# 67 69
# 67 69
# 65 67
# 61 63
# 58 60
# 59 61
# 59 61
# 60 62
# 61 63
# 61 63
# 59 61
# 57 59
# 60 62
# 60 62
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 659 661
# 659 661
# 659 661
# 659 661
# 659 661
# 659 661
# 659 661
# 659 661
# 659 661
# 659 661
# 659 661
# 659 661
# 652 654
# 616 618
# 546 548
# 469 471
# 386 388
# 345 347
# 276 278
# 250 252
# 228 230
# 215 217
# 202 204
# 190 192
# 166 168
# 156 158
# 139 141
# 131 133
# 123 125
# 119 121
# 111 113
# 105 107
# 103 105
# 99 101
# 102 104
# 97 99
# 88 90
# 88 90
# 86 88
# 85 87
# 80 82
# 76 78
# 75 77
# 76 78
# 78 80
# 75 77
# 70 72
# 73 75
# 76 78
# 78 80
# 75 77
# 74 76
# 73 75
# 73 75
# 75 77
# 73 75
# 69 71
# 70 72
# 69 71
# 66 68
# 66 68
# 64 66
# 63 65
# 65 67
# 67 69
# 68 70
# 66 68
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 677 679
# 677 679
# 677 679
# 677 679
# 677 679
# 677 679
# 677 679
# 677 679
# 677 679
# 677 679
# 677 679
# 677 679
# 683 685
# 667 669
# 589 591
# 536 538
# 456 458
# 391 393
# 327 329
# 271 273
# 241 243
# 222 224
# 192 194
# 186 188
# 171 173
# 158 160
# 149 151
# 146 148
# 137 139
# 140 142
# 132 134
# 121 123
# 118 120
# 108 110
# 105 107
# 103 105
# 98 100
# 99 101
# 98 100
# 92 94
# 87 89
# 86 88
# 84 86
# 79 81
# 79 81
# 83 85
# 82 84
# 81 83
# 86 88
# 87 89
# 84 86
# 84 86
# 81 83
# 82 84
# 82 84
# 78 80
# 78 80
# 77 79
# 74 76
# 77 79
# 76 78
# 75 77
# 78 80
# 79 81
# 78 80
# 79 81
# 81 83
# 79 81
# 80 82
# 75 77
# 76 78
# 76 78
# 76 78
# 76 78
# 69 71
# 70 72
# 69 71
# 74 76
# 71 73
# 69 71
# 72 74
# 68 70
# 69 71
# 66 68
# 68 70
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 597 599
# 597 599
# 597 599
# 597 599
# 597 599
# 597 599
# 597 599
# 597 599
# 597 599
# 597 599
# 597 599
#
# rho: 14.142135623730951, mu: 0.01, acc: 0.496
# rho: 14.142135623730951, mu: 0.1, acc: 0.56
# rho: 14.142135623730951, mu: 1.0, acc: 0.572
# rho: 96.16652224137046, mu: 0.01, acc: 0.44399999999999995
# rho: 96.16652224137046, mu: 0.1, acc: 0.548
# rho: 96.16652224137046, mu: 1.0, acc: 0.556
# Best rho: 14.142135623730951, Best mu: 1.0
# Synthetic dataset 1: Running Lasso model
# Synthetic dataset 1: Running Proximal model
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 832 834
# 823 825
# 828 830
# 800 802
# 754 756
# 693 695
# 634 636
# 586 588
# 517 519
# 469 471
# 425 427
# 398 400
# 382 384
# 352 354
# 343 345
# 315 317
# 298 300
# 283 285
# 274 276
# 259 261
# 260 262
# 261 263
# 254 256
# 258 260
# 260 262
# 264 266
# 251 253
# 257 259
# 257 259
# 251 253
# 246 248
# 242 244
# 242 244
# 236 238
# 238 240
# 235 237
# 238 240
# 243 245
# 243 245
# 234 236
# 228 230
# Synthetic dataset 1: Running Lasso_Sklearn model
# Synthetic dataset 2: Running GFL_Matlab model
# Synthetic dataset 2: Running Lasso model
# Synthetic dataset 2: Running Proximal model
# 843 845
# 843 845
# 843 845
# 843 845
# 843 845
# 843 845
# 843 845
# 843 845
# 843 845
# 843 845
# 843 845
# 843 845
# 836 838
# 845 847
# 860 862
# 792 794
# 743 745
# 715 717
# 634 636
# 582 584
# 531 533
# 463 465
# 410 412
# 398 400
# 374 376
# 351 353
# 328 330
# 320 322
# 317 319
# 307 309
# 301 303
# 281 283
# 279 281
# 272 274
# 256 258
# 243 245
# 246 248
# 232 234
# 225 227
# 222 224
# 211 213
# 219 221
# 213 215
# 207 209
# 217 219
# 222 224
# 214 216
# 220 222
# 222 224
# 212 214
# 212 214
# 210 212
# Synthetic dataset 2: Running Lasso_Sklearn model
# Synthetic dataset 3: Running GFL_Matlab model
# Synthetic dataset 3: Running Lasso model
# Synthetic dataset 3: Running Proximal model
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 847 849
# 840 842
# 806 808
# 795 797
# 742 744
# 673 675
# 626 628
# 571 573
# 510 512
# 464 466
# 422 424
# 395 397
# 376 378
# 354 356
# 338 340
# 342 344
# 327 329
# 326 328
# 319 321
# 309 311
# 308 310
# 291 293
# 280 282
# 285 287
# 281 283
# 275 277
# 259 261
# 277 279
# 274 276
# 271 273
# 269 271
# 252 254
# 251 253
# 240 242
# 250 252
# 247 249
# 237 239
# 235 237
# 239 241
# 236 238
# Synthetic dataset 3: Running Lasso_Sklearn model
# Synthetic dataset 4: Running GFL_Matlab model
# Synthetic dataset 4: Running Lasso model
# Synthetic dataset 4: Running Proximal model
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 813 815
# 838 840
# 811 813
# 835 837
# 812 814
# 766 768
# 705 707
# 647 649
# 587 589
# 526 528
# 464 466
# 439 441
# 392 394
# 357 359
# 335 337
# 310 312
# 290 292
# 278 280
# 270 272
# 263 265
# 261 263
# 254 256
# 250 252
# 243 245
# 235 237
# 226 228
# 234 236
# 228 230
# 222 224
# 215 217
# 209 211
# 204 206
# 204 206
# 199 201
# 201 203
# 194 196
# 197 199
# 191 193
# Synthetic dataset 4: Running Lasso_Sklearn model
# Synthetic dataset 5: Running GFL_Matlab model
# Synthetic dataset 5: Running Lasso model
# Synthetic dataset 5: Running Proximal model
# 812 814
# 812 814
# 812 814
# 812 814
# 812 814
# 812 814
# 812 814
# 812 814
# 812 814
# 812 814
# 812 814
# 812 814
# 847 849
# 832 834
# 827 829
# 802 804
# 758 760
# 723 725
# 639 641
# 573 575
# 524 526
# 469 471
# 435 437
# 395 397
# 374 376
# 363 365
# 342 344
# 323 325
# 320 322
# 290 292
# 280 282
# 273 275
# 265 267
# 262 264
# 258 260
# 263 265
# 260 262
# 256 258
# 257 259
# 247 249
# 243 245
# 240 242
# 252 254
# 250 252
# 245 247
# 237 239
# Synthetic dataset 5: Running Lasso_Sklearn model
# Synthetic dataset 6: Running GFL_Matlab model
# Synthetic dataset 6: Running Lasso model
# Synthetic dataset 6: Running Proximal model
# 818 820
# 818 820
# 818 820
# 818 820
# 818 820
# 818 820
# 818 820
# 818 820
# 818 820
# 818 820
# 818 820
# 818 820
# 841 843
# 847 849
# 821 823
# 798 800
# 759 761
# 712 714
# 654 656
# 585 587
# 522 524
# 465 467
# 403 405
# 369 371
# 340 342
# 322 324
# 313 315
# 289 291
# 280 282
# 278 280
# 270 272
# 256 258
# 248 250
# 247 249
# 239 241
# 228 230
# 217 219
# 210 212
# 201 203
# 203 205
# 186 188
# 195 197
# 183 185
# 193 195
# 187 189
# 187 189
# 179 181
# 184 186
# 185 187
# 176 178
# 179 181
# Synthetic dataset 6: Running Lasso_Sklearn model
# Synthetic dataset 7: Running GFL_Matlab model
# Synthetic dataset 7: Running Lasso model
# Synthetic dataset 7: Running Proximal model
# 785 787
# 785 787
# 785 787
# 785 787
# 785 787
# 785 787
# 785 787
# 785 787
# 785 787
# 785 787
# 785 787
# 785 787
# 833 835
# 807 809
# 807 809
# 783 785
# 719 721
# 651 653
# 587 589
# 522 524
# 473 475
# 430 432
# 412 414
# 387 389
# 352 354
# 344 346
# 320 322
# 295 297
# 283 285
# 287 289
# 279 281
# 269 271
# 264 266
# 271 273
# 277 279
# 269 271
# 266 268
# 255 257
# 248 250
# 242 244
# 227 229
# 244 246
# 247 249
# 233 235
# 231 233
# 223 225
# 225 227
# 234 236
# 229 231
# 223 225
# 221 223
# 221 223
# 219 221
# 217 219
# Synthetic dataset 7: Running Lasso_Sklearn model
# Synthetic dataset 8: Running GFL_Matlab model
# Synthetic dataset 8: Running Lasso model
# Synthetic dataset 8: Running Proximal model
# 837 839
# 837 839
# 837 839
# 837 839
# 837 839
# 837 839
# 837 839
# 837 839
# 837 839
# 837 839
# 837 839
# 837 839
# 866 868
# 860 862
# 855 857
# 826 828
# 777 779
# 749 751
# 695 697
# 628 630
# 565 567
# 523 525
# 464 466
# 440 442
# 408 410
# 386 388
# 364 366
# 339 341
# 310 312
# 292 294
# 284 286
# 277 279
# 273 275
# 263 265
# 252 254
# 244 246
# 235 237
# 241 243
# 232 234
# 233 235
# 237 239
# 239 241
# 236 238
# 239 241
# 240 242
# 245 247
# 244 246
# 231 233
# 226 228
# 225 227
# 223 225
# 224 226
# 218 220
# 210 212
# 214 216
# Synthetic dataset 8: Running Lasso_Sklearn model
# Synthetic dataset 9: Running GFL_Matlab model
# Synthetic dataset 9: Running Lasso model
# Synthetic dataset 9: Running Proximal model
# 817 819
# 817 819
# 817 819
# 817 819
# 817 819
# 817 819
# 817 819
# 817 819
# 817 819
# 817 819
# 817 819
# 817 819
# 835 837
# 845 847
# 837 839
# 817 819
# 733 735
# 652 654
# 607 609
# 574 576
# 512 514
# 502 504
# 460 462
# 428 430
# 384 386
# 379 381
# 360 362
# 340 342
# 340 342
# 331 333
# 323 325
# 305 307
# 284 286
# 271 273
# 264 266
# 258 260
# 241 243
# 224 226
# 222 224
# 212 214
# 209 211
# 201 203
# 208 210
# 207 209
# 194 196
# 193 195
# 200 202
# 193 195
# 192 194
# 191 193
# Synthetic dataset 9: Running Lasso_Sklearn model
# Synthetic dataset 10: Running GFL_Matlab model
# Synthetic dataset 10: Running Lasso model
# Synthetic dataset 10: Running Proximal model
# 794 796
# 794 796
# 794 796
# 794 796
# 794 796
# 794 796
# 794 796
# 794 796
# 794 796
# 794 796
# 794 796
# 794 796
# 827 829
# 836 838
# 787 789
# 769 771
# 692 694
# 637 639
# 592 594
# 521 523
# 461 463
# 436 438
# 399 401
# 378 380
# 333 335
# 329 331
# 317 319
# 297 299
# 304 306
# 284 286
# 278 280
# 268 270
# 264 266
# 238 240
# 243 245
# 241 243
# 234 236
# 233 235
# 235 237
# 225 227
# 216 218
# 217 219
# 210 212
# 209 211
# 211 213
# 208 210
# 211 213
# 210 212
# 201 203
# 197 199
# Synthetic dataset 10: Running Lasso_Sklearn model
# Synthetic dataset 11: Running GFL_Matlab model
# Synthetic dataset 11: Running Lasso model
# Synthetic dataset 11: Running Proximal model
# 836 838
# 836 838
# 836 838
# 836 838
# 836 838
# 836 838
# 836 838
# 836 838
# 836 838
# 836 838
# 836 838
# 836 838
# 837 839
# 866 868
# 815 817
# 802 804
# 762 764
# 713 715
# 644 646
# 606 608
# 545 547
# 492 494
# 460 462
# 415 417
# 374 376
# 348 350
# 326 328
# 320 322
# 313 315
# 306 308
# 288 290
# 276 278
# 264 266
# 267 269
# 270 272
# 269 271
# 269 271
# 239 241
# 250 252
# 238 240
# 230 232
# 236 238
# 225 227
# 221 223
# 221 223
# 215 217
# 219 221
# 223 225
# 219 221
# 229 231
# 232 234
# 221 223
# 212 214
# 209 211
# Synthetic dataset 11: Running Lasso_Sklearn model
# Synthetic dataset 12: Running GFL_Matlab model
# Synthetic dataset 12: Running Lasso model
# Synthetic dataset 12: Running Proximal model
# 806 808
# 806 808
# 806 808
# 806 808
# 806 808
# 806 808
# 806 808
# 806 808
# 806 808
# 806 808
# 806 808
# 806 808
# 827 829
# 826 828
# 815 817
# 764 766
# 699 701
# 605 607
# 535 537
# 496 498
# 456 458
# 431 433
# 399 401
# 341 343
# 314 316
# 297 299
# 280 282
# 275 277
# 273 275
# 276 278
# 266 268
# 254 256
# 255 257
# 234 236
# 239 241
# 241 243
# 237 239
# 242 244
# 243 245
# 239 241
# 236 238
# 249 251
# 242 244
# 241 243
# 238 240
# 230 232
# 210 212
# 207 209
# 205 207
# 200 202
# 196 198
# Synthetic dataset 12: Running Lasso_Sklearn model
# Synthetic dataset 13: Running GFL_Matlab model
# Synthetic dataset 13: Running Lasso model
# Synthetic dataset 13: Running Proximal model
# 829 831
# 829 831
# 829 831
# 829 831
# 829 831
# 829 831
# 829 831
# 829 831
# 829 831
# 829 831
# 829 831
# 829 831
# 837 839
# 837 839
# 819 821
# 805 807
# 766 768
# 715 717
# 687 689
# 608 610
# 540 542
# 498 500
# 446 448
# 402 404
# 353 355
# 337 339
# 317 319
# 297 299
# 296 298
# 280 282
# 266 268
# 257 259
# 251 253
# 244 246
# 234 236
# 230 232
# 229 231
# 239 241
# 238 240
# 230 232
# 230 232
# 217 219
# 214 216
# 222 224
# 224 226
# 219 221
# 210 212
# 207 209
# 206 208
# 202 204
# 204 206
# Synthetic dataset 13: Running Lasso_Sklearn model
# Synthetic dataset 14: Running GFL_Matlab model
# Synthetic dataset 14: Running Lasso model
# Synthetic dataset 14: Running Proximal model
# 792 794
# 792 794
# 792 794
# 792 794
# 792 794
# 792 794
# 792 794
# 792 794
# 792 794
# 792 794
# 792 794
# 792 794
# 855 857
# 844 846
# 824 826
# 782 784
# 774 776
# 728 730
# 690 692
# 640 642
# 566 568
# 503 505
# 436 438
# 394 396
# 361 363
# 338 340
# 333 335
# 334 336
# 318 320
# 312 314
# 299 301
# 300 302
# 287 289
# 287 289
# 270 272
# 269 271
# 259 261
# 246 248
# 249 251
# 258 260
# 239 241
# 236 238
# 237 239
# 242 244
# 241 243
# 242 244
# 232 234
# 242 244
# 236 238
# 229 231
# 223 225
# Synthetic dataset 14: Running Lasso_Sklearn model
# Synthetic dataset 15: Running GFL_Matlab model
# Synthetic dataset 15: Running Lasso model
# Synthetic dataset 15: Running Proximal model
# 824 826
# 824 826
# 824 826
# 824 826
# 824 826
# 824 826
# 824 826
# 824 826
# 824 826
# 824 826
# 824 826
# 824 826
# 836 838
# 855 857
# 827 829
# 798 800
# 728 730
# 707 709
# 635 637
# 557 559
# 509 511
# 471 473
# 417 419
# 403 405
# 376 378
# 345 347
# 324 326
# 319 321
# 308 310
# 289 291
# 280 282
# 277 279
# 272 274
# 261 263
# 255 257
# 255 257
# 257 259
# 241 243
# 243 245
# 239 241
# 241 243
# 223 225
# 229 231
# 237 239
# 225 227
# 228 230
# 231 233
# 218 220
# 225 227
# 228 230
# 225 227
# Synthetic dataset 15: Running Lasso_Sklearn model
# Synthetic dataset 16: Running GFL_Matlab model
# Synthetic dataset 16: Running Lasso model
# Synthetic dataset 16: Running Proximal model
# 767 769
# 767 769
# 767 769
# 767 769
# 767 769
# 767 769
# 767 769
# 767 769
# 767 769
# 767 769
# 767 769
# 767 769
# 820 822
# 792 794
# 793 795
# 751 753
# 702 704
# 629 631
# 552 554
# 475 477
# 434 436
# 410 412
# 391 393
# 360 362
# 333 335
# 310 312
# 305 307
# 296 298
# 291 293
# 277 279
# 276 278
# 264 266
# 254 256
# 253 255
# 245 247
# 246 248
# 238 240
# 232 234
# 232 234
# 233 235
# 235 237
# 225 227
# 225 227
# 233 235
# 228 230
# 224 226
# 233 235
# 227 229
# 223 225
# 220 222
# 227 229
# 218 220
# Synthetic dataset 16: Running Lasso_Sklearn model
# Synthetic dataset 17: Running GFL_Matlab model
# Synthetic dataset 17: Running Lasso model
# Synthetic dataset 17: Running Proximal model
# 794 796
# 794 796
# 794 796
# 794 796
# 794 796
# 794 796
# 794 796
# 794 796
# 794 796
# 794 796
# 794 796
# 794 796
# 850 852
# 835 837
# 815 817
# 778 780
# 748 750
# 716 718
# 637 639
# 561 563
# 527 529
# 487 489
# 433 435
# 406 408
# 372 374
# 352 354
# 335 337
# 303 305
# 295 297
# 295 297
# 280 282
# 274 276
# 272 274
# 265 267
# 269 271
# 255 257
# 245 247
# 249 251
# 241 243
# 233 235
# 237 239
# 229 231
# 235 237
# 232 234
# 225 227
# 221 223
# 220 222
# 211 213
# 197 199
# 197 199
# Synthetic dataset 17: Running Lasso_Sklearn model
# Synthetic dataset 18: Running GFL_Matlab model
# Synthetic dataset 18: Running Lasso model
# Synthetic dataset 18: Running Proximal model
# 815 817
# 815 817
# 815 817
# 815 817
# 815 817
# 815 817
# 815 817
# 815 817
# 815 817
# 815 817
# 815 817
# 815 817
# 830 832
# 816 818
# 810 812
# 782 784
# 731 733
# 667 669
# 598 600
# 541 543
# 485 487
# 452 454
# 430 432
# 404 406
# 359 361
# 337 339
# 322 324
# 326 328
# 297 299
# 281 283
# 269 271
# 261 263
# 265 267
# 253 255
# 251 253
# 246 248
# 232 234
# 227 229
# 224 226
# 219 221
# 210 212
# 211 213
# 210 212
# 207 209
# 204 206
# 195 197
# 200 202
# 206 208
# Synthetic dataset 18: Running Lasso_Sklearn model
# Synthetic dataset 19: Running GFL_Matlab model
# Synthetic dataset 19: Running Lasso model
# Synthetic dataset 19: Running Proximal model
# 782 784
# 782 784
# 782 784
# 782 784
# 782 784
# 782 784
# 782 784
# 782 784
# 782 784
# 782 784
# 782 784
# 782 784
# 816 818
# 828 830
# 799 801
# 749 751
# 719 721
# 657 659
# 603 605
# 548 550
# 453 455
# 396 398
# 368 370
# 337 339
# 315 317
# 293 295
# 262 264
# 237 239
# 225 227
# 217 219
# 216 218
# 209 211
# 216 218
# 215 217
# 212 214
# 209 211
# 205 207
# 201 203
# 207 209
# 197 199
# 198 200
# 202 204
# 208 210
# 198 200
# 192 194
# 198 200
# Synthetic dataset 19: Running Lasso_Sklearn model
# Synthetic dataset 20: Running GFL_Matlab model
# Synthetic dataset 20: Running Lasso model
# Synthetic dataset 20: Running Proximal model
# 808 810
# 808 810
# 808 810
# 808 810
# 808 810
# 808 810
# 808 810
# 808 810
# 808 810
# 808 810
# 808 810
# 808 810
# 809 811
# 818 820
# 803 805
# 779 781
# 746 748
# 689 691
# 592 594
# 533 535
# 476 478
# 428 430
# 408 410
# 376 378
# 337 339
# 322 324
# 307 309
# 292 294
# 283 285
# 270 272
# 261 263
# 263 265
# 269 271
# 253 255
# 246 248
# 243 245
# 243 245
# 243 245
# 236 238
# 232 234
# 232 234
# 224 226
# 234 236
# 228 230
# 219 221
# 215 217
# 209 211
# 208 210
# 206 208
# Synthetic dataset 20: Running Lasso_Sklearn model
# Model: GFL_Matlab, Avg. Accuracy: 0.677, Std. Accuracy: 0.06333245613427602
# Model: Lasso, Avg. Accuracy: 0.385, Std. Accuracy: 0.04811444689487763
# Model: Proximal, Avg. Accuracy: 0.9420000000000002, Std. Accuracy: 0.03458323293158116
# Model: Lasso_Sklearn, Avg. Accuracy: 0.39599999999999996, Std. Accuracy: 0.0571314274283428

# %%
# write a function to plot the results
def analysis(accuracy):
    acc_1, acc_2, acc_3, acc_4 = [], [], [], []
    std_1, std_2, std_3, std_4 = [], [], [], []

    for i in range(len(accuracy)):
        mean_1 = np.mean(accuracy[i]['Proximal'])
        stddev_1 = np.std(accuracy[i]['Proximal'])
        acc_1.append(mean_1)
        std_1.append(stddev_1)

        mean_2 = np.mean(accuracy[i]['GFL_Matlab'])
        stddev_2 = np.std(accuracy[i]['GFL_Matlab'])
        acc_2.append(mean_2)
        std_2.append(stddev_2)

        mean_3 = np.mean(accuracy[i]['Lasso'])
        stddev_3 = np.std(accuracy[i]['Lasso'])
        acc_3.append(mean_3)
        std_3.append(stddev_3)

        mean_4 = np.mean(accuracy[i]['Lasso_Sklearn'])
        stddev_4 = np.std(accuracy[i]['Lasso_Sklearn'])
        acc_4.append(mean_4)
        std_4.append(stddev_4)

    
    plt.figure(figsize=(8, 6))
    plt.errorbar(sample_sizes, acc_1, yerr=std_1, fmt='o-', label='Proximal', capsize=5)
    plt.errorbar(sample_sizes, acc_2, yerr=std_2, fmt='o-', label='GFL_Matlab', capsize=5)
    plt.errorbar(sample_sizes, acc_3, yerr=std_3, fmt='o-', label='Lasso', capsize=5)
    plt.errorbar(sample_sizes, acc_4, yerr=std_4, fmt='o-', label='Lasso_Sklearn', capsize=5)
    plt.xlabel('Sample Size')
    plt.ylabel('Accuracy')
    plt.title('Accuracy vs. Sample Size')
    plt.legend()
    plt.show()


accuracys = [accuracy, accuracy_1, accuracy_2, accuracy_3, accuracy_4, accuracy_5]
for acc in accuracys:
    analysis(acc)
